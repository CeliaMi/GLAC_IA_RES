# %% [markdown]
# # GlacIAnalys:
#
#
# ##***PROYECTO AI Saturdays : Glaciares y Deshielo***🧊:
# + **Alumnos**: Celia Millán, Daniel López, Ana Aragón, Laura Castro, Jorge Benitez
# + **Mentores**: Alejandro, Miguel B, Jorge G
#
#   ## Objetivos☝:
#
#     ``
#     ⭐Nuestro objetivo principal es: Tener un Data set para entrenar a nuestro modelo
#     ``
#
#     Este proyecto es una investigación sobre la pérdida de masa y volumen de los glaciares aplicando la inteligencia Artificial para realizar **prediciones sobre el estado de algunos glaciares en  2030 y 2050**.
#
#     Para ello hemos realizado una búsqueda de datos recogidos de glaciares teniendo en cuenta su localización, su masa  y su volumen a lo largo del el tiempo.
#
#     Son muchas las instituciones que recogen este tipo de datos, en nuestro caso nos hemos decantado por la recopilación que se ha hecho desde  World Glacier Monitoring Service [**WGMS**](https://wgms.ch/data_databaseversions)
#
#     Nuestro objetivo es crear un único data set a través de un **conjunto de 10 csv** que proporciona WGMS relacionados entre sí a través de identificadores únicos.
#
#     Cuando escojamos las columnas que nos interesen más para nuestro estudio,
#     pasaremos a añadir **variables exogenas** como C02 , temperatura, irradiación solar, subida del nivel del mar.
#
#
#   ## Conjunto de dataset proporcionados por WGMS.
#
#
#   1. 🧊**glacier.csv**: General (and presumably static) information about each glacier. When submitting a new glacier, assign a temporary WGMS_ID and use this as the WGMS_ID in all other table rows that correspond to this glacier
#   2. 🧊**state.csv**: Glacier length, area, and elevation range.
#   3. 🧊 **change.csv**: Change in glacier thickness, area, and/or volume – typically from geodetic surveys.
#   4. 🧊**mass_balance.csv**: Glacier mass balance measurements by elevation band.
#   2. 🧊**front_variation.csv**
#   3. 🧊**glacier.csv**: General (and presumably static) information about each glacier. When submitting a new glacier, assign a temporary WGMS_ID and use this as the WGMS_ID in all other table rows that correspond to this glacier.
#   5. 🧊**mass_balance_overview.csv**: Overview of glacier mass balance surveys.
#   6. 🧊**mass_balance_point.csv**: Glacier mass balance measured at specific points (e.g. stakes or pits).
#   7. 🧊**reconstruction_front_variation.csv**: Glacier length changes reconstructed from historic records and geologic dating.
#   8. 🧊**reconstruction_series.csv**: Overview of reconstructed glacier length change series.
#   9. 🧊**special_event.csv**: Extraordinary events concerning glacier hazards and dramatic glacier changes.

# %% [markdown]
# ## Preparamos el entorno de trabajo👷‍♀️

# %%
import re
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import spacy
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, roc_curve, auc
from sklearn.metrics import classification_report, confusion_matrix

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Análisis exploratorio de datos🔍:
#
# Es un conjunto de datos **sobre cambios en los glaciares** (longitud, área, volumen, masa) estandarizados y recopilados internacionalmente, basados ​​en observaciones in situ y teledetección, así como en reconstrucciones. publicado por World Glacier Monitoring Service [**WGMS**](https://wgms.ch/data_databaseversions)
#
# - `✍creado` 2024-01-23
# - `⏰temporalidad de los datos` 1127/2024
#
# `
# `
# ### 📄 Consideraciones a la hora de analizar `glacier.csv`:
#
# + este csv contiene Información general (y presumiblemente estática) sobre cada glaciar. Al enviar un nuevo glaciar, asigne un `WGMS_ID` temporal y utilícelo como `WGMS_ID` en todas las demás filas de la tabla que correspondan a este glaciar.
#
# + ⚠ `Atención` desde WGMS advierten que los datos pueden contener errores e inexactitudes y sugieren que en caso de ambigüedades se les comunique o bien a ellos o a los investigadores e instituciones enumerados en los datos (columnas `INVESTIGADOR` y `SPONS_AGENCY`).

# %% [markdown]
# ###🧊DATASET 1 **Glacier.csv**:
# - dataset resultante: **clean_glacier_df**

# %%
#leemos el archivo y representamos sus primeras 10 líneas
glacier_df = pd.read_csv('/content/drive/MyDrive/DATASETS/glacier.csv')
glacier_df.head(10)
# Out:
# <ipython-input-103-4b6b463e2270>:2: DtypeWarning: Columns (3,4,10,11,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   glacier_df = pd.read_csv('/content/drive/MyDrive/DATASETS/glacier.csv')
#   POLITICAL_UNIT            NAME  WGMS_ID             GEN_LOCATION  \
# 0             AF        PIR YAKH    10452  UPPER CABUL RIVER BASIN
# 1             AF  RGI60-13.10763   156232                      NaN
# 2             AF  RGI60-13.10764   156233                      NaN
# 3             AF  RGI60-13.10765   156234                      NaN
# 4             AF  RGI60-13.10766   156235                      NaN
# 5             AF  RGI60-13.10767   156236                      NaN
# 6             AF  RGI60-13.10768   156237                      NaN
# 7             AF  RGI60-13.10769   156238                      NaN
# 8             AF  RGI60-13.10770   156239                      NaN
# 9             AF  RGI60-13.10771   156240                      NaN
#
#    SPEC_LOCATION   LATITUDE  LONGITUDE  PRIM_CLASSIFIC  FORM  FRONTAL_CHARS  \
# 0  CHUMAR VALLEY  35.595001  70.169998             6.0   3.0            8.0
# 1            NaN  37.262384  73.525069             NaN   NaN            NaN
# 2            NaN  37.258539  73.546610             NaN   NaN            NaN
# 3            NaN  37.266134  73.542243             NaN   NaN            NaN
# 4            NaN  37.273266  73.535659             NaN   NaN            NaN
# 5            NaN  37.267820  73.557927             NaN   NaN            NaN
# 6            NaN  37.270174  73.566393             NaN   NaN            NaN
# 7            NaN  37.273807  73.576475             NaN   NaN            NaN
# 8            NaN  37.284926  73.579521             NaN   NaN            NaN
# 9            NaN  37.290455  73.565636             NaN   NaN            NaN
#
#   EXPOS_ACC_AREA EXPOS_ABL_AREA  PARENT_GLACIER  \
# 0             NE             NE             NaN
# 1            NaN            NaN             NaN
# 2            NaN            NaN             NaN
# 3            NaN            NaN             NaN
# 4            NaN            NaN             NaN
# 5            NaN            NaN             NaN
# 6            NaN            NaN             NaN
# 7            NaN            NaN             NaN
# 8            NaN            NaN             NaN
# 9            NaN            NaN             NaN
#
#                                              REMARKS GLACIER_REGION_CODE  \
# 0  Local people call this glacier PIR YAKH which ...                 ASW
# 1                                                NaN                 ASC
# 2                                                NaN                 ASC
# 3                                                NaN                 ASC
# 4                                                NaN                 ASC
# 5                                                NaN                 ASC
# 6                                                NaN                 ASC
# 7                                                NaN                 ASC
# 8                                                NaN                 ASC
# 9                                                NaN                 ASC
#
#   GLACIER_SUBREGION_CODE
# 0                 ASW-01
# 1                 ASC-02
# 2                 ASC-02
# 3                 ASC-02
# 4                 ASC-02
# 5                 ASC-02
# 6                 ASC-02
# 7                 ASC-02
# 8                 ASC-02
# 9                 ASC-02

# %%
glacier_df['GLACIER_REGION_CODE'].unique()
# Out:
# array(['ASW', 'ASC', 'CEU', 'ANT', 'SAN', 'TRP', 'CAU', 'ASE', 'ACS',
#        'ACN', 'ALA', 'WNA', 'ASN', 'GRL', 'ISL', 'SCA', 'NZL', 'RUA',
#        'SJM'], dtype=object)

# %%
#info general:
glacier_df.describe()
# Out:
#              WGMS_ID       LATITUDE      LONGITUDE  PRIM_CLASSIFIC  \
# count  214644.000000  214644.000000  214644.000000     3547.000000
# mean   109392.292512      37.568446      -1.501271        5.454187
# std     62242.576488      33.549702      92.229193        0.955482
# min         0.000000     -82.059998    -179.029999        0.000000
# 25%     55891.750000      32.942000     -73.618551        5.000000
# 50%    109569.500000      41.418001      16.083000        6.000000
# 75%    163259.250000      60.234000      78.794000        6.000000
# max    216925.000000      83.554200     177.350204        8.000000
#
#               FORM  FRONTAL_CHARS  PARENT_GLACIER
# count  3349.000000    3398.000000      405.000000
# mean      2.858167       7.336374     4513.160494
# std       1.181502       2.492055     5937.969763
# min       0.000000       0.000000       85.000000
# 25%       2.000000       6.000000     2740.000000
# 50%       3.000000       8.000000     3325.000000
# 75%       3.000000       9.000000     3754.000000
# max       9.000000       9.000000    33649.000000

# %%
glacier_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214644 entries, 0 to 214643
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   POLITICAL_UNIT          214644 non-null  object
#  1   NAME                    214644 non-null  object
#  2   WGMS_ID                 214644 non-null  int64
#  3   GEN_LOCATION            7594 non-null    object
#  4   SPEC_LOCATION           6353 non-null    object
#  5   LATITUDE                214644 non-null  float64
#  6   LONGITUDE               214644 non-null  float64
#  7   PRIM_CLASSIFIC          3547 non-null    float64
#  8   FORM                    3349 non-null    float64
#  9   FRONTAL_CHARS           3398 non-null    float64
#  10  EXPOS_ACC_AREA          2068 non-null    object
#  11  EXPOS_ABL_AREA          2078 non-null    object
#  12  PARENT_GLACIER          405 non-null     float64
#  13  REMARKS                 20879 non-null   object
#  14  GLACIER_REGION_CODE     214644 non-null  object
#  15  GLACIER_SUBREGION_CODE  214644 non-null  object
# dtypes: float64(6), int64(1), object(9)
# memory usage: 26.2+ MB

# %%
#convertimos a nulos los valores NaN:
columns_glacier = list(glacier_df.columns)
glacier_df[columns_glacier].replace('NaN', np.nan)
# Out:
#        POLITICAL_UNIT            NAME  WGMS_ID             GEN_LOCATION  \
# 0                  AF        PIR YAKH    10452  UPPER CABUL RIVER BASIN
# 1                  AF  RGI60-13.10763   156232                      NaN
# 2                  AF  RGI60-13.10764   156233                      NaN
# 3                  AF  RGI60-13.10765   156234                      NaN
# 4                  AF  RGI60-13.10766   156235                      NaN
# ...               ...             ...      ...                      ...
# 214639             VE  RGI60-16.01388    69769                      NaN
# 214640             VE  RGI60-16.01389    69770                      NaN
# 214641             VE       TIMONCITO     1009            SIERRA NEVADA
# 214642             VE   UNNAMED 26918    26918                      NaN
# 214643             VE   UNNAMED 26919    26919                      NaN
#
#         SPEC_LOCATION   LATITUDE  LONGITUDE  PRIM_CLASSIFIC  FORM  \
# 0       CHUMAR VALLEY  35.595001  70.169998             6.0   3.0
# 1                 NaN  37.262384  73.525069             NaN   NaN
# 2                 NaN  37.258539  73.546610             NaN   NaN
# 3                 NaN  37.266134  73.542243             NaN   NaN
# 4                 NaN  37.273266  73.535659             NaN   NaN
# ...               ...        ...        ...             ...   ...
# 214639            NaN   8.540470 -71.046000             NaN   NaN
# 214640            NaN   8.541140 -71.050400             NaN   NaN
# 214641  CERRO BOLIVAR   8.550000 -71.029999             NaN   NaN
# 214642            NaN   8.547500 -70.996300             NaN   NaN
# 214643            NaN   8.547400 -71.000099             NaN   NaN
#
#         FRONTAL_CHARS EXPOS_ACC_AREA EXPOS_ABL_AREA  PARENT_GLACIER  \
# 0                 8.0             NE             NE             NaN
# 1                 NaN            NaN            NaN             NaN
# 2                 NaN            NaN            NaN             NaN
# 3                 NaN            NaN            NaN             NaN
# 4                 NaN            NaN            NaN             NaN
# ...               ...            ...            ...             ...
# 214639            NaN            NaN            NaN             NaN
# 214640            NaN            NaN            NaN             NaN
# 214641            NaN             SE             SE             NaN
# 214642            NaN            NaN            NaN             NaN
# 214643            NaN            NaN            NaN             NaN
#
#                                                   REMARKS GLACIER_REGION_CODE  \
# 0       Local people call this glacier PIR YAKH which ...                 ASW
# 1                                                     NaN                 ASC
# 2                                                     NaN                 ASC
# 3                                                     NaN                 ASC
# 4                                                     NaN                 ASC
# ...                                                   ...                 ...
# 214639                                                NaN                 TRP
# 214640                                                NaN                 TRP
# 214641                                                NaN                 TRP
# 214642                                                NaN                 TRP
# 214643                                                NaN                 TRP
#
#        GLACIER_SUBREGION_CODE
# 0                      ASW-01
# 1                      ASC-02
# 2                      ASC-02
# 3                      ASC-02
# 4                      ASC-02
# ...                       ...
# 214639                 TRP-01
# 214640                 TRP-01
# 214641                 TRP-01
# 214642                 TRP-01
# 214643                 TRP-01
#
# [214644 rows x 16 columns]

# %%
glacier_df.isna()
# Out:
#         POLITICAL_UNIT   NAME  WGMS_ID  GEN_LOCATION  SPEC_LOCATION  LATITUDE  \
# 0                False  False    False         False          False     False
# 1                False  False    False          True           True     False
# 2                False  False    False          True           True     False
# 3                False  False    False          True           True     False
# 4                False  False    False          True           True     False
# ...                ...    ...      ...           ...            ...       ...
# 214639           False  False    False          True           True     False
# 214640           False  False    False          True           True     False
# 214641           False  False    False         False          False     False
# 214642           False  False    False          True           True     False
# 214643           False  False    False          True           True     False
#
#         LONGITUDE  PRIM_CLASSIFIC   FORM  FRONTAL_CHARS  EXPOS_ACC_AREA  \
# 0           False           False  False          False           False
# 1           False            True   True           True            True
# 2           False            True   True           True            True
# 3           False            True   True           True            True
# 4           False            True   True           True            True
# ...           ...             ...    ...            ...             ...
# 214639      False            True   True           True            True
# 214640      False            True   True           True            True
# 214641      False            True   True           True           False
# 214642      False            True   True           True            True
# 214643      False            True   True           True            True
#
#         EXPOS_ABL_AREA  PARENT_GLACIER  REMARKS  GLACIER_REGION_CODE  \
# 0                False            True    False                False
# 1                 True            True     True                False
# 2                 True            True     True                False
# 3                 True            True     True                False
# 4                 True            True     True                False
# ...                ...             ...      ...                  ...
# 214639            True            True     True                False
# 214640            True            True     True                False
# 214641           False            True     True                False
# 214642            True            True     True                False
# 214643            True            True     True                False
#
#         GLACIER_SUBREGION_CODE
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 214639                   False
# 214640                   False
# 214641                   False
# 214642                   False
# 214643                   False
#
# [214644 rows x 16 columns]

# %%
# ver la cantidad de valores nulos por cada columna:
glacier_df.isna().sum()
# Out:
# POLITICAL_UNIT                 0
# NAME                           0
# WGMS_ID                        0
# GEN_LOCATION              207050
# SPEC_LOCATION             208291
# LATITUDE                       0
# LONGITUDE                      0
# PRIM_CLASSIFIC            211097
# FORM                      211295
# FRONTAL_CHARS             211246
# EXPOS_ACC_AREA            212576
# EXPOS_ABL_AREA            212566
# PARENT_GLACIER            214239
# REMARKS                   193765
# GLACIER_REGION_CODE            0
# GLACIER_SUBREGION_CODE         0
# dtype: int64

# %%
#Aquellas columnas que tengan valores nulos no nos van a servir, así que haremos limpieza de este dataset y nos quedaremos con las columnas necesarias:
clean_glacier_df = pd.DataFrame()
# Iterar sobre cada columna del DataFrame original
for col in glacier_df.columns:
    # Verificar si la columna no tiene valores nulos
    if glacier_df[col].isna().sum() == 0:
        # Si no tiene valores nulos, agregarla al nuevo DataFrame
        clean_glacier_df[col] = glacier_df[col]

# %%
#Vemos como queda el primer df limpio
#clean_glacier_df.drop(columns='GLACIER_SUBREGION_CODE', inplace = True)
clean_glacier_df.head(15)
# Out:
#    POLITICAL_UNIT            NAME  WGMS_ID   LATITUDE  LONGITUDE  \
# 0              AF        PIR YAKH    10452  35.595001  70.169998
# 1              AF  RGI60-13.10763   156232  37.262384  73.525069
# 2              AF  RGI60-13.10764   156233  37.258539  73.546610
# 3              AF  RGI60-13.10765   156234  37.266134  73.542243
# 4              AF  RGI60-13.10766   156235  37.273266  73.535659
# 5              AF  RGI60-13.10767   156236  37.267820  73.557927
# 6              AF  RGI60-13.10768   156237  37.270174  73.566393
# 7              AF  RGI60-13.10769   156238  37.273807  73.576475
# 8              AF  RGI60-13.10770   156239  37.284926  73.579521
# 9              AF  RGI60-13.10771   156240  37.290455  73.565636
# 10             AF  RGI60-13.10772   156241  37.296124  73.574452
# 11             AF  RGI60-13.10773   156242  37.292148  73.583840
# 12             AF  RGI60-13.10774   156243  37.309428  73.595000
# 13             AF  RGI60-13.10775   156244  37.309774  73.598329
# 14             AF  RGI60-13.10776   156245  37.313393  73.601402
#
#    GLACIER_REGION_CODE GLACIER_SUBREGION_CODE
# 0                  ASW                 ASW-01
# 1                  ASC                 ASC-02
# 2                  ASC                 ASC-02
# 3                  ASC                 ASC-02
# 4                  ASC                 ASC-02
# 5                  ASC                 ASC-02
# 6                  ASC                 ASC-02
# 7                  ASC                 ASC-02
# 8                  ASC                 ASC-02
# 9                  ASC                 ASC-02
# 10                 ASC                 ASC-02
# 11                 ASC                 ASC-02
# 12                 ASC                 ASC-02
# 13                 ASC                 ASC-02
# 14                 ASC                 ASC-02

# %% [markdown]
# ###🧊DATASET 2  **State.csv**:
# - dataset resultante: **copy_clean_state_df**

# %%
state_df = pd.read_csv('/content/drive/MyDrive/DATASETS/state.csv')
state_df.head(15)
# Out:
#    POLITICAL_UNIT              NAME  WGMS_ID  YEAR  SURVEY_DATE  \
# 0              AF          PIR YAKH    10452  2018     20189999
# 1              AQ             ADAMS      885  1989     19899999
# 2              AQ             ADAMS      885  1990     19909999
# 3              AQ          ALBERICH     1062  1975     19759999
# 4              AQ         ASTROLABE     3354  1947     19479999
# 5              AQ         ASTROLABE     3354  1963     19639999
# 6              AQ         ASTROLABE     3354  1973     19739999
# 7              AQ         ASTROLABE     3354  1985     19859999
# 8              AQ         ASTROLABE     3354  1989     19899999
# 9              AQ  BAHIA DEL DIABLO     2665  2004     20040201
# 10             AQ  BAHIA DEL DIABLO     2665  2008     20089999
# 11             AQ  BAHIA DEL DIABLO     2665  2010     20100228
# 12             AQ  BAHIA DEL DIABLO     2665  2014     20140301
# 13             AQ  BAHIA DEL DIABLO     2665  2015     20150226
# 14             AQ  BAHIA DEL DIABLO     2665  2016     20160228
#
#     HIGHEST_ELEVATION  MEDIAN_ELEVATION  LOWEST_ELEVATION  ELEVATION_UNC  \
# 0              5070.0               NaN            4400.0            NaN
# 1                 NaN               NaN               NaN            NaN
# 2              1200.0             785.0             370.0            NaN
# 3              1800.0            1560.0            1400.0            NaN
# 4                 NaN               NaN               NaN            NaN
# 5                 NaN               NaN               NaN            NaN
# 6                 NaN               NaN               NaN            NaN
# 7                 NaN               NaN               NaN            NaN
# 8                 NaN               NaN               NaN            NaN
# 9               630.0             390.0              50.0            0.5
# 10                NaN               NaN               NaN            NaN
# 11              630.0             390.0              50.0            0.5
# 12              630.0             390.0              50.0            0.5
# 13              630.0             390.0              50.0            0.5
# 14              630.0             390.0              50.0            1.0
#
#     LENGTH  LENGTH_UNC       AREA  AREA_UNC SURVEY_PLATFORM_METHOD  \
# 0      2.1         NaN   1.680000       NaN                    NaN
# 1     10.0         NaN   5.730000       NaN                     cC
# 2      NaN         NaN        NaN       NaN                    NaN
# 3      1.3         NaN   1.360000       NaN                    NaN
# 4      NaN         NaN  83.500000       NaN                    NaN
# 5      NaN         NaN  75.000000       NaN                    NaN
# 6      NaN         NaN  78.900002       NaN                    NaN
# 7      NaN         NaN  70.000000       NaN                    NaN
# 8      NaN         NaN  70.750000       NaN                    NaN
# 9      7.6        0.01        NaN       NaN                     xX
# 10     NaN         NaN  14.300000       NaN                    NaN
# 11     7.6        0.01  14.300000       NaN                     xX
# 12     7.6        0.01  12.900000      0.23                     cG
# 13     7.6        0.01  12.900000      0.23                     cC
# 14     7.6        0.01  12.900000      0.23                     cG
#
#                                          INVESTIGATOR  \
# 0              Abeer Ahmad Sajood, Hedayatullah Arian
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                      Pedro Skvarca, Evgeniy Ermolin
# 10  Pedro Skvarca, Evgeniy Ermolin, Sebastián Mari...
# 11  Pedro Skvarca, Evgeniy Ermolin, Sebastián Mari...
# 12  Evgeniy Ermolin, Sebastián Marinsek, José Luis...
# 13  Sebastián Marinsek, José Luis Seco, Evgeniy Er...
# 14  Sebastián Marinsek, José Luis Seco, Evgeniy Er...
#
#                                          SPONS_AGENCY  \
# 0   Hydrometeorology Department, Geoscience Facult...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   División Glaciología, Instituto Antártico Arge...
# 10                                                NaN
# 11  División Glaciología, Instituto Antártico Arge...
# 12  Departamento de Glaciología, Instituto Antárti...
# 13  Departamento de Glaciología, Instituto Antárti...
# 14  Departamento de Glaciología, Instituto Antárti...
#
#                                 REFERENCE  \
# 0                                     NaN
# 1   WGMS (1993): FoG 1985-1990 (Vol. VI).
# 2   WGMS (1993): FoG 1985-1990 (Vol. VI).
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                                    NaN
# 11   WGMS (2012): FoG 2005-2010 (Vol. X).
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
#
#                                               REMARKS
# 0              Information derived from field report.
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   Survey method: Combination of geodetic ground ...
# 10                                                NaN
# 11  Survey method: Combination of geodetic ground ...
# 12  Survey method: Combination of geodetic ground ...
# 13  Survey method: Combination of geodetic ground ...
# 14  Survey method: Combination of geodetic ground ...

# %%
state_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10756 entries, 0 to 10755
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   POLITICAL_UNIT          10756 non-null  object
#  1   NAME                    10756 non-null  object
#  2   WGMS_ID                 10756 non-null  int64
#  3   YEAR                    10756 non-null  int64
#  4   SURVEY_DATE             10756 non-null  int64
#  5   HIGHEST_ELEVATION       5335 non-null   float64
#  6   MEDIAN_ELEVATION        3590 non-null   float64
#  7   LOWEST_ELEVATION        9308 non-null   float64
#  8   ELEVATION_UNC           1486 non-null   float64
#  9   LENGTH                  4817 non-null   float64
#  10  LENGTH_UNC              917 non-null    float64
#  11  AREA                    5504 non-null   float64
#  12  AREA_UNC                566 non-null    float64
#  13  SURVEY_PLATFORM_METHOD  5189 non-null   object
#  14  INVESTIGATOR            4068 non-null   object
#  15  SPONS_AGENCY            4240 non-null   object
#  16  REFERENCE               8025 non-null   object
#  17  REMARKS                 2860 non-null   object
# dtypes: float64(8), int64(3), object(7)
# memory usage: 1.5+ MB

# %%
state_df.isna().sum()
# Out:
# POLITICAL_UNIT                0
# NAME                          0
# WGMS_ID                       0
# YEAR                          0
# SURVEY_DATE                   0
# HIGHEST_ELEVATION          5421
# MEDIAN_ELEVATION           7166
# LOWEST_ELEVATION           1448
# ELEVATION_UNC              9270
# LENGTH                     5939
# LENGTH_UNC                 9839
# AREA                       5252
# AREA_UNC                  10190
# SURVEY_PLATFORM_METHOD     5567
# INVESTIGATOR               6688
# SPONS_AGENCY               6516
# REFERENCE                  2731
# REMARKS                    7896
# dtype: int64

# %%
# creamos una función para quedaros solo con el año de survey_date porque el mes y el día vemos que no suele aparecer:
def only_year(text):
  text = str(text)
  if text == 'nan':
    return 'nan'
  else:
    text = text[:4]
    return text

# %%
# aplicamos función
state_df['SURVEY_DATE'].apply(only_year)
# Out:
# 0        2018
# 1        1989
# 2        1990
# 3        1975
# 4        1947
#          ...
# 10751    1961
# 10752    1961
# 10753    1970
# 10754    1975
# 10755    1972
# Name: SURVEY_DATE, Length: 10756, dtype: object

# %%
# Revisando nos quedaremos con las siguientes columnas del data set:
# Lista de columnas a mantener en el nuevo DataFrame
columns_state = ['POLITICAL_UNIT', 'NAME', 'WGMS_ID', 'YEAR', 'HIGHEST_ELEVATION', 'MEDIAN_ELEVATION', 'LOWEST_ELEVATION', 'LENGTH', 'AREA']

# Crear un nuevo DataFrame para almacenar las columnas seleccionadas
clean_state_df = pd.DataFrame()

# Iterar sobre cada columna en la lista de columnas
for column in columns_state:
    # Si la columna es 'YEAR' o 'SURVEY_DATE', añadir el prefijo 'state_'
    #if column == 'YEAR' or column == 'SURVEY_DATE':
       # new_state[f'state_{column}'] = state[column]
   # else:
   clean_state_df[column] = state_df[column]

# %%
#Revisamos:
clean_state_df.head(15)
# Out:
#    POLITICAL_UNIT              NAME  WGMS_ID  YEAR  HIGHEST_ELEVATION  \
# 0              AF          PIR YAKH    10452  2018             5070.0
# 1              AQ             ADAMS      885  1989                NaN
# 2              AQ             ADAMS      885  1990             1200.0
# 3              AQ          ALBERICH     1062  1975             1800.0
# 4              AQ         ASTROLABE     3354  1947                NaN
# 5              AQ         ASTROLABE     3354  1963                NaN
# 6              AQ         ASTROLABE     3354  1973                NaN
# 7              AQ         ASTROLABE     3354  1985                NaN
# 8              AQ         ASTROLABE     3354  1989                NaN
# 9              AQ  BAHIA DEL DIABLO     2665  2004              630.0
# 10             AQ  BAHIA DEL DIABLO     2665  2008                NaN
# 11             AQ  BAHIA DEL DIABLO     2665  2010              630.0
# 12             AQ  BAHIA DEL DIABLO     2665  2014              630.0
# 13             AQ  BAHIA DEL DIABLO     2665  2015              630.0
# 14             AQ  BAHIA DEL DIABLO     2665  2016              630.0
#
#     MEDIAN_ELEVATION  LOWEST_ELEVATION  LENGTH       AREA
# 0                NaN            4400.0     2.1   1.680000
# 1                NaN               NaN    10.0   5.730000
# 2              785.0             370.0     NaN        NaN
# 3             1560.0            1400.0     1.3   1.360000
# 4                NaN               NaN     NaN  83.500000
# 5                NaN               NaN     NaN  75.000000
# 6                NaN               NaN     NaN  78.900002
# 7                NaN               NaN     NaN  70.000000
# 8                NaN               NaN     NaN  70.750000
# 9              390.0              50.0     7.6        NaN
# 10               NaN               NaN     NaN  14.300000
# 11             390.0              50.0     7.6  14.300000
# 12             390.0              50.0     7.6  12.900000
# 13             390.0              50.0     7.6  12.900000
# 14             390.0              50.0     7.6  12.900000

# %%
#Rellenaremos los campos de median elevation que sean NA con la media entre el highest y el lowest si existen:
# Verificar si hay filas donde 'MEDIAN_ELEVATION' sea NaN pero 'LOWEST_ELEVATION' y 'HIGHEST_ELEVATION' no lo sean
mask = clean_state_df['MEDIAN_ELEVATION'].isna() & ~clean_state_df['LOWEST_ELEVATION'].isna() & ~clean_state_df['HIGHEST_ELEVATION'].isna()

# Calcular el valor medio para las filas seleccionadas y asignarlo a 'MEDIAN_ELEVATION'
clean_state_df.loc[mask, 'MEDIAN_ELEVATION'] = (clean_state_df.loc[mask, 'LOWEST_ELEVATION'] + clean_state_df.loc[mask, 'HIGHEST_ELEVATION']) / 2

# Ahora, las filas donde 'MEDIAN_ELEVATION' era NaN pero 'LOWEST_ELEVATION' y 'HIGHEST_ELEVATION' tenían datos, tienen 'MEDIAN_ELEVATION' actualizado

# %%
def km_m(area):
  return area * 1000

# %%
clean_state_df['AREA'] = clean_state_df['AREA'].apply(km_m)

# %%
clean_state_df['LENGTH'] = clean_state_df['LENGTH'].apply(km_m)

# %%
clean_state_df.head(15)
# Out:
#    POLITICAL_UNIT              NAME  WGMS_ID  YEAR  HIGHEST_ELEVATION  \
# 0              AF          PIR YAKH    10452  2018             5070.0
# 1              AQ             ADAMS      885  1989                NaN
# 2              AQ             ADAMS      885  1990             1200.0
# 3              AQ          ALBERICH     1062  1975             1800.0
# 4              AQ         ASTROLABE     3354  1947                NaN
# 5              AQ         ASTROLABE     3354  1963                NaN
# 6              AQ         ASTROLABE     3354  1973                NaN
# 7              AQ         ASTROLABE     3354  1985                NaN
# 8              AQ         ASTROLABE     3354  1989                NaN
# 9              AQ  BAHIA DEL DIABLO     2665  2004              630.0
# 10             AQ  BAHIA DEL DIABLO     2665  2008                NaN
# 11             AQ  BAHIA DEL DIABLO     2665  2010              630.0
# 12             AQ  BAHIA DEL DIABLO     2665  2014              630.0
# 13             AQ  BAHIA DEL DIABLO     2665  2015              630.0
# 14             AQ  BAHIA DEL DIABLO     2665  2016              630.0
#
#     MEDIAN_ELEVATION  LOWEST_ELEVATION      LENGTH        AREA
# 0             4735.0            4400.0   2099.9999   1679.9999
# 1                NaN               NaN  10000.0000   5730.0000
# 2              785.0             370.0         NaN         NaN
# 3             1560.0            1400.0   1300.0000   1360.0000
# 4                NaN               NaN         NaN  83500.0000
# 5                NaN               NaN         NaN  75000.0000
# 6                NaN               NaN         NaN  78900.0020
# 7                NaN               NaN         NaN  70000.0000
# 8                NaN               NaN         NaN  70750.0000
# 9              390.0              50.0   7599.9999         NaN
# 10               NaN               NaN         NaN  14300.0000
# 11             390.0              50.0   7599.9999  14300.0000
# 12             390.0              50.0   7599.9999  12900.0000
# 13             390.0              50.0   7599.9999  12900.0000
# 14             390.0              50.0   7599.9999  12900.0000

# %%
clean_state_df['AREA'].isna().sum()
# Out:
# 5252

# %%
copy_clean_state_df = clean_state_df[clean_state_df['NAME'] == 'BAHIA DEL DIABLO']

# %%
copy_clean_state_df
# Out:
#    POLITICAL_UNIT              NAME  WGMS_ID  YEAR  HIGHEST_ELEVATION  \
# 9              AQ  BAHIA DEL DIABLO     2665  2004              630.0
# 10             AQ  BAHIA DEL DIABLO     2665  2008                NaN
# 11             AQ  BAHIA DEL DIABLO     2665  2010              630.0
# 12             AQ  BAHIA DEL DIABLO     2665  2014              630.0
# 13             AQ  BAHIA DEL DIABLO     2665  2015              630.0
# 14             AQ  BAHIA DEL DIABLO     2665  2016              630.0
# 15             AQ  BAHIA DEL DIABLO     2665  2020              630.0
# 16             AQ  BAHIA DEL DIABLO     2665  2023              630.0
#
#     MEDIAN_ELEVATION  LOWEST_ELEVATION     LENGTH     AREA
# 9              390.0              50.0  7599.9999      NaN
# 10               NaN               NaN        NaN  14300.0
# 11             390.0              50.0  7599.9999  14300.0
# 12             390.0              50.0  7599.9999  12900.0
# 13             390.0              50.0  7599.9999  12900.0
# 14             390.0              50.0  7599.9999  12900.0
# 15             390.0              50.0  7600.0000  12900.0
# 16             390.0              50.0  7500.0000  12810.0

# %%
plt.figure(figsize = (8,10))
plt.plot(copy_clean_state_df['YEAR'], copy_clean_state_df['AREA'], marker = 'o', linestyle='-')
plt.title('Área del Glaciar BAHIA DEL DIABLO en función del Año')  # Establece el título del gráfico
plt.xlabel('Año')  # Etiqueta del eje x
plt.ylabel('Área (km2)')  # Etiqueta del eje y
plt.grid(True)  # Muestra una cuadrícula en el gráfico
plt.show()  # Muestra el gráfico

# %%
# Conclusión: vamo a morir todos

# %% [markdown]
# ###🧊DATASET 3  **Change.csv**:
# - dataset resultante: **copy_clean_change_df**

# %%
# Vamos a limpiar el siguiente dataset, change.csv
change_df = pd.read_csv('/content/drive/MyDrive/DATASETS/change.csv')
change_df.head(15)
# Out:
#    POLITICAL_UNIT            NAME  WGMS_ID  SURVEY_ID  YEAR  SURVEY_DATE  \
# 0              AF  RGI60-13.10763   156232     808792  2004     20041231
# 1              AF  RGI60-13.10763   156232     808793  2019     20191231
# 2              AF  RGI60-13.10763   156232     808794  2009     20091231
# 3              AF  RGI60-13.10763   156232     808795  2014     20141231
# 4              AF  RGI60-13.10763   156232     808796  2019     20191231
# 5              AF  RGI60-13.10764   156233     808797  2004     20041231
# 6              AF  RGI60-13.10764   156233     808798  2019     20191231
# 7              AF  RGI60-13.10764   156233     808799  2009     20091231
# 8              AF  RGI60-13.10764   156233     808800  2014     20141231
# 9              AF  RGI60-13.10764   156233     808801  2019     20191231
# 10             AF  RGI60-13.10765   156234     808802  2004     20041231
# 11             AF  RGI60-13.10765   156234     808803  2019     20191231
# 12             AF  RGI60-13.10765   156234     808804  2009     20091231
# 13             AF  RGI60-13.10765   156234     808805  2014     20141231
# 14             AF  RGI60-13.10765   156234     808806  2019     20191231
#
#     REFERENCE_DATE  LOWER_BOUND  UPPER_BOUND  AREA_SURVEY_YEAR  ...  \
# 0       19991231.0         9999         9999             1.010  ...
# 1       19991231.0         9999         9999             1.010  ...
# 2       20041231.0         9999         9999             1.010  ...
# 3       20091231.0         9999         9999             1.010  ...
# 4       20141231.0         9999         9999             1.010  ...
# 5       19991231.0         9999         9999             0.061  ...
# 6       19991231.0         9999         9999             0.061  ...
# 7       20041231.0         9999         9999             0.061  ...
# 8       20091231.0         9999         9999             0.061  ...
# 9       20141231.0         9999         9999             0.061  ...
# 10      19991231.0         9999         9999             0.131  ...
# 11      19991231.0         9999         9999             0.131  ...
# 12      20041231.0         9999         9999             0.131  ...
# 13      20091231.0         9999         9999             0.131  ...
# 14      20141231.0         9999         9999             0.131  ...
#
#     THICKNESS_CHG  THICKNESS_CHG_UNC  VOLUME_CHANGE  VOLUME_CHANGE_UNC  \
# 0         -1535.0             3650.0        -1550.0             3690.0
# 1         -4420.0             3840.0        -4460.0             3880.0
# 2         -1265.0             3515.0        -1275.0             3550.0
# 3          -915.0             3620.0         -920.0             3660.0
# 4          -715.0             3620.0         -720.0             3660.0
# 5         -3920.0             7580.0         -235.0              465.0
# 6         -3780.0             8220.0         -220.0              500.0
# 7         -1805.0             6990.0         -110.0              425.0
# 8           360.0             7065.0           20.0              430.0
# 9          1575.0             7755.0           95.0              470.0
# 10         -100.0             5010.0          -10.0              655.0
# 11        -2300.0             5400.0         -300.0              700.0
# 12         -350.0             4675.0          -45.0              610.0
# 13         -615.0             4690.0          -80.0              615.0
# 14        -1240.0             5050.0         -160.0              660.0
#
#     SD_PLATFORM_METHOD  RD_PLATFORM_METHOD     INVESTIGATOR  \
# 0                   sP                  sP  Romain Hugonnet
# 1                   sP                  sP  Romain Hugonnet
# 2                   sP                  sP  Romain Hugonnet
# 3                   sP                  sP  Romain Hugonnet
# 4                   sP                  sP  Romain Hugonnet
# 5                   sP                  sP  Romain Hugonnet
# 6                   sP                  sP  Romain Hugonnet
# 7                   sP                  sP  Romain Hugonnet
# 8                   sP                  sP  Romain Hugonnet
# 9                   sP                  sP  Romain Hugonnet
# 10                  sP                  sP  Romain Hugonnet
# 11                  sP                  sP  Romain Hugonnet
# 12                  sP                  sP  Romain Hugonnet
# 13                  sP                  sP  Romain Hugonnet
# 14                  sP                  sP  Romain Hugonnet
#
#                                          SPONS_AGENCY  \
# 0   LEGOS, Université Toulouse, France; VAW, ETH Z...
# 1   LEGOS, Université Toulouse, France; VAW, ETH Z...
# 2   LEGOS, Université Toulouse, France; VAW, ETH Z...
# 3   LEGOS, Université Toulouse, France; VAW, ETH Z...
# 4   LEGOS, Université Toulouse, France; VAW, ETH Z...
# 5   LEGOS, Université Toulouse, France; VAW, ETH Z...
# 6   LEGOS, Université Toulouse, France; VAW, ETH Z...
# 7   LEGOS, Université Toulouse, France; VAW, ETH Z...
# 8   LEGOS, Université Toulouse, France; VAW, ETH Z...
# 9   LEGOS, Université Toulouse, France; VAW, ETH Z...
# 10  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 11  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 12  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 13  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 14  LEGOS, Université Toulouse, France; VAW, ETH Z...
#
#                                           REFERENCE  \
# 0   Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 1   Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 2   Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 3   Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 4   Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 5   Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 6   Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 7   Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 8   Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 9   Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 10  Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 11  Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 12  Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 13  Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 14  Hugonnet et al. (2021); Nature, 592, 726-731 p.
#
#                                               REMARKS
# 0   Only glaciers with >50% spatial coverage are i...
# 1   Only glaciers with >50% spatial coverage are i...
# 2   Only glaciers with >50% spatial coverage are i...
# 3   Only glaciers with >50% spatial coverage are i...
# 4   Only glaciers with >50% spatial coverage are i...
# 5   Only glaciers with >50% spatial coverage are i...
# 6   Only glaciers with >50% spatial coverage are i...
# 7   Only glaciers with >50% spatial coverage are i...
# 8   Only glaciers with >50% spatial coverage are i...
# 9   Only glaciers with >50% spatial coverage are i...
# 10  Only glaciers with >50% spatial coverage are i...
# 11  Only glaciers with >50% spatial coverage are i...
# 12  Only glaciers with >50% spatial coverage are i...
# 13  Only glaciers with >50% spatial coverage are i...
# 14  Only glaciers with >50% spatial coverage are i...
#
# [15 rows x 22 columns]

# %%
change_df.tail(15)
# Out:
#         POLITICAL_UNIT            NAME  WGMS_ID  SURVEY_ID  YEAR  SURVEY_DATE  \
# 1143287             VE  RGI60-16.01389    69770     254892  2009     20091231
# 1143288             VE  RGI60-16.01389    69770     254893  2014     20141231
# 1143289             VE  RGI60-16.01389    69770     254894  2019     20191231
# 1143290             VE   UNNAMED 26918    26918      90731  2012     20120201
# 1143291             VE   UNNAMED 26918    26918     254895  2004     20041231
# 1143292             VE   UNNAMED 26918    26918     254896  2019     20191231
# 1143293             VE   UNNAMED 26918    26918     254897  2009     20091231
# 1143294             VE   UNNAMED 26918    26918     254898  2014     20141231
# 1143295             VE   UNNAMED 26918    26918     254899  2019     20191231
# 1143296             VE   UNNAMED 26919    26919      90732  2012     20120201
# 1143297             VE   UNNAMED 26919    26919     254900  2004     20041231
# 1143298             VE   UNNAMED 26919    26919     254901  2019     20191231
# 1143299             VE   UNNAMED 26919    26919     254902  2009     20091231
# 1143300             VE   UNNAMED 26919    26919     254903  2014     20141231
# 1143301             VE   UNNAMED 26919    26919     254904  2019     20191231
#
#          REFERENCE_DATE  LOWER_BOUND  UPPER_BOUND  AREA_SURVEY_YEAR  ...  \
# 1143287      20041231.0         9999         9999             0.095  ...
# 1143288      20091231.0         9999         9999             0.095  ...
# 1143289      20141231.0         9999         9999             0.095  ...
# 1143290      20000216.0         9999         9999             0.186  ...
# 1143291      19991231.0         9999         9999             0.186  ...
# 1143292      19991231.0         9999         9999             0.186  ...
# 1143293      20041231.0         9999         9999             0.186  ...
# 1143294      20091231.0         9999         9999             0.186  ...
# 1143295      20141231.0         9999         9999             0.186  ...
# 1143296      20000216.0         9999         9999             0.456  ...
# 1143297      19991231.0         9999         9999             0.456  ...
# 1143298      19991231.0         9999         9999             0.456  ...
# 1143299      20041231.0         9999         9999             0.456  ...
# 1143300      20091231.0         9999         9999             0.456  ...
# 1143301      20141231.0         9999         9999             0.456  ...
#
#          THICKNESS_CHG  THICKNESS_CHG_UNC  VOLUME_CHANGE  VOLUME_CHANGE_UNC  \
# 1143287          115.0             8580.0           10.0              815.0
# 1143288        -2770.0             9340.0         -260.0              890.0
# 1143289        -5175.0            10990.0         -490.0             1055.0
# 1143290        -1459.0             5531.0         -271.0             1029.0
# 1143291        -6690.0             5420.0        -1240.0             1060.0
# 1143292        -8780.0             6440.0        -1620.0             1280.0
# 1143293        -3180.0             5295.0         -590.0              995.0
# 1143294        -1180.0             5580.0         -215.0             1035.0
# 1143295         2275.0             6510.0          420.0             1215.0
# 1143296        -8443.0             2435.0        -3850.0             1110.0
# 1143297       -10310.0             4255.0        -4700.0             2260.0
# 1143298       -20860.0             4920.0        -9500.0             3240.0
# 1143299        -6475.0             4300.0        -2950.0             2090.0
# 1143300        -4580.0             4480.0        -2090.0             2105.0
# 1143301          510.0             5025.0          230.0             2290.0
#
#          SD_PLATFORM_METHOD  RD_PLATFORM_METHOD      INVESTIGATOR  \
# 1143287                  sP                  sP   Romain Hugonnet
# 1143288                  sP                  sP   Romain Hugonnet
# 1143289                  sP                  sP   Romain Hugonnet
# 1143290                  sZ                  sZ  Thorsten Seehaus
# 1143291                  sP                  sP   Romain Hugonnet
# 1143292                  sP                  sP   Romain Hugonnet
# 1143293                  sP                  sP   Romain Hugonnet
# 1143294                  sP                  sP   Romain Hugonnet
# 1143295                  sP                  sP   Romain Hugonnet
# 1143296                  sZ                  sZ  Thorsten Seehaus
# 1143297                  sP                  sP   Romain Hugonnet
# 1143298                  sP                  sP   Romain Hugonnet
# 1143299                  sP                  sP   Romain Hugonnet
# 1143300                  sP                  sP   Romain Hugonnet
# 1143301                  sP                  sP   Romain Hugonnet
#
#                                               SPONS_AGENCY  \
# 1143287  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 1143288  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 1143289  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 1143290  German Reseach Foundation, DFG, Grant BR2105/1...
# 1143291  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 1143292  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 1143293  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 1143294  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 1143295  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 1143296  German Reseach Foundation, DFG, Grant BR2105/1...
# 1143297  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 1143298  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 1143299  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 1143300  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 1143301  LEGOS, Université Toulouse, France; VAW, ETH Z...
#
#                                                  REFERENCE  \
# 1143287    Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 1143288    Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 1143289    Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 1143290  Braun et al. 2019; Nature Climate Change 9,130...
# 1143291    Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 1143292    Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 1143293    Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 1143294    Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 1143295    Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 1143296  Braun et al. 2019; Nature Climate Change 9,130...
# 1143297    Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 1143298    Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 1143299    Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 1143300    Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 1143301    Hugonnet et al. (2021); Nature, 592, 726-731 p.
#
#                                                    REMARKS
# 1143287  Only glaciers with >50% spatial coverage are i...
# 1143288  Only glaciers with >50% spatial coverage are i...
# 1143289  Only glaciers with >50% spatial coverage are i...
# 1143290  Glacier outlines and area from RGI6.0, surface...
# 1143291  Only glaciers with >50% spatial coverage are i...
# 1143292  Only glaciers with >50% spatial coverage are i...
# 1143293  Only glaciers with >50% spatial coverage are i...
# 1143294  Only glaciers with >50% spatial coverage are i...
# 1143295  Only glaciers with >50% spatial coverage are i...
# 1143296  Glacier outlines and area from RGI6.0, surface...
# 1143297  Only glaciers with >50% spatial coverage are i...
# 1143298  Only glaciers with >50% spatial coverage are i...
# 1143299  Only glaciers with >50% spatial coverage are i...
# 1143300  Only glaciers with >50% spatial coverage are i...
# 1143301  Only glaciers with >50% spatial coverage are i...
#
# [15 rows x 22 columns]

# %%
change_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143302 entries, 0 to 1143301
# Data columns (total 22 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   POLITICAL_UNIT      1143302 non-null  object
#  1   NAME                1143302 non-null  object
#  2   WGMS_ID             1143302 non-null  int64
#  3   SURVEY_ID           1143302 non-null  int64
#  4   YEAR                1143302 non-null  int64
#  5   SURVEY_DATE         1143302 non-null  int64
#  6   REFERENCE_DATE      1142799 non-null  float64
#  7   LOWER_BOUND         1143302 non-null  int64
#  8   UPPER_BOUND         1143302 non-null  int64
#  9   AREA_SURVEY_YEAR    1140570 non-null  float64
#  10  AREA_CHANGE         6567 non-null     float64
#  11  AREA_CHANGE_UNC     1713 non-null     float64
#  12  THICKNESS_CHG       1141074 non-null  float64
#  13  THICKNESS_CHG_UNC   1133804 non-null  float64
#  14  VOLUME_CHANGE       1040926 non-null  float64
#  15  VOLUME_CHANGE_UNC   1036571 non-null  float64
#  16  SD_PLATFORM_METHOD  1139945 non-null  object
#  17  RD_PLATFORM_METHOD  1137971 non-null  object
#  18  INVESTIGATOR        1135487 non-null  object
#  19  SPONS_AGENCY        1135339 non-null  object
#  20  REFERENCE           1141575 non-null  object
#  21  REMARKS             1135952 non-null  object
# dtypes: float64(8), int64(6), object(8)
# memory usage: 191.9+ MB

# %%
change_df.count()
# Out:
# POLITICAL_UNIT        1143302
# NAME                  1143302
# WGMS_ID               1143302
# SURVEY_ID             1143302
# YEAR                  1143302
# SURVEY_DATE           1143302
# REFERENCE_DATE        1142799
# LOWER_BOUND           1143302
# UPPER_BOUND           1143302
# AREA_SURVEY_YEAR      1140570
# AREA_CHANGE              6567
# AREA_CHANGE_UNC          1713
# THICKNESS_CHG         1141074
# THICKNESS_CHG_UNC     1133804
# VOLUME_CHANGE         1040926
# VOLUME_CHANGE_UNC     1036571
# SD_PLATFORM_METHOD    1139945
# RD_PLATFORM_METHOD    1137971
# INVESTIGATOR          1135487
# SPONS_AGENCY          1135339
# REFERENCE             1141575
# REMARKS               1135952
# dtype: int64

# %%
change_df.isna().sum()
# Out:
# POLITICAL_UNIT              0
# NAME                        0
# WGMS_ID                     0
# SURVEY_ID                   0
# YEAR                        0
# SURVEY_DATE                 0
# REFERENCE_DATE            503
# LOWER_BOUND                 0
# UPPER_BOUND                 0
# AREA_SURVEY_YEAR         2732
# AREA_CHANGE           1136735
# AREA_CHANGE_UNC       1141589
# THICKNESS_CHG            2228
# THICKNESS_CHG_UNC        9498
# VOLUME_CHANGE          102376
# VOLUME_CHANGE_UNC      106731
# SD_PLATFORM_METHOD       3357
# RD_PLATFORM_METHOD       5331
# INVESTIGATOR             7815
# SPONS_AGENCY             7963
# REFERENCE                1727
# REMARKS                  7350
# dtype: int64

# %%
change_df['LOWER_BOUND'].replace(9999, np.nan, inplace=True)
change_df['UPPER_BOUND'].replace(9999, np.nan, inplace=True)

# %%
change_df.head(15)
# Out:
#    POLITICAL_UNIT            NAME  WGMS_ID  SURVEY_ID  YEAR  SURVEY_DATE  \
# 0              AF  RGI60-13.10763   156232     808792  2004     20041231
# 1              AF  RGI60-13.10763   156232     808793  2019     20191231
# 2              AF  RGI60-13.10763   156232     808794  2009     20091231
# 3              AF  RGI60-13.10763   156232     808795  2014     20141231
# 4              AF  RGI60-13.10763   156232     808796  2019     20191231
# 5              AF  RGI60-13.10764   156233     808797  2004     20041231
# 6              AF  RGI60-13.10764   156233     808798  2019     20191231
# 7              AF  RGI60-13.10764   156233     808799  2009     20091231
# 8              AF  RGI60-13.10764   156233     808800  2014     20141231
# 9              AF  RGI60-13.10764   156233     808801  2019     20191231
# 10             AF  RGI60-13.10765   156234     808802  2004     20041231
# 11             AF  RGI60-13.10765   156234     808803  2019     20191231
# 12             AF  RGI60-13.10765   156234     808804  2009     20091231
# 13             AF  RGI60-13.10765   156234     808805  2014     20141231
# 14             AF  RGI60-13.10765   156234     808806  2019     20191231
#
#     REFERENCE_DATE  LOWER_BOUND  UPPER_BOUND  AREA_SURVEY_YEAR  ...  \
# 0       19991231.0          NaN          NaN             1.010  ...
# 1       19991231.0          NaN          NaN             1.010  ...
# 2       20041231.0          NaN          NaN             1.010  ...
# 3       20091231.0          NaN          NaN             1.010  ...
# 4       20141231.0          NaN          NaN             1.010  ...
# 5       19991231.0          NaN          NaN             0.061  ...
# 6       19991231.0          NaN          NaN             0.061  ...
# 7       20041231.0          NaN          NaN             0.061  ...
# 8       20091231.0          NaN          NaN             0.061  ...
# 9       20141231.0          NaN          NaN             0.061  ...
# 10      19991231.0          NaN          NaN             0.131  ...
# 11      19991231.0          NaN          NaN             0.131  ...
# 12      20041231.0          NaN          NaN             0.131  ...
# 13      20091231.0          NaN          NaN             0.131  ...
# 14      20141231.0          NaN          NaN             0.131  ...
#
#     THICKNESS_CHG  THICKNESS_CHG_UNC  VOLUME_CHANGE  VOLUME_CHANGE_UNC  \
# 0         -1535.0             3650.0        -1550.0             3690.0
# 1         -4420.0             3840.0        -4460.0             3880.0
# 2         -1265.0             3515.0        -1275.0             3550.0
# 3          -915.0             3620.0         -920.0             3660.0
# 4          -715.0             3620.0         -720.0             3660.0
# 5         -3920.0             7580.0         -235.0              465.0
# 6         -3780.0             8220.0         -220.0              500.0
# 7         -1805.0             6990.0         -110.0              425.0
# 8           360.0             7065.0           20.0              430.0
# 9          1575.0             7755.0           95.0              470.0
# 10         -100.0             5010.0          -10.0              655.0
# 11        -2300.0             5400.0         -300.0              700.0
# 12         -350.0             4675.0          -45.0              610.0
# 13         -615.0             4690.0          -80.0              615.0
# 14        -1240.0             5050.0         -160.0              660.0
#
#     SD_PLATFORM_METHOD  RD_PLATFORM_METHOD     INVESTIGATOR  \
# 0                   sP                  sP  Romain Hugonnet
# 1                   sP                  sP  Romain Hugonnet
# 2                   sP                  sP  Romain Hugonnet
# 3                   sP                  sP  Romain Hugonnet
# 4                   sP                  sP  Romain Hugonnet
# 5                   sP                  sP  Romain Hugonnet
# 6                   sP                  sP  Romain Hugonnet
# 7                   sP                  sP  Romain Hugonnet
# 8                   sP                  sP  Romain Hugonnet
# 9                   sP                  sP  Romain Hugonnet
# 10                  sP                  sP  Romain Hugonnet
# 11                  sP                  sP  Romain Hugonnet
# 12                  sP                  sP  Romain Hugonnet
# 13                  sP                  sP  Romain Hugonnet
# 14                  sP                  sP  Romain Hugonnet
#
#                                          SPONS_AGENCY  \
# 0   LEGOS, Université Toulouse, France; VAW, ETH Z...
# 1   LEGOS, Université Toulouse, France; VAW, ETH Z...
# 2   LEGOS, Université Toulouse, France; VAW, ETH Z...
# 3   LEGOS, Université Toulouse, France; VAW, ETH Z...
# 4   LEGOS, Université Toulouse, France; VAW, ETH Z...
# 5   LEGOS, Université Toulouse, France; VAW, ETH Z...
# 6   LEGOS, Université Toulouse, France; VAW, ETH Z...
# 7   LEGOS, Université Toulouse, France; VAW, ETH Z...
# 8   LEGOS, Université Toulouse, France; VAW, ETH Z...
# 9   LEGOS, Université Toulouse, France; VAW, ETH Z...
# 10  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 11  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 12  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 13  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 14  LEGOS, Université Toulouse, France; VAW, ETH Z...
#
#                                           REFERENCE  \
# 0   Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 1   Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 2   Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 3   Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 4   Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 5   Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 6   Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 7   Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 8   Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 9   Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 10  Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 11  Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 12  Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 13  Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 14  Hugonnet et al. (2021); Nature, 592, 726-731 p.
#
#                                               REMARKS
# 0   Only glaciers with >50% spatial coverage are i...
# 1   Only glaciers with >50% spatial coverage are i...
# 2   Only glaciers with >50% spatial coverage are i...
# 3   Only glaciers with >50% spatial coverage are i...
# 4   Only glaciers with >50% spatial coverage are i...
# 5   Only glaciers with >50% spatial coverage are i...
# 6   Only glaciers with >50% spatial coverage are i...
# 7   Only glaciers with >50% spatial coverage are i...
# 8   Only glaciers with >50% spatial coverage are i...
# 9   Only glaciers with >50% spatial coverage are i...
# 10  Only glaciers with >50% spatial coverage are i...
# 11  Only glaciers with >50% spatial coverage are i...
# 12  Only glaciers with >50% spatial coverage are i...
# 13  Only glaciers with >50% spatial coverage are i...
# 14  Only glaciers with >50% spatial coverage are i...
#
# [15 rows x 22 columns]

# %%
change_df.tail(15)
# Out:
#         POLITICAL_UNIT            NAME  WGMS_ID  SURVEY_ID  YEAR  SURVEY_DATE  \
# 1143287             VE  RGI60-16.01389    69770     254892  2009     20091231
# 1143288             VE  RGI60-16.01389    69770     254893  2014     20141231
# 1143289             VE  RGI60-16.01389    69770     254894  2019     20191231
# 1143290             VE   UNNAMED 26918    26918      90731  2012     20120201
# 1143291             VE   UNNAMED 26918    26918     254895  2004     20041231
# 1143292             VE   UNNAMED 26918    26918     254896  2019     20191231
# 1143293             VE   UNNAMED 26918    26918     254897  2009     20091231
# 1143294             VE   UNNAMED 26918    26918     254898  2014     20141231
# 1143295             VE   UNNAMED 26918    26918     254899  2019     20191231
# 1143296             VE   UNNAMED 26919    26919      90732  2012     20120201
# 1143297             VE   UNNAMED 26919    26919     254900  2004     20041231
# 1143298             VE   UNNAMED 26919    26919     254901  2019     20191231
# 1143299             VE   UNNAMED 26919    26919     254902  2009     20091231
# 1143300             VE   UNNAMED 26919    26919     254903  2014     20141231
# 1143301             VE   UNNAMED 26919    26919     254904  2019     20191231
#
#          REFERENCE_DATE  LOWER_BOUND  UPPER_BOUND  AREA_SURVEY_YEAR  ...  \
# 1143287      20041231.0          NaN          NaN             0.095  ...
# 1143288      20091231.0          NaN          NaN             0.095  ...
# 1143289      20141231.0          NaN          NaN             0.095  ...
# 1143290      20000216.0          NaN          NaN             0.186  ...
# 1143291      19991231.0          NaN          NaN             0.186  ...
# 1143292      19991231.0          NaN          NaN             0.186  ...
# 1143293      20041231.0          NaN          NaN             0.186  ...
# 1143294      20091231.0          NaN          NaN             0.186  ...
# 1143295      20141231.0          NaN          NaN             0.186  ...
# 1143296      20000216.0          NaN          NaN             0.456  ...
# 1143297      19991231.0          NaN          NaN             0.456  ...
# 1143298      19991231.0          NaN          NaN             0.456  ...
# 1143299      20041231.0          NaN          NaN             0.456  ...
# 1143300      20091231.0          NaN          NaN             0.456  ...
# 1143301      20141231.0          NaN          NaN             0.456  ...
#
#          THICKNESS_CHG  THICKNESS_CHG_UNC  VOLUME_CHANGE  VOLUME_CHANGE_UNC  \
# 1143287          115.0             8580.0           10.0              815.0
# 1143288        -2770.0             9340.0         -260.0              890.0
# 1143289        -5175.0            10990.0         -490.0             1055.0
# 1143290        -1459.0             5531.0         -271.0             1029.0
# 1143291        -6690.0             5420.0        -1240.0             1060.0
# 1143292        -8780.0             6440.0        -1620.0             1280.0
# 1143293        -3180.0             5295.0         -590.0              995.0
# 1143294        -1180.0             5580.0         -215.0             1035.0
# 1143295         2275.0             6510.0          420.0             1215.0
# 1143296        -8443.0             2435.0        -3850.0             1110.0
# 1143297       -10310.0             4255.0        -4700.0             2260.0
# 1143298       -20860.0             4920.0        -9500.0             3240.0
# 1143299        -6475.0             4300.0        -2950.0             2090.0
# 1143300        -4580.0             4480.0        -2090.0             2105.0
# 1143301          510.0             5025.0          230.0             2290.0
#
#          SD_PLATFORM_METHOD  RD_PLATFORM_METHOD      INVESTIGATOR  \
# 1143287                  sP                  sP   Romain Hugonnet
# 1143288                  sP                  sP   Romain Hugonnet
# 1143289                  sP                  sP   Romain Hugonnet
# 1143290                  sZ                  sZ  Thorsten Seehaus
# 1143291                  sP                  sP   Romain Hugonnet
# 1143292                  sP                  sP   Romain Hugonnet
# 1143293                  sP                  sP   Romain Hugonnet
# 1143294                  sP                  sP   Romain Hugonnet
# 1143295                  sP                  sP   Romain Hugonnet
# 1143296                  sZ                  sZ  Thorsten Seehaus
# 1143297                  sP                  sP   Romain Hugonnet
# 1143298                  sP                  sP   Romain Hugonnet
# 1143299                  sP                  sP   Romain Hugonnet
# 1143300                  sP                  sP   Romain Hugonnet
# 1143301                  sP                  sP   Romain Hugonnet
#
#                                               SPONS_AGENCY  \
# 1143287  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 1143288  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 1143289  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 1143290  German Reseach Foundation, DFG, Grant BR2105/1...
# 1143291  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 1143292  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 1143293  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 1143294  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 1143295  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 1143296  German Reseach Foundation, DFG, Grant BR2105/1...
# 1143297  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 1143298  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 1143299  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 1143300  LEGOS, Université Toulouse, France; VAW, ETH Z...
# 1143301  LEGOS, Université Toulouse, France; VAW, ETH Z...
#
#                                                  REFERENCE  \
# 1143287    Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 1143288    Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 1143289    Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 1143290  Braun et al. 2019; Nature Climate Change 9,130...
# 1143291    Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 1143292    Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 1143293    Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 1143294    Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 1143295    Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 1143296  Braun et al. 2019; Nature Climate Change 9,130...
# 1143297    Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 1143298    Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 1143299    Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 1143300    Hugonnet et al. (2021); Nature, 592, 726-731 p.
# 1143301    Hugonnet et al. (2021); Nature, 592, 726-731 p.
#
#                                                    REMARKS
# 1143287  Only glaciers with >50% spatial coverage are i...
# 1143288  Only glaciers with >50% spatial coverage are i...
# 1143289  Only glaciers with >50% spatial coverage are i...
# 1143290  Glacier outlines and area from RGI6.0, surface...
# 1143291  Only glaciers with >50% spatial coverage are i...
# 1143292  Only glaciers with >50% spatial coverage are i...
# 1143293  Only glaciers with >50% spatial coverage are i...
# 1143294  Only glaciers with >50% spatial coverage are i...
# 1143295  Only glaciers with >50% spatial coverage are i...
# 1143296  Glacier outlines and area from RGI6.0, surface...
# 1143297  Only glaciers with >50% spatial coverage are i...
# 1143298  Only glaciers with >50% spatial coverage are i...
# 1143299  Only glaciers with >50% spatial coverage are i...
# 1143300  Only glaciers with >50% spatial coverage are i...
# 1143301  Only glaciers with >50% spatial coverage are i...
#
# [15 rows x 22 columns]

# %%
change_df['AREA_CHANGE'].isna().sum()
# Out:
# 1136735

# %%
list(change_df.columns)
# Out:
# ['POLITICAL_UNIT',
#  'NAME',
#  'WGMS_ID',
#  'SURVEY_ID',
#  'YEAR',
#  'SURVEY_DATE',
#  'REFERENCE_DATE',
#  'LOWER_BOUND',
#  'UPPER_BOUND',
#  'AREA_SURVEY_YEAR',
#  'AREA_CHANGE',
#  'AREA_CHANGE_UNC',
#  'THICKNESS_CHG',
#  'THICKNESS_CHG_UNC',
#  'VOLUME_CHANGE',
#  'VOLUME_CHANGE_UNC',
#  'SD_PLATFORM_METHOD',
#  'RD_PLATFORM_METHOD',
#  'INVESTIGATOR',
#  'SPONS_AGENCY',
#  'REFERENCE',
#  'REMARKS']

# %%
# Revisando nos quedaremos con las siguientes columnas del data set:
# Lista de columnas a mantener en el nuevo DataFrame
columns_change = ['POLITICAL_UNIT',
 'NAME',
 'WGMS_ID',
 'YEAR',
 'AREA_CHANGE',
 'THICKNESS_CHG',
 'VOLUME_CHANGE']

# Crear un nuevo DataFrame para almacenar las columnas seleccionadas
clean_change_df = pd.DataFrame()

# Iterar sobre cada columna en la lista de columnas
for column in columns_change:
    # Si la columna es 'YEAR' o 'SURVEY_DATE', añadir el prefijo 'state_'
    #if column == 'YEAR' or column == 'SURVEY_DATE':
        #new_change[f'change_{column}'] = change[column]
    #else:
   clean_change_df[column] = change_df[column]

# %%
# revisamos:
clean_change_df.head(15)
# Out:
#    POLITICAL_UNIT            NAME  WGMS_ID  YEAR  AREA_CHANGE  THICKNESS_CHG  \
# 0              AF  RGI60-13.10763   156232  2004          NaN        -1535.0
# 1              AF  RGI60-13.10763   156232  2019          NaN        -4420.0
# 2              AF  RGI60-13.10763   156232  2009          NaN        -1265.0
# 3              AF  RGI60-13.10763   156232  2014          NaN         -915.0
# 4              AF  RGI60-13.10763   156232  2019          NaN         -715.0
# 5              AF  RGI60-13.10764   156233  2004          NaN        -3920.0
# 6              AF  RGI60-13.10764   156233  2019          NaN        -3780.0
# 7              AF  RGI60-13.10764   156233  2009          NaN        -1805.0
# 8              AF  RGI60-13.10764   156233  2014          NaN          360.0
# 9              AF  RGI60-13.10764   156233  2019          NaN         1575.0
# 10             AF  RGI60-13.10765   156234  2004          NaN         -100.0
# 11             AF  RGI60-13.10765   156234  2019          NaN        -2300.0
# 12             AF  RGI60-13.10765   156234  2009          NaN         -350.0
# 13             AF  RGI60-13.10765   156234  2014          NaN         -615.0
# 14             AF  RGI60-13.10765   156234  2019          NaN        -1240.0
#
#     VOLUME_CHANGE
# 0         -1550.0
# 1         -4460.0
# 2         -1275.0
# 3          -920.0
# 4          -720.0
# 5          -235.0
# 6          -220.0
# 7          -110.0
# 8            20.0
# 9            95.0
# 10          -10.0
# 11         -300.0
# 12          -45.0
# 13          -80.0
# 14         -160.0

# %%
clean_change_df.tail(15)
# Out:
#         POLITICAL_UNIT            NAME  WGMS_ID  YEAR  AREA_CHANGE  \
# 1143287             VE  RGI60-16.01389    69770  2009          NaN
# 1143288             VE  RGI60-16.01389    69770  2014          NaN
# 1143289             VE  RGI60-16.01389    69770  2019          NaN
# 1143290             VE   UNNAMED 26918    26918  2012          NaN
# 1143291             VE   UNNAMED 26918    26918  2004          NaN
# 1143292             VE   UNNAMED 26918    26918  2019          NaN
# 1143293             VE   UNNAMED 26918    26918  2009          NaN
# 1143294             VE   UNNAMED 26918    26918  2014          NaN
# 1143295             VE   UNNAMED 26918    26918  2019          NaN
# 1143296             VE   UNNAMED 26919    26919  2012          NaN
# 1143297             VE   UNNAMED 26919    26919  2004          NaN
# 1143298             VE   UNNAMED 26919    26919  2019          NaN
# 1143299             VE   UNNAMED 26919    26919  2009          NaN
# 1143300             VE   UNNAMED 26919    26919  2014          NaN
# 1143301             VE   UNNAMED 26919    26919  2019          NaN
#
#          THICKNESS_CHG  VOLUME_CHANGE
# 1143287          115.0           10.0
# 1143288        -2770.0         -260.0
# 1143289        -5175.0         -490.0
# 1143290        -1459.0         -271.0
# 1143291        -6690.0        -1240.0
# 1143292        -8780.0        -1620.0
# 1143293        -3180.0         -590.0
# 1143294        -1180.0         -215.0
# 1143295         2275.0          420.0
# 1143296        -8443.0        -3850.0
# 1143297       -10310.0        -4700.0
# 1143298       -20860.0        -9500.0
# 1143299        -6475.0        -2950.0
# 1143300        -4580.0        -2090.0
# 1143301          510.0          230.0

# %%
change_df['NAME'].value_counts()
# Out:
# NAME
# HINTEREIS F.       507
# SLADDEN            436
# TS.TUYUKSUYSKIY    417
# UNNAMED 21821      412
# UNNAMED 21926      372
#                   ...
# UNNAMED 28253        1
# UNNAMED 28252        1
# UNNAMED 28251        1
# UNNAMED 28250        1
# UNNAMED 16355        1
# Name: count, Length: 210216, dtype: int64

# %%
copy_clean_change_df = []
copy_clean_change_df = clean_change_df[clean_change_df['NAME'] == 'UNNAMED 21821']
plt.figure(figsize = (8,10))
plt.plot(copy_clean_change_df['YEAR'], copy_clean_change_df['VOLUME_CHANGE'], marker = 'o', linestyle='-')
plt.title('Cambio en grosor del hielo del Glaciar UNNAMED 21821 en función del Año')  # Establece el título del gráfico
plt.xlabel('Año')  # Etiqueta del eje x
plt.ylabel('Cambio (mm)')  # Etiqueta del eje y
plt.grid(True)  # Muestra una cuadrícula en el gráfico
plt.show()  # Muestra el gráfico

# %%
copy_clean_change_df
# Out:
#        POLITICAL_UNIT           NAME  WGMS_ID  YEAR  AREA_CHANGE  \
# 843279             NZ  UNNAMED 21821    21821  2012          NaN
# 843280             NZ  UNNAMED 21821    21821  2015          NaN
# 843281             NZ  UNNAMED 21821    21821  2017          NaN
# 843282             NZ  UNNAMED 21821    21821  2018          NaN
# 843283             NZ  UNNAMED 21821    21821  2015          NaN
# ...               ...            ...      ...   ...          ...
# 843686             NZ  UNNAMED 21821    21821  2004          NaN
# 843687             NZ  UNNAMED 21821    21821  2019          NaN
# 843688             NZ  UNNAMED 21821    21821  2009          NaN
# 843689             NZ  UNNAMED 21821    21821  2014          NaN
# 843690             NZ  UNNAMED 21821    21821  2019          NaN
#
#         THICKNESS_CHG  VOLUME_CHANGE
# 843279        -8597.0            NaN
# 843280        -9895.0            NaN
# 843281       -13803.0            NaN
# 843282        -7734.0            NaN
# 843283       -12573.0            NaN
# ...               ...            ...
# 843686        -1365.0        -2800.0
# 843687       -14780.0       -30320.0
# 843688        -3580.0        -7345.0
# 843689        -3620.0        -7425.0
# 843690        -6215.0       -12745.0
#
# [412 rows x 7 columns]

# %%
mean_by_year = copy_clean_change_df.groupby('YEAR')['THICKNESS_CHG'].mean()
print(mean_by_year)
# Out:
# YEAR
# 2004    -1365.000000
# 2009    -3580.000000
# 2010   -20169.500000
# 2011   -16155.250000
# 2012   -14222.411765
# 2013   -13737.629630
# 2014   -12234.857143
# 2015   -12774.747253
# 2016   -13423.360825
# 2017   -13749.898148
# 2018   -18999.000000
# 2019   -10497.500000
# Name: THICKNESS_CHG, dtype: float64

# %%
plt.figure(figsize = (8,10))
plt.plot(mean_by_year, marker = 'o', linestyle='-')
plt.title('Cambio en grosor del hielo del Glaciar UNNAMED 21821 en función del Año')  # Establece el título del gráfico
plt.xlabel('Año')  # Etiqueta del eje x
plt.ylabel('Cambio (mm)')  # Etiqueta del eje y
plt.grid(True)  # Muestra una cuadrícula en el gráfico
plt.show()  # Muestra el gráfico

# %%
clean_change_df['NAME'].value_counts()
# Out:
# NAME
# HINTEREIS F.       507
# SLADDEN            436
# TS.TUYUKSUYSKIY    417
# UNNAMED 21821      412
# UNNAMED 21926      372
#                   ...
# UNNAMED 28253        1
# UNNAMED 28252        1
# UNNAMED 28251        1
# UNNAMED 28250        1
# UNNAMED 16355        1
# Name: count, Length: 210216, dtype: int64

# %%
copy_2_clean_change_df_state = clean_change_df[clean_change_df['NAME'] == 'VERNAGT F.']
plt.figure(figsize = (8,10))
plt.plot(copy_2_clean_change_df_state['YEAR'], copy_2_clean_change_df_state['VOLUME_CHANGE'], marker = 'o', linestyle='-')
plt.title('Área del Glaciar VERNAGT F. en función del Año')  # Establece el título del gráfico
plt.xlabel('Año')  # Etiqueta del eje x
plt.ylabel('Área (km2)')  # Etiqueta del eje y
plt.grid(True)  # Muestra una cuadrícula en el gráfico
plt.show()  # Muestra el gráfico

# %% [markdown]
# ###🧊DATASET 4  **Mass_balance.csv**:
# - dataset resultante: **mass_balance_df**

# %%
mass_balance_df = pd.read_csv('/content/drive/MyDrive/DATASETS/mass_balance.csv')
mass_balance_df.head(15)
# Out:
#    POLITICAL_UNIT              NAME  WGMS_ID  YEAR  LOWER_BOUND  UPPER_BOUND  \
# 0              AQ          ALBERICH     1062  1972         9999         9999
# 1              AQ          ALBERICH     1062  1973         9999         9999
# 2              AQ          ALBERICH     1062  1974         9999         9999
# 3              AQ          ALBERICH     1062  1975         9999         9999
# 4              AQ  ANVERS I ICE CAP     3954  1966         9999         9999
# 5              AQ  ANVERS I ICE CAP     3954  1967         9999         9999
# 6              AQ  BAHIA DEL DIABLO     2665  2000           38          112
# 7              AQ  BAHIA DEL DIABLO     2665  2000          112          188
# 8              AQ  BAHIA DEL DIABLO     2665  2000          188          262
# 9              AQ  BAHIA DEL DIABLO     2665  2000          262          338
# 10             AQ  BAHIA DEL DIABLO     2665  2000          338          412
# 11             AQ  BAHIA DEL DIABLO     2665  2000          412          488
# 12             AQ  BAHIA DEL DIABLO     2665  2000          488          562
# 13             AQ  BAHIA DEL DIABLO     2665  2000          562          638
# 14             AQ  BAHIA DEL DIABLO     2665  2000         9999         9999
#
#      AREA  WINTER_BALANCE  WINTER_BALANCE_UNC  SUMMER_BALANCE  \
# 0    1.36             0.0                 NaN            10.0
# 1    1.36             0.0                 NaN            30.0
# 2    1.36           -10.0                 NaN             0.0
# 3    1.36            10.0                 NaN             0.0
# 4     NaN             NaN                 NaN             NaN
# 5     NaN             NaN                 NaN             NaN
# 6     NaN             NaN                 NaN             NaN
# 7     NaN             NaN                 NaN             NaN
# 8     NaN             NaN                 NaN             NaN
# 9     NaN             NaN                 NaN             NaN
# 10    NaN             NaN                 NaN             NaN
# 11    NaN             NaN                 NaN             NaN
# 12    NaN             NaN                 NaN             NaN
# 13    NaN             NaN                 NaN             NaN
# 14  12.90             NaN                 NaN             NaN
#
#     SUMMER_BALANCE_UNC  ANNUAL_BALANCE  ANNUAL_BALANCE_UNC  \
# 0                  NaN            20.0                 NaN
# 1                  NaN            30.0                 NaN
# 2                  NaN           -20.0                 NaN
# 3                  NaN            10.0                 NaN
# 4                  NaN            44.0                 NaN
# 5                  NaN            44.0                 NaN
# 6                  NaN         -2300.0                 NaN
# 7                  NaN         -1650.0                 NaN
# 8                  NaN         -1250.0                 NaN
# 9                  NaN          -680.0                 NaN
# 10                 NaN          -250.0                 NaN
# 11                 NaN            80.0                 NaN
# 12                 NaN           280.0                 NaN
# 13                 NaN            50.0                 NaN
# 14                 NaN          -570.0                30.0
#
#                                               REMARKS
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Multi-annual observation (87 mm w.e.) evenly d...
# 5   Multi-annual observation (87 mm w.e.) evenly d...
# 6                          Balance based on old area.
# 7                          Balance based on old area.
# 8                          Balance based on old area.
# 9                          Balance based on old area.
# 10                         Balance based on old area.
# 11                         Balance based on old area.
# 12                         Balance based on old area.
# 13                         Balance based on old area.
# 14  Value has been revised according to new glacie...

# %%
mass_balance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54249 entries, 0 to 54248
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   POLITICAL_UNIT      54249 non-null  object
#  1   NAME                54249 non-null  object
#  2   WGMS_ID             54249 non-null  int64
#  3   YEAR                54249 non-null  int64
#  4   LOWER_BOUND         54249 non-null  int64
#  5   UPPER_BOUND         54249 non-null  int64
#  6   AREA                50286 non-null  float64
#  7   WINTER_BALANCE      40149 non-null  float64
#  8   WINTER_BALANCE_UNC  6529 non-null   float64
#  9   SUMMER_BALANCE      39805 non-null  float64
#  10  SUMMER_BALANCE_UNC  6101 non-null   float64
#  11  ANNUAL_BALANCE      54069 non-null  float64
#  12  ANNUAL_BALANCE_UNC  10254 non-null  float64
#  13  REMARKS             17419 non-null  object
# dtypes: float64(7), int64(4), object(3)
# memory usage: 5.8+ MB

# %%
mass_balance_df.isna().sum()
# Out:
# POLITICAL_UNIT            0
# NAME                      0
# WGMS_ID                   0
# YEAR                      0
# LOWER_BOUND               0
# UPPER_BOUND               0
# AREA                   3963
# WINTER_BALANCE        14100
# WINTER_BALANCE_UNC    47720
# SUMMER_BALANCE        14444
# SUMMER_BALANCE_UNC    48148
# ANNUAL_BALANCE          180
# ANNUAL_BALANCE_UNC    43995
# REMARKS               36830
# dtype: int64

# %%
# Leyendo la documentación vemos que este dataset se complementa con el de mass_balance_overview asi que vamos a juntarlos.

# %% [markdown]
# ###🧊DATASET 5  **Mass_balance_overviwe.csv**:
# - dataset resultante: **mass_balance_ov_df**

# %%
mass_balance_ov_df = pd.read_csv('/content/drive/MyDrive/DATASETS/mass_balance_overview.csv')
mass_balance_ov_df.head(15)
# Out:
#    POLITICAL_UNIT              NAME  WGMS_ID  YEAR TIME_SYSTEM  BEGIN_PERIOD  \
# 0              AF          PIR YAKH    10452  2018         NaN           NaN
# 1              AQ          ALBERICH     1062  1972         OTH    19710206.0
# 2              AQ          ALBERICH     1062  1973         OTH    19720118.0
# 3              AQ          ALBERICH     1062  1974         OTH    19730122.0
# 4              AQ          ALBERICH     1062  1975         OTH    19740122.0
# 5              AQ  ANVERS I ICE CAP     3954  1966         NaN           NaN
# 6              AQ  ANVERS I ICE CAP     3954  1967         NaN           NaN
# 7              AQ  BAHIA DEL DIABLO     2665  2000         COM    19990301.0
# 8              AQ  BAHIA DEL DIABLO     2665  2001         COM    20000301.0
# 9              AQ  BAHIA DEL DIABLO     2665  2002         COM    20010301.0
# 10             AQ  BAHIA DEL DIABLO     2665  2003         COM    20020301.0
# 11             AQ  BAHIA DEL DIABLO     2665  2004         COM    20030301.0
# 12             AQ  BAHIA DEL DIABLO     2665  2005         COM    20040301.0
# 13             AQ  BAHIA DEL DIABLO     2665  2006         COM    20050301.0
# 14             AQ  BAHIA DEL DIABLO     2665  2007         COM    20060301.0
#
#     END_WINTER  END_PERIOD ELA_PREFIX    ELA  ...  MAX_SITES_ABL  ACC_AREA  \
# 0          NaN         NaN        NaN    NaN  ...            NaN       NaN
# 1          NaN  19720118.0        NaN    NaN  ...            NaN       NaN
# 2          NaN  19730122.0        NaN    NaN  ...            NaN       NaN
# 3          NaN  19740122.0        NaN    NaN  ...            NaN       NaN
# 4          NaN  19750110.0        NaN    NaN  ...            NaN       NaN
# 5          NaN         NaN        NaN    NaN  ...            NaN       NaN
# 6          NaN         NaN        NaN    NaN  ...            NaN       NaN
# 7          NaN  20000228.0        NaN  427.0  ...            NaN       NaN
# 8          NaN  20010228.0        NaN  375.0  ...            NaN       NaN
# 9          NaN  20020228.0        NaN  438.0  ...            NaN       NaN
# 10         NaN  20030228.0        NaN  389.0  ...            NaN       NaN
# 11         NaN  20040228.0        NaN  386.0  ...            NaN       NaN
# 12         NaN  20050228.0        NaN  405.0  ...            NaN       NaN
# 13         NaN  20060228.0        NaN  431.0  ...            NaN       NaN
# 14         NaN  20070228.0        NaN  360.0  ...            NaN       NaN
#
#     ACC_AREA_UNC  ABL_AREA  ABL_AREA_UNC   AAR  \
# 0            NaN       NaN           NaN   NaN
# 1            NaN       NaN           NaN  67.0
# 2            NaN       NaN           NaN  75.0
# 3            NaN       NaN           NaN  35.0
# 4            NaN       NaN           NaN  60.0
# 5            NaN       NaN           NaN   NaN
# 6            NaN       NaN           NaN   NaN
# 7            NaN       NaN           NaN  34.0
# 8            NaN       NaN           NaN  52.0
# 9            NaN       NaN           NaN  33.0
# 10           NaN       NaN           NaN  43.0
# 11           NaN       NaN           NaN  48.0
# 12           NaN       NaN           NaN  49.0
# 13           NaN       NaN           NaN  35.0
# 14           NaN       NaN           NaN  53.0
#
#                                          INVESTIGATOR  \
# 0              Abeer Ahmad Sajood, Hedayatullah Arian
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   Pedro Skvarca, Hernán De Angelis, Evgeniy Ermolin
# 8   Pedro Skvarca, Hernán De Angelis, Evgeniy Ermolin
# 9   Pedro Skvarca, Hernán De Angelis, Evgeniy Ermolin
# 10  Pedro Skvarca, Hernán De Angelis, Evgeniy Ermolin
# 11                     Pedro Skvarca, Evgeniy Ermolin
# 12                     Pedro Skvarca, Evgeniy Ermolin
# 13                     Pedro Skvarca, Evgeniy Ermolin
# 14                     Pedro Skvarca, Evgeniy Ermolin
#
#                                          SPONS_AGENCY  \
# 0   Hydrometeorology Department, Geoscience Facult...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   División Glaciología, Instituto Antártico Arge...
# 8   División Glaciología, Instituto Antártico Arge...
# 9   Instituto Antártico Argentino, Glaciology Divi...
# 10  Instituto Antártico Argentino, Glaciology Divi...
# 11  División Glaciología; Instituto Antártico Arge...
# 12  División Glaciología; Instituto Antártico Arge...
# 13  División Glaciología; Instituto Antártico Arge...
# 14  División Glaciología; Instituto Antártico Arge...
#
#                                             REFERENCE  \
# 0                                                 NaN
# 1   Data from Dyurgerov, M.(2002): [3] For detaile...
# 2   Data from Dyurgerov, M.(2002): [3] For detaile...
# 3   Data from Dyurgerov, M.(2002): [3] For detaile...
# 4   Data from Dyurgerov, M.(2002): [3] For detaile...
# 5   Data from Cogley (2008, updated 2013) based on...
# 6   Data from Cogley (2008, updated 2013) based on...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#                                               REMARKS
# 0                      Index point measurements only.
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   Multi-annual observation (87 mm w.e.) evenly d...
# 6   Multi-annual observation (87 mm w.e.) evenly d...
# 7   Series has been revised according to new glaci...
# 8   Series has been revised according to new glaci...
# 9   Series has been revised according to new glaci...
# 10  Series has been revised according to new glaci...
# 11  Series has been revised according to new glaci...
# 12  Series has been revised according to new glaci...
# 13  Series has been revised according to new glaci...
# 14  Series has been revised according to new glaci...
#
# [15 rows x 24 columns]

# %% [markdown]
# ### 💥💥 MERGEAMOS🧊🧊 DATASET 4 Y 5
# - Mass_balance + Mass_balance_overviwe.csv
# - dataset resultante: **copy_mass_merged_df_filtered**

# %%
# mergeamos los dos datasets en base al campo nombre y el campo año.
mass_merged_df = pd.merge(mass_balance_df, mass_balance_ov_df, on=['NAME', 'YEAR', 'POLITICAL_UNIT','WGMS_ID'], suffixes=('_mass_balance', '_mass_balance_ov'))

# %%
mass_merged_df.describe()
# Out:
#              WGMS_ID          YEAR   LOWER_BOUND   UPPER_BOUND          AREA  \
# count   54249.000000  54249.000000  54249.000000  54249.000000  50286.000000
# mean     1897.159450   1995.501576   3600.173441   3657.583513      9.581129
# std      7597.481364     21.705685   2892.389958   2872.380034    220.625808
# min         0.000000   1885.000000      0.000000     50.000000      0.000000
# 25%       332.000000   1982.000000   1600.000000   1650.000000      0.084000
# 50%       491.000000   2000.000000   2900.000000   2950.000000      0.269000
# 75%      1331.000000   2013.000000   3800.000000   3900.000000      0.853004
# max    167234.000000   2024.000000   9999.000000   9999.000000  32100.000000
#
#        WINTER_BALANCE  WINTER_BALANCE_UNC  SUMMER_BALANCE  SUMMER_BALANCE_UNC  \
# count    40149.000000         6529.000000    39805.000000         6101.000000
# mean      1313.969279           76.110584    -2322.094423           82.335683
# std        943.319577           97.971324     2796.022477          107.703823
# min      -4720.000000            0.000000  -161839.000000            5.000000
# 25%        725.000000           20.000000    -3075.000000           20.000000
# 50%       1162.000000           50.000000    -1909.000000           50.000000
# 75%       1712.000000          100.000000    -1000.000000          100.000000
# max      10915.000000         1053.000000     4901.000000         1150.000000
#
#        ANNUAL_BALANCE  ...       ELA_UNC  MIN_SITES_ACC  MAX_SITES_ACC  \
# count    54069.000000  ...  11843.000000   20350.000000   16122.000000
# mean      -973.157341  ...     24.152706      24.955332      80.188686
# std       2681.769364  ...     88.233650     375.051021     582.143361
# min    -160574.000000  ...      0.000000       0.000000       0.000000
# 25%      -1706.000000  ...     10.000000       1.000000       2.000000
# 50%       -520.000000  ...     10.000000       5.000000       6.000000
# 75%        250.000000  ...     30.000000      15.000000      31.000000
# max      15050.000000  ...   1995.000000   53026.000000   53026.000000
#
#        MIN_SITES_ABL  MAX_SITES_ABL      ACC_AREA  ACC_AREA_UNC      ABL_AREA  \
# count   19963.000000   1.578500e+04  32083.000000  11697.000000  32091.000000
# mean       32.289886   7.641142e+03      4.159185      0.115235      9.396132
# std        49.231447   2.756228e+05     17.907815      0.322577    108.684782
# min         0.000000   0.000000e+00      0.000000      0.000000      0.000000
# 25%         7.000000   9.000000e+00      0.313120      0.010000      0.963750
# 50%        14.000000   1.800000e+01      1.350000      0.010000      2.030000
# 75%        32.000000   4.000000e+01      3.675625      0.050000      4.799000
# max       386.000000   9.999999e+06   1317.000000      4.000000   2829.000000
#
#        ABL_AREA_UNC           AAR
# count  11938.000000  48802.000000
# mean       0.127562     40.940835
# std        0.382124     27.380892
# min        0.000000      0.000000
# 25%        0.010000     18.000000
# 50%        0.010000     41.000000
# 75%        0.050000     62.000000
# max        4.000000    100.000000
#
# [8 rows x 25 columns]

# %%
mass_merged_df.head(15)
# Out:
#    POLITICAL_UNIT              NAME  WGMS_ID  YEAR  LOWER_BOUND  UPPER_BOUND  \
# 0              AQ          ALBERICH     1062  1972         9999         9999
# 1              AQ          ALBERICH     1062  1973         9999         9999
# 2              AQ          ALBERICH     1062  1974         9999         9999
# 3              AQ          ALBERICH     1062  1975         9999         9999
# 4              AQ  ANVERS I ICE CAP     3954  1966         9999         9999
# 5              AQ  ANVERS I ICE CAP     3954  1967         9999         9999
# 6              AQ  BAHIA DEL DIABLO     2665  2000           38          112
# 7              AQ  BAHIA DEL DIABLO     2665  2000          112          188
# 8              AQ  BAHIA DEL DIABLO     2665  2000          188          262
# 9              AQ  BAHIA DEL DIABLO     2665  2000          262          338
# 10             AQ  BAHIA DEL DIABLO     2665  2000          338          412
# 11             AQ  BAHIA DEL DIABLO     2665  2000          412          488
# 12             AQ  BAHIA DEL DIABLO     2665  2000          488          562
# 13             AQ  BAHIA DEL DIABLO     2665  2000          562          638
# 14             AQ  BAHIA DEL DIABLO     2665  2000         9999         9999
#
#      AREA  WINTER_BALANCE  WINTER_BALANCE_UNC  SUMMER_BALANCE  ...  \
# 0    1.36             0.0                 NaN            10.0  ...
# 1    1.36             0.0                 NaN            30.0  ...
# 2    1.36           -10.0                 NaN             0.0  ...
# 3    1.36            10.0                 NaN             0.0  ...
# 4     NaN             NaN                 NaN             NaN  ...
# 5     NaN             NaN                 NaN             NaN  ...
# 6     NaN             NaN                 NaN             NaN  ...
# 7     NaN             NaN                 NaN             NaN  ...
# 8     NaN             NaN                 NaN             NaN  ...
# 9     NaN             NaN                 NaN             NaN  ...
# 10    NaN             NaN                 NaN             NaN  ...
# 11    NaN             NaN                 NaN             NaN  ...
# 12    NaN             NaN                 NaN             NaN  ...
# 13    NaN             NaN                 NaN             NaN  ...
# 14  12.90             NaN                 NaN             NaN  ...
#
#     MAX_SITES_ABL  ACC_AREA  ACC_AREA_UNC ABL_AREA ABL_AREA_UNC   AAR  \
# 0             NaN       NaN           NaN      NaN          NaN  67.0
# 1             NaN       NaN           NaN      NaN          NaN  75.0
# 2             NaN       NaN           NaN      NaN          NaN  35.0
# 3             NaN       NaN           NaN      NaN          NaN  60.0
# 4             NaN       NaN           NaN      NaN          NaN   NaN
# 5             NaN       NaN           NaN      NaN          NaN   NaN
# 6             NaN       NaN           NaN      NaN          NaN  34.0
# 7             NaN       NaN           NaN      NaN          NaN  34.0
# 8             NaN       NaN           NaN      NaN          NaN  34.0
# 9             NaN       NaN           NaN      NaN          NaN  34.0
# 10            NaN       NaN           NaN      NaN          NaN  34.0
# 11            NaN       NaN           NaN      NaN          NaN  34.0
# 12            NaN       NaN           NaN      NaN          NaN  34.0
# 13            NaN       NaN           NaN      NaN          NaN  34.0
# 14            NaN       NaN           NaN      NaN          NaN  34.0
#
#                                          INVESTIGATOR  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   Pedro Skvarca, Hernán De Angelis, Evgeniy Ermolin
# 7   Pedro Skvarca, Hernán De Angelis, Evgeniy Ermolin
# 8   Pedro Skvarca, Hernán De Angelis, Evgeniy Ermolin
# 9   Pedro Skvarca, Hernán De Angelis, Evgeniy Ermolin
# 10  Pedro Skvarca, Hernán De Angelis, Evgeniy Ermolin
# 11  Pedro Skvarca, Hernán De Angelis, Evgeniy Ermolin
# 12  Pedro Skvarca, Hernán De Angelis, Evgeniy Ermolin
# 13  Pedro Skvarca, Hernán De Angelis, Evgeniy Ermolin
# 14  Pedro Skvarca, Hernán De Angelis, Evgeniy Ermolin
#
#                                          SPONS_AGENCY  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   División Glaciología, Instituto Antártico Arge...
# 7   División Glaciología, Instituto Antártico Arge...
# 8   División Glaciología, Instituto Antártico Arge...
# 9   División Glaciología, Instituto Antártico Arge...
# 10  División Glaciología, Instituto Antártico Arge...
# 11  División Glaciología, Instituto Antártico Arge...
# 12  División Glaciología, Instituto Antártico Arge...
# 13  División Glaciología, Instituto Antártico Arge...
# 14  División Glaciología, Instituto Antártico Arge...
#
#                                             REFERENCE  \
# 0   Data from Dyurgerov, M.(2002): [3] For detaile...
# 1   Data from Dyurgerov, M.(2002): [3] For detaile...
# 2   Data from Dyurgerov, M.(2002): [3] For detaile...
# 3   Data from Dyurgerov, M.(2002): [3] For detaile...
# 4   Data from Cogley (2008, updated 2013) based on...
# 5   Data from Cogley (2008, updated 2013) based on...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#                               REMARKS_mass_balance_ov
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Multi-annual observation (87 mm w.e.) evenly d...
# 5   Multi-annual observation (87 mm w.e.) evenly d...
# 6   Series has been revised according to new glaci...
# 7   Series has been revised according to new glaci...
# 8   Series has been revised according to new glaci...
# 9   Series has been revised according to new glaci...
# 10  Series has been revised according to new glaci...
# 11  Series has been revised according to new glaci...
# 12  Series has been revised according to new glaci...
# 13  Series has been revised according to new glaci...
# 14  Series has been revised according to new glaci...
#
# [15 rows x 34 columns]

# %%
mass_merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54249 entries, 0 to 54248
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   POLITICAL_UNIT           54249 non-null  object
#  1   NAME                     54249 non-null  object
#  2   WGMS_ID                  54249 non-null  int64
#  3   YEAR                     54249 non-null  int64
#  4   LOWER_BOUND              54249 non-null  int64
#  5   UPPER_BOUND              54249 non-null  int64
#  6   AREA                     50286 non-null  float64
#  7   WINTER_BALANCE           40149 non-null  float64
#  8   WINTER_BALANCE_UNC       6529 non-null   float64
#  9   SUMMER_BALANCE           39805 non-null  float64
#  10  SUMMER_BALANCE_UNC       6101 non-null   float64
#  11  ANNUAL_BALANCE           54069 non-null  float64
#  12  ANNUAL_BALANCE_UNC       10254 non-null  float64
#  13  REMARKS_mass_balance     17419 non-null  object
#  14  TIME_SYSTEM              31961 non-null  object
#  15  BEGIN_PERIOD             48037 non-null  float64
#  16  END_WINTER               35118 non-null  float64
#  17  END_PERIOD               48461 non-null  float64
#  18  ELA_PREFIX               5810 non-null   object
#  19  ELA                      50080 non-null  float64
#  20  ELA_UNC                  11843 non-null  float64
#  21  MIN_SITES_ACC            20350 non-null  float64
#  22  MAX_SITES_ACC            16122 non-null  float64
#  23  MIN_SITES_ABL            19963 non-null  float64
#  24  MAX_SITES_ABL            15785 non-null  float64
#  25  ACC_AREA                 32083 non-null  float64
#  26  ACC_AREA_UNC             11697 non-null  float64
#  27  ABL_AREA                 32091 non-null  float64
#  28  ABL_AREA_UNC             11938 non-null  float64
#  29  AAR                      48802 non-null  float64
#  30  INVESTIGATOR             32730 non-null  object
#  31  SPONS_AGENCY             36962 non-null  object
#  32  REFERENCE                44831 non-null  object
#  33  REMARKS_mass_balance_ov  21736 non-null  object
# dtypes: float64(21), int64(4), object(9)
# memory usage: 14.1+ MB

# %%
mass_merged_df.isna().sum()
# Out:
# POLITICAL_UNIT                 0
# NAME                           0
# WGMS_ID                        0
# YEAR                           0
# LOWER_BOUND                    0
# UPPER_BOUND                    0
# AREA                        3963
# WINTER_BALANCE             14100
# WINTER_BALANCE_UNC         47720
# SUMMER_BALANCE             14444
# SUMMER_BALANCE_UNC         48148
# ANNUAL_BALANCE               180
# ANNUAL_BALANCE_UNC         43995
# REMARKS_mass_balance       36830
# TIME_SYSTEM                22288
# BEGIN_PERIOD                6212
# END_WINTER                 19131
# END_PERIOD                  5788
# ELA_PREFIX                 48439
# ELA                         4169
# ELA_UNC                    42406
# MIN_SITES_ACC              33899
# MAX_SITES_ACC              38127
# MIN_SITES_ABL              34286
# MAX_SITES_ABL              38464
# ACC_AREA                   22166
# ACC_AREA_UNC               42552
# ABL_AREA                   22158
# ABL_AREA_UNC               42311
# AAR                         5447
# INVESTIGATOR               21519
# SPONS_AGENCY               17287
# REFERENCE                   9418
# REMARKS_mass_balance_ov    32513
# dtype: int64

# %% [markdown]
# * Borraremos las columnas que contengan 'UNC' ya que solo son márgenes de error, los comentarios de las columnas 'REMARKS',
#
# * TIME_SYSTEM: Puede no ser relevante para la predicción del deshielo en sí
# misma, ya que se refiere al sistema de medición del tiempo y no a características específicas del glaciar.
#
# * BEGIN_PERIOD, END_WINTER, END_PERIOD: Aunque estas columnas proporcionan información temporal, si nuestro objetivo es predecir el deshielo futuro, es posible que puedas prescindir de ellas, especialmente si ya tienes una columna que representa el año del balance de masa.
#
# * MIN_SITES_ACC, MAX_SITES_ACC, MIN_SITES_ABL, MAX_SITES_ABL: Estas columnas proporcionan información sobre la cantidad de sitios de medición en áreas específicas del glaciar. Pueden ser relevantes si estamos interesados en la distribución espacial de las mediciones, pero podrían no ser cruciales para la predicción del deshielo.
#
# * INVESTIGATOR, SPONS_AGENCY, REFERENCE: Estas columnas contienen metadatos sobre los investigadores, las agencias patrocinadoras y las referencias a las publicaciones. Por lo general, no son características que se utilizan directamente para la predicción.

# %%
# Revisando nos quedaremos con las siguientes columnas del data set:
# Lista de columnas a mantener en el nuevo DataFrame
mass_merged_columns = ['POLITICAL_UNIT', 'NAME', 'WGMS_ID', 'YEAR', 'AREA', 'WINTER_BALANCE',
       'SUMMER_BALANCE', 'ANNUAL_BALANCE', 'ELA', 'ACC_AREA', 'ABL_AREA',
       'AAR']

# Crear un nuevo DataFrame para almacenar las columnas seleccionadas
copy_mass_merged_df = pd.DataFrame()

# Iterar sobre cada columna en la lista de columnas
for column in mass_merged_columns:
    # Si la columna es 'YEAR' o 'SURVEY_DATE', añadir el prefijo 'state_'
    #if column == 'YEAR' or column == 'SURVEY_DATE':
        #new_mass[f'mass_{column}'] = mass_merged[column]
    #else:
  copy_mass_merged_df[column] = mass_merged_df[column]

# %%
# esto es solo una prueba
copy_mass_merged_df[(copy_mass_merged_df['NAME'] == 'BAHIA DEL DIABLO') & (copy_mass_merged_df['YEAR'] == 2005)]
# Out:
#    POLITICAL_UNIT              NAME  WGMS_ID  YEAR  AREA  WINTER_BALANCE  \
# 51             AQ  BAHIA DEL DIABLO     2665  2005   NaN             NaN
# 52             AQ  BAHIA DEL DIABLO     2665  2005   NaN             NaN
# 53             AQ  BAHIA DEL DIABLO     2665  2005   NaN             NaN
# 54             AQ  BAHIA DEL DIABLO     2665  2005   NaN             NaN
# 55             AQ  BAHIA DEL DIABLO     2665  2005   NaN             NaN
# 56             AQ  BAHIA DEL DIABLO     2665  2005   NaN             NaN
# 57             AQ  BAHIA DEL DIABLO     2665  2005   NaN             NaN
# 58             AQ  BAHIA DEL DIABLO     2665  2005   NaN             NaN
# 59             AQ  BAHIA DEL DIABLO     2665  2005  12.9             NaN
#
#     SUMMER_BALANCE  ANNUAL_BALANCE    ELA  ACC_AREA  ABL_AREA   AAR
# 51             NaN         -1700.0  405.0       NaN       NaN  49.0
# 52             NaN          -900.0  405.0       NaN       NaN  49.0
# 53             NaN          -450.0  405.0       NaN       NaN  49.0
# 54             NaN          -350.0  405.0       NaN       NaN  49.0
# 55             NaN          -100.0  405.0       NaN       NaN  49.0
# 56             NaN           100.0  405.0       NaN       NaN  49.0
# 57             NaN           225.0  405.0       NaN       NaN  49.0
# 58             NaN            50.0  405.0       NaN       NaN  49.0
# 59             NaN          -140.0  405.0       NaN       NaN  49.0

# %%
#cambiaremos los valores 9999 por NaN:
mass_merged_columns = list(copy_mass_merged_df.columns)
copy_mass_merged_df[mass_merged_columns].replace(9999, np.nan, inplace=True)

# %%
copy_mass_merged_df.head()
# Out:
#   POLITICAL_UNIT              NAME  WGMS_ID  YEAR  AREA  WINTER_BALANCE  \
# 0             AQ          ALBERICH     1062  1972  1.36             0.0
# 1             AQ          ALBERICH     1062  1973  1.36             0.0
# 2             AQ          ALBERICH     1062  1974  1.36           -10.0
# 3             AQ          ALBERICH     1062  1975  1.36            10.0
# 4             AQ  ANVERS I ICE CAP     3954  1966   NaN             NaN
#
#    SUMMER_BALANCE  ANNUAL_BALANCE  ELA  ACC_AREA  ABL_AREA   AAR
# 0            10.0            20.0  NaN       NaN       NaN  67.0
# 1            30.0            30.0  NaN       NaN       NaN  75.0
# 2             0.0           -20.0  NaN       NaN       NaN  35.0
# 3             0.0            10.0  NaN       NaN       NaN  60.0
# 4             NaN            44.0  NaN       NaN       NaN   NaN

# %%
# Crea un nuevo DataFrame filtrando las filas donde ambas columnas tengan valores no nulos
#new_mass = new_mass[(new_mass['SUMMER_BALANCE'].notnull()) & (new_mass['WINTER_BALANCE'].notnull()) & (new_mass['AREA'].notnull())]

# %%
copy_mass_merged_df[copy_mass_merged_df['ABL_AREA'].notnull()].head()
# Out:
#     POLITICAL_UNIT              NAME  WGMS_ID  YEAR  AREA  WINTER_BALANCE  \
# 132             AQ  BAHIA DEL DIABLO     2665  2014   NaN             NaN
# 133             AQ  BAHIA DEL DIABLO     2665  2014   NaN             NaN
# 134             AQ  BAHIA DEL DIABLO     2665  2014   NaN             NaN
# 135             AQ  BAHIA DEL DIABLO     2665  2014   NaN             NaN
# 136             AQ  BAHIA DEL DIABLO     2665  2014   NaN             NaN
#
#      SUMMER_BALANCE  ANNUAL_BALANCE    ELA  ACC_AREA  ABL_AREA   AAR
# 132             NaN          -600.0  325.0       8.0       4.9  62.0
# 133             NaN          -200.0  325.0       8.0       4.9  62.0
# 134             NaN          -180.0  325.0       8.0       4.9  62.0
# 135             NaN          -100.0  325.0       8.0       4.9  62.0
# 136             NaN           250.0  325.0       8.0       4.9  62.0

# %%
copy_mass_merged_df['AREA'] = copy_mass_merged_df['AREA'].apply(km_m)

# %%
copy_mass_merged_df['ACC_AREA'] = copy_mass_merged_df['ACC_AREA'].apply(km_m)

# %%
copy_mass_merged_df['ABL_AREA'] = copy_mass_merged_df['ABL_AREA'].apply(km_m)

# %%
copy_mass_merged_df[copy_mass_merged_df['ACC_AREA'].notnull()]
# Out:
#       POLITICAL_UNIT                         NAME  WGMS_ID  YEAR        AREA  \
# 132               AQ             BAHIA DEL DIABLO     2665  2014         NaN
# 133               AQ             BAHIA DEL DIABLO     2665  2014         NaN
# 134               AQ             BAHIA DEL DIABLO     2665  2014         NaN
# 135               AQ             BAHIA DEL DIABLO     2665  2014         NaN
# 136               AQ             BAHIA DEL DIABLO     2665  2014         NaN
# ...              ...                          ...      ...   ...         ...
# 54244             UZ  BARKRAK SREDNIY EAST BRANCH   165854  2023   42.984060
# 54245             UZ  BARKRAK SREDNIY EAST BRANCH   165854  2023   66.810100
# 54246             UZ  BARKRAK SREDNIY EAST BRANCH   165854  2023   63.420500
# 54247             UZ  BARKRAK SREDNIY EAST BRANCH   165854  2023   53.489480
# 54248             UZ  BARKRAK SREDNIY EAST BRANCH   165854  2023  415.840572
#
#        WINTER_BALANCE  SUMMER_BALANCE  ANNUAL_BALANCE     ELA  ACC_AREA  \
# 132               NaN             NaN     -600.000000   325.0    8000.0
# 133               NaN             NaN     -200.000000   325.0    8000.0
# 134               NaN             NaN     -180.000000   325.0    8000.0
# 135               NaN             NaN     -100.000000   325.0    8000.0
# 136               NaN             NaN      250.000000   325.0    8000.0
# ...               ...             ...             ...     ...       ...
# 54244             NaN             NaN       14.848109  2848.0     276.7
# 54245             NaN             NaN        0.000000  2848.0     276.7
# 54246             NaN             NaN        0.000000  2848.0     276.7
# 54247             NaN             NaN        0.000000  2848.0     276.7
# 54248             NaN             NaN     -640.570000  2848.0     276.7
#
#        ABL_AREA   AAR
# 132      4900.0  62.0
# 133      4900.0  62.0
# 134      4900.0  62.0
# 135      4900.0  62.0
# 136      4900.0  62.0
# ...         ...   ...
# 54244     139.0  66.5
# 54245     139.0  66.5
# 54246     139.0  66.5
# 54247     139.0  66.5
# 54248     139.0  66.5
#
# [32083 rows x 12 columns]

# %%
copy_mass_merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54249 entries, 0 to 54248
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   POLITICAL_UNIT  54249 non-null  object
#  1   NAME            54249 non-null  object
#  2   WGMS_ID         54249 non-null  int64
#  3   YEAR            54249 non-null  int64
#  4   AREA            50286 non-null  float64
#  5   WINTER_BALANCE  40149 non-null  float64
#  6   SUMMER_BALANCE  39805 non-null  float64
#  7   ANNUAL_BALANCE  54069 non-null  float64
#  8   ELA             50080 non-null  float64
#  9   ACC_AREA        32083 non-null  float64
#  10  ABL_AREA        32091 non-null  float64
#  11  AAR             48802 non-null  float64
# dtypes: float64(8), int64(2), object(2)
# memory usage: 5.0+ MB

# %% [markdown]
# copy_mass_merged es la tabla final de los balances de masa por año

# %%
copy_mass_merged_df.isna().sum()
# Out:
# POLITICAL_UNIT        0
# NAME                  0
# WGMS_ID               0
# YEAR                  0
# AREA               3963
# WINTER_BALANCE    14100
# SUMMER_BALANCE    14444
# ANNUAL_BALANCE      180
# ELA                4169
# ACC_AREA          22166
# ABL_AREA          22158
# AAR                5447
# dtype: int64

# %%
copy_mass_merged_df=copy_mass_merged_df[copy_mass_merged_df['NAME']=='BAHIA DEL DIABLO']

# %%
copy_mass_merged_df.head()
# Out:
#    POLITICAL_UNIT              NAME  WGMS_ID  YEAR  AREA  WINTER_BALANCE  \
# 6              AQ  BAHIA DEL DIABLO     2665  2000   NaN             NaN
# 7              AQ  BAHIA DEL DIABLO     2665  2000   NaN             NaN
# 8              AQ  BAHIA DEL DIABLO     2665  2000   NaN             NaN
# 9              AQ  BAHIA DEL DIABLO     2665  2000   NaN             NaN
# 10             AQ  BAHIA DEL DIABLO     2665  2000   NaN             NaN
#
#     SUMMER_BALANCE  ANNUAL_BALANCE    ELA  ACC_AREA  ABL_AREA   AAR
# 6              NaN         -2300.0  427.0       NaN       NaN  34.0
# 7              NaN         -1650.0  427.0       NaN       NaN  34.0
# 8              NaN         -1250.0  427.0       NaN       NaN  34.0
# 9              NaN          -680.0  427.0       NaN       NaN  34.0
# 10             NaN          -250.0  427.0       NaN       NaN  34.0

# %%
# Filtrar el DataFrame para mantener solo las filas con 'mass_YEAR' único y 'AREA' no nulo para hacer una visualización de datos:
copy_mass_merged_df_filtered = copy_mass_merged_df[copy_mass_merged_df['AREA'].notnull()].drop_duplicates(subset=['YEAR'], keep = False)
copy_mass_merged_df_filtered.head(15)
# Out:
#     POLITICAL_UNIT              NAME  WGMS_ID  YEAR     AREA  WINTER_BALANCE  \
# 14              AQ  BAHIA DEL DIABLO     2665  2000  12900.0             NaN
# 23              AQ  BAHIA DEL DIABLO     2665  2001  12900.0             NaN
# 32              AQ  BAHIA DEL DIABLO     2665  2002  12900.0             NaN
# 41              AQ  BAHIA DEL DIABLO     2665  2003  12900.0             NaN
# 50              AQ  BAHIA DEL DIABLO     2665  2004  12900.0             NaN
# 59              AQ  BAHIA DEL DIABLO     2665  2005  12900.0             NaN
# 68              AQ  BAHIA DEL DIABLO     2665  2006  12900.0             NaN
# 77              AQ  BAHIA DEL DIABLO     2665  2007  12900.0             NaN
# 86              AQ  BAHIA DEL DIABLO     2665  2008  12900.0             NaN
# 95              AQ  BAHIA DEL DIABLO     2665  2009  12900.0             NaN
# 104             AQ  BAHIA DEL DIABLO     2665  2010  12900.0             NaN
# 113             AQ  BAHIA DEL DIABLO     2665  2011  12900.0             NaN
# 122             AQ  BAHIA DEL DIABLO     2665  2012  12900.0             NaN
# 131             AQ  BAHIA DEL DIABLO     2665  2013  12900.0             NaN
# 140             AQ  BAHIA DEL DIABLO     2665  2014  12900.0             NaN
#
#      SUMMER_BALANCE  ANNUAL_BALANCE    ELA  ACC_AREA  ABL_AREA    AAR
# 14              NaN          -570.0  427.0       NaN       NaN   34.0
# 23              NaN           -60.0  375.0       NaN       NaN   52.0
# 32              NaN          -560.0  438.0       NaN       NaN   33.0
# 41              NaN          -180.0  389.0       NaN       NaN   43.0
# 50              NaN          -120.0  386.0       NaN       NaN   48.0
# 59              NaN          -140.0  405.0       NaN       NaN   49.0
# 68              NaN          -450.0  431.0       NaN       NaN   35.0
# 77              NaN          -140.0  360.0       NaN       NaN   53.0
# 86              NaN          -440.0  435.0       NaN       NaN   37.0
# 95              NaN          -330.0  388.0       NaN       NaN   42.0
# 104             NaN           370.0   75.0       NaN       NaN  100.0
# 113             NaN            20.0  322.0       NaN       NaN   62.0
# 122             NaN           -20.0  370.0       NaN       NaN   52.0
# 131             NaN           100.0  295.0       NaN       NaN   58.0
# 140             NaN           190.0  325.0    8000.0    4900.0   62.0

# %%
plt.figure(figsize = (8,10))
plt.plot(copy_mass_merged_df_filtered['YEAR'], copy_mass_merged_df_filtered['AREA'], marker = 'o', linestyle='-')
plt.title('Área del Glaciar BAHIA DEL DIABLO en función del Año')  # Establece el título del gráfico
plt.xlabel('Año')  # Etiqueta del eje x
plt.ylabel('Área (km2)')  # Etiqueta del eje y
plt.grid(True)  # Muestra una cuadrícula en el gráfico
# Establecer la ubicación de los ticks del eje x a intervalos de 1
plt.xticks(copy_mass_merged_df_filtered['YEAR'], rotation=90)
plt.show()  # Muestra el gráfico

# %%
copy_mass_merged_df_filtered_2 = copy_mass_merged_df[copy_mass_merged_df['ANNUAL_BALANCE'].notnull()]
copy_mass_merged_df_filtered_2.head(15)
# Out:
#    POLITICAL_UNIT              NAME  WGMS_ID  YEAR     AREA  WINTER_BALANCE  \
# 6              AQ  BAHIA DEL DIABLO     2665  2000      NaN             NaN
# 7              AQ  BAHIA DEL DIABLO     2665  2000      NaN             NaN
# 8              AQ  BAHIA DEL DIABLO     2665  2000      NaN             NaN
# 9              AQ  BAHIA DEL DIABLO     2665  2000      NaN             NaN
# 10             AQ  BAHIA DEL DIABLO     2665  2000      NaN             NaN
# 11             AQ  BAHIA DEL DIABLO     2665  2000      NaN             NaN
# 12             AQ  BAHIA DEL DIABLO     2665  2000      NaN             NaN
# 13             AQ  BAHIA DEL DIABLO     2665  2000      NaN             NaN
# 14             AQ  BAHIA DEL DIABLO     2665  2000  12900.0             NaN
# 15             AQ  BAHIA DEL DIABLO     2665  2001      NaN             NaN
# 16             AQ  BAHIA DEL DIABLO     2665  2001      NaN             NaN
# 17             AQ  BAHIA DEL DIABLO     2665  2001      NaN             NaN
# 18             AQ  BAHIA DEL DIABLO     2665  2001      NaN             NaN
# 19             AQ  BAHIA DEL DIABLO     2665  2001      NaN             NaN
# 20             AQ  BAHIA DEL DIABLO     2665  2001      NaN             NaN
#
#     SUMMER_BALANCE  ANNUAL_BALANCE    ELA  ACC_AREA  ABL_AREA   AAR
# 6              NaN         -2300.0  427.0       NaN       NaN  34.0
# 7              NaN         -1650.0  427.0       NaN       NaN  34.0
# 8              NaN         -1250.0  427.0       NaN       NaN  34.0
# 9              NaN          -680.0  427.0       NaN       NaN  34.0
# 10             NaN          -250.0  427.0       NaN       NaN  34.0
# 11             NaN            80.0  427.0       NaN       NaN  34.0
# 12             NaN           280.0  427.0       NaN       NaN  34.0
# 13             NaN            50.0  427.0       NaN       NaN  34.0
# 14             NaN          -570.0  427.0       NaN       NaN  34.0
# 15             NaN         -1000.0  375.0       NaN       NaN  52.0
# 16             NaN          -600.0  375.0       NaN       NaN  52.0
# 17             NaN          -250.0  375.0       NaN       NaN  52.0
# 18             NaN          -260.0  375.0       NaN       NaN  52.0
# 19             NaN             0.0  375.0       NaN       NaN  52.0
# 20             NaN           330.0  375.0       NaN       NaN  52.0

# %%
plt.figure(figsize = (8,10))
plt.plot(copy_mass_merged_df_filtered['YEAR'], copy_mass_merged_df_filtered['ANNUAL_BALANCE'], marker = 'o')
plt.title('Balance de masa del Glaciar BAHIA DEL DIABLO en función del Año')  # Establece el título del gráfico
plt.xlabel('Año')  # Etiqueta del eje x
plt.ylabel('balance de masa (kg m⁻²)')  # Etiqueta del eje y
plt.grid(True)  # Muestra una cuadrícula en el gráfico
# Establecer la ubicación de los ticks del eje x a intervalos de 1
plt.xticks(copy_mass_merged_df_filtered['YEAR'], rotation=90)
plt.show()  # Muestra el gráfico

# %% [markdown]
# ###🧊DATASET 6 **Mass_balance_point.csv**:
# - dataset resultante : **copy_mass_b_point_df**

# %%
# leemos el siguiente csv
mass_b_point_df = pd.read_csv('/content/drive/MyDrive/DATASETS/mass_balance_point.csv')
mass_b_point_df.head(15)
# Out:
#    POLITICAL_UNIT              NAME  WGMS_ID  YEAR POINT_ID  FROM_DATE  \
# 0              AF          PIR YAKH    10452  2018     PY10   20170707
# 1              AF          PIR YAKH    10452  2018     PY20   20170707
# 2              AQ  BAHIA DEL DIABLO     2665  2010        1   20090301
# 3              AQ  BAHIA DEL DIABLO     2665  2010       10   20090301
# 4              AQ  BAHIA DEL DIABLO     2665  2010       11   20090301
# 5              AQ  BAHIA DEL DIABLO     2665  2010       12   20090301
# 6              AQ  BAHIA DEL DIABLO     2665  2010       13   20090301
# 7              AQ  BAHIA DEL DIABLO     2665  2010       14   20090301
# 8              AQ  BAHIA DEL DIABLO     2665  2010       15   20090301
# 9              AQ  BAHIA DEL DIABLO     2665  2010       16   20090301
# 10             AQ  BAHIA DEL DIABLO     2665  2010       17   20090301
# 11             AQ  BAHIA DEL DIABLO     2665  2010       18   20090301
# 12             AQ  BAHIA DEL DIABLO     2665  2010       19   20090301
# 13             AQ  BAHIA DEL DIABLO     2665  2010        2   20090301
# 14             AQ  BAHIA DEL DIABLO     2665  2010       20   20090301
#
#      TO_DATE  POINT_LAT  POINT_LON  POINT_ELEVATION  POINT_BALANCE  \
# 0   20180831   35.59870   70.17995           4541.0        -3413.0
# 1   20180831   35.60075   70.17420           4737.0        -1684.0
# 2   20100228        NaN        NaN            100.0          100.0
# 3   20100228        NaN        NaN            398.0          500.0
# 4   20100228        NaN        NaN            442.0          600.0
# 5   20100228        NaN        NaN            456.0          700.0
# 6   20100228        NaN        NaN            458.0          400.0
# 7   20100228        NaN        NaN            464.0          600.0
# 8   20100228        NaN        NaN            445.0         1000.0
# 9   20100228        NaN        NaN            505.0          600.0
# 10  20100228        NaN        NaN            515.0          600.0
# 11  20100228        NaN        NaN            551.0          600.0
# 12  20100228        NaN        NaN            588.0          300.0
# 13  20100228        NaN        NaN            115.0          200.0
# 14  20100228        NaN        NaN            553.0          700.0
#
#     POINT_BALANCE_UNCERTAINTY  DENSITY  DENSITY_UNCERTAINTY BALANCE_CODE  \
# 0                         NaN    910.0                  NaN           IN
# 1                         NaN    910.0                  NaN           IN
# 2                         NaN      NaN                  NaN           BA
# 3                         NaN      NaN                  NaN           BA
# 4                         NaN      NaN                  NaN           BA
# 5                         NaN      NaN                  NaN           BA
# 6                         NaN      NaN                  NaN           BA
# 7                         NaN      NaN                  NaN           BA
# 8                         NaN      NaN                  NaN           BA
# 9                         NaN      NaN                  NaN           BA
# 10                        NaN      NaN                  NaN           BA
# 11                        NaN      NaN                  NaN           BA
# 12                        NaN      NaN                  NaN           BA
# 13                        NaN      NaN                  NaN           BA
# 14                        NaN      NaN                  NaN           BA
#
#                          REMARKS
# 0                            NaN
# 1                            NaN
# 2   POINT_ID assigned arbitrary.
# 3   POINT_ID assigned arbitrary.
# 4   POINT_ID assigned arbitrary.
# 5   POINT_ID assigned arbitrary.
# 6   POINT_ID assigned arbitrary.
# 7   POINT_ID assigned arbitrary.
# 8   POINT_ID assigned arbitrary.
# 9   POINT_ID assigned arbitrary.
# 10  POINT_ID assigned arbitrary.
# 11  POINT_ID assigned arbitrary.
# 12  POINT_ID assigned arbitrary.
# 13  POINT_ID assigned arbitrary.
# 14  POINT_ID assigned arbitrary.

# %%
# vemos cuántos valores nulos tiene cada columna:
mass_b_point_df.isna().sum()
# Out:
# POLITICAL_UNIT                   0
# NAME                             0
# WGMS_ID                          0
# YEAR                             0
# POINT_ID                         0
# FROM_DATE                        0
# TO_DATE                          0
# POINT_LAT                     4054
# POINT_LON                     4054
# POINT_ELEVATION               7534
# POINT_BALANCE                    0
# POINT_BALANCE_UNCERTAINTY    42727
# DENSITY                      46265
# DENSITY_UNCERTAINTY          50034
# BALANCE_CODE                     0
# REMARKS                      27730
# dtype: int64

# %%
mass_b_point_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57509 entries, 0 to 57508
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   POLITICAL_UNIT             57509 non-null  object
#  1   NAME                       57509 non-null  object
#  2   WGMS_ID                    57509 non-null  int64
#  3   YEAR                       57509 non-null  int64
#  4   POINT_ID                   57509 non-null  object
#  5   FROM_DATE                  57509 non-null  int64
#  6   TO_DATE                    57509 non-null  int64
#  7   POINT_LAT                  53455 non-null  float64
#  8   POINT_LON                  53455 non-null  float64
#  9   POINT_ELEVATION            49975 non-null  float64
#  10  POINT_BALANCE              57509 non-null  float64
#  11  POINT_BALANCE_UNCERTAINTY  14782 non-null  float64
#  12  DENSITY                    11244 non-null  float64
#  13  DENSITY_UNCERTAINTY        7475 non-null   float64
#  14  BALANCE_CODE               57509 non-null  object
#  15  REMARKS                    29779 non-null  object
# dtypes: float64(7), int64(4), object(5)
# memory usage: 7.0+ MB

# %% [markdown]
# Viendo la documentación y analizándolo, nos quedaremos con las siguientes columnas:
# * ``NAME``: El nombre del glaciar.
#
# * ``YEAR``: El año asociado con el último ciclo de acumulación (invierno) - ablación
# (verano). Esto te proporcionaría la información temporal necesaria para rastrear los cambios en el tiempo.
#
# * ``FROM_DATE y TO_DATE``: Las fechas de inicio y finalización del ciclo de medición. Esto proporcionaría información sobre la duración de cada medición de balance de masa.
#
# * ``POINT_LAT y POINT_LON``: Las coordenadas geográficas del punto de medición. Esto te permitiría tener en cuenta la ubicación geográfica del glaciar, lo cual puede ser importante para comprender los factores que afectan su balance de masa.
#
# * ``POINT_ELEVATION``: La elevación de la superficie del glaciar en el punto de medición. Esto sería relevante ya que la elevación puede influir significativamente en el balance de masa de un glaciar.
#
# * `` POINT_BALANCE``: El balance de masa medido en el punto de medición. Esto podría ser una de las variables objetivo.
#
# * `` DENSITY``: La densidad del glaciar puede variar espacialmente debido a diferentes condiciones de acumulación de nieve, compactación del hielo, etc. Esta variabilidad espacial puede influir en la respuesta del glaciar al cambio climático y, por lo tanto, podría ser una característica importante para incluir en el modelo.

# %%
mp_columns = ['POLITICAL_UNIT', 'NAME', 'WGMS_ID', 'YEAR', 'POINT_ELEVATION', 'POINT_BALANCE']

# %%
clean_mass_b_point_df = pd.DataFrame()
for column in mp_columns:
  #if column == 'mp_YEAR':
   # new_mp[column] = mass_b_point['YEAR']
  #else:
  clean_mass_b_point_df[column] = mass_b_point_df[column]

# %%
clean_mass_b_point_df.head(10)
# Out:
#   POLITICAL_UNIT              NAME  WGMS_ID  YEAR  POINT_ELEVATION  \
# 0             AF          PIR YAKH    10452  2018           4541.0
# 1             AF          PIR YAKH    10452  2018           4737.0
# 2             AQ  BAHIA DEL DIABLO     2665  2010            100.0
# 3             AQ  BAHIA DEL DIABLO     2665  2010            398.0
# 4             AQ  BAHIA DEL DIABLO     2665  2010            442.0
# 5             AQ  BAHIA DEL DIABLO     2665  2010            456.0
# 6             AQ  BAHIA DEL DIABLO     2665  2010            458.0
# 7             AQ  BAHIA DEL DIABLO     2665  2010            464.0
# 8             AQ  BAHIA DEL DIABLO     2665  2010            445.0
# 9             AQ  BAHIA DEL DIABLO     2665  2010            505.0
#
#    POINT_BALANCE
# 0        -3413.0
# 1        -1684.0
# 2          100.0
# 3          500.0
# 4          600.0
# 5          700.0
# 6          400.0
# 7          600.0
# 8         1000.0
# 9          600.0

# %%
clean_mass_b_point_df.describe()
# Out:
#              WGMS_ID          YEAR  POINT_ELEVATION  POINT_BALANCE
# count   57509.000000  57509.000000     49975.000000   57509.000000
# mean     1889.999878   2001.012607      2302.447308    -518.044268
# std     10177.366010     20.510469      1272.127269    1954.173294
# min         0.000000   1885.000000         0.000000  -22890.000000
# 25%       394.000000   1987.000000      1258.600000   -1690.000000
# 50%       732.000000   2009.000000      2593.000000    -210.000000
# 75%      1511.000000   2016.000000      3109.000000     786.000000
# max    216746.000000   2023.000000      6331.000000    8810.000000

# %%
clean_mass_b_point_df.isna().sum()
# Out:
# POLITICAL_UNIT        0
# NAME                  0
# WGMS_ID               0
# YEAR                  0
# POINT_ELEVATION    7534
# POINT_BALANCE         0
# dtype: int64

# %%
clean_mass_b_point_df['NAME'].value_counts()
# Out:
# NAME
# ABRAMOV                       6544
# TS.TUYUKSUYSKIY               4286
# GRIES                         2077
# WHITE                         2043
# SILVRETTA                     1888
#                               ...
# CHRISTIAN ERICHSEN ICE CAP       4
# NUUSSUAQ                         3
# SCHUCHERT                        2
# PIR YAKH                         2
# SERMIKAVSAK                      1
# Name: count, Length: 163, dtype: int64

# %%
copy_mass_b_point_df = clean_mass_b_point_df[clean_mass_b_point_df['NAME']=='SILVRETTA']
copy_mass_b_point_df.head(15)
# Out:
#       POLITICAL_UNIT       NAME  WGMS_ID  YEAR  POINT_ELEVATION  POINT_BALANCE
# 21679             CH  SILVRETTA      408  1920           2756.0         1870.0
# 21680             CH  SILVRETTA      408  1920           2756.0          540.0
# 21681             CH  SILVRETTA      408  1920           2756.0        -1330.0
# 21682             CH  SILVRETTA      408  1920           3009.0         2250.0
# 21683             CH  SILVRETTA      408  1920           3009.0          730.0
# 21684             CH  SILVRETTA      408  1920           3009.0        -1520.0
# 21685             CH  SILVRETTA      408  1921           3009.0          920.0
# 21686             CH  SILVRETTA      408  1921           3009.0         -980.0
# 21687             CH  SILVRETTA      408  1921           3009.0        -1900.0
# 21688             CH  SILVRETTA      408  1922           2756.0          810.0
# 21689             CH  SILVRETTA      408  1922           2756.0          470.0
# 21690             CH  SILVRETTA      408  1922           2756.0         -340.0
# 21691             CH  SILVRETTA      408  1922           3008.0         1220.0
# 21692             CH  SILVRETTA      408  1922           3008.0          520.0
# 21693             CH  SILVRETTA      408  1922           3008.0         -700.0

# %%
copy_mass_b_point_df['YEAR'].unique()
# Out:
# array([1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930,
#        1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941,
#        1942, 1943, 1944, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953,
#        1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964,
#        1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975,
#        1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1987, 1988,
#        1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999,
#        2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022])

# %%
# los años se repiten varias veces y hay muchos registros asi que haremos la media por año de POINT_ELEVATION:
mean_by_year = copy_mass_b_point_df.groupby('YEAR')['POINT_ELEVATION'].mean()
print(mean_by_year)
# Out:
# YEAR
# 1920    2882.500000
# 1921    3009.000000
# 1922    2882.000000
# 1923    2882.000000
# 1924    2882.000000
#            ...
# 2018    2719.052632
# 2019    2695.243902
# 2020    2732.437500
# 2021    2736.531250
# 2022    2746.000000
# Name: POINT_ELEVATION, Length: 99, dtype: float64

# %%
#hacemos una gráfica
plt.figure(figsize = (35,20))
plt.plot(mean_by_year, marker = 'o', linestyle='-')
plt.title('Media de elevación por año del glaciar SILVRETTA')
plt.xlabel('Año')
plt.ylabel('Elevación (m)')
plt.grid(True)
plt.xticks(copy_mass_b_point_df['YEAR'], rotation=90)
plt.show()

#comentario: tarda y se ve fatal hay que hacer zoom

# %%
plt.figure(figsize = (35,20))
plt.plot(copy_mass_b_point_df['POINT_BALANCE'], marker = 'o')
plt.title('Balance de masa medido en el punto de medición del glaciar SILVRETTA')
plt.grid(True)
plt.show()
# wow

# %%
# Filtrar los datos para obtener valores positivos y negativos de POINT_BALANCE
positive_values = copy_mass_b_point_df[copy_mass_b_point_df['POINT_BALANCE']>0]['POINT_BALANCE']
negative_values = copy_mass_b_point_df[copy_mass_b_point_df['POINT_BALANCE']<0]['POINT_BALANCE']

# Hacemos la gráfica
plt.figure(figsize=(10,6))
plt.hist(positive_values,color='blue', alpha=0.7, bins=20, label='Valores positivos del balance')
plt.hist(negative_values, color='red', alpha=0.7, bins=20, label='Valores Negativos del balance')

plt.xlabel('Balance de Masa (mm w.e.)')
plt.ylabel('Frecuencia')
plt.title('Histograma de Balance de Masa (Valores Positivos y Negativos)')
plt.legend()

plt.show()

# %%
# Vemos que hay más valores negativos que positivos. :(

# %% [markdown]
# ###🧊DATASET 7 **front_variation.csv**:
# - dataset resultante : **clean_front_variation_df**

# %%
# Vamos al siguiente dataset:
front_variation_df = pd.read_csv('/content/drive/MyDrive/DATASETS/front_variation.csv')
front_variation_df.head(15)
# Out:
#    POLITICAL_UNIT              NAME  WGMS_ID  YEAR  SURVEY_DATE  \
# 0              AQ             ADAMS      885  1989     19899999
# 1              AQ             ADAMS      885  1990     19909999
# 2              AQ  BAHIA DEL DIABLO     2665  2000     20009999
# 3              AQ  BAHIA DEL DIABLO     2665  2001     20019999
# 4              AQ  BAHIA DEL DIABLO     2665  2002     20029999
# 5              AQ  BAHIA DEL DIABLO     2665  2003     20039999
# 6              AQ  BAHIA DEL DIABLO     2665  2004     20049999
# 7              AQ  BAHIA DEL DIABLO     2665  2005     20059999
# 8              AQ  BAHIA DEL DIABLO     2665  2006     20069999
# 9              AQ  BAHIA DEL DIABLO     2665  2007     20079999
# 10             AQ  BAHIA DEL DIABLO     2665  2008     20089999
# 11             AQ  BAHIA DEL DIABLO     2665  2009     20090228
# 12             AQ  BAHIA DEL DIABLO     2665  2010     20100228
# 13             AQ  BAHIA DEL DIABLO     2665  2012     20129999
# 14             AQ  BAHIA DEL DIABLO     2665  2013     20139999
#
#     REFERENCE_DATE  FRONT_VARIATION  FRONT_VAR_UNC QUALITATIVE_VARIATION  \
# 0       19889999.0             -2.1            NaN                   NaN
# 1       19899999.0              0.0            NaN                   NaN
# 2       19999999.0              NaN            NaN                    ST
# 3       20009999.0              NaN            NaN                    ST
# 4       20019999.0              NaN            NaN                    ST
# 5       20029999.0              NaN            NaN                    ST
# 6       20039999.0              NaN            NaN                    ST
# 7       20049999.0              NaN            NaN                    ST
# 8       20059999.0              NaN            NaN                    ST
# 9       20069999.0              NaN            NaN                    ST
# 10      20079999.0              NaN            NaN                    ST
# 11      20080229.0              NaN            NaN                    ST
# 12      20090228.0              NaN            NaN                    ST
# 13      20119999.0              NaN            NaN                    ST
# 14      20129999.0              NaN            NaN                    ST
#
#    SURVEY_PLATFORM_METHOD                                       INVESTIGATOR  \
# 0                      cC                                                NaN
# 1                     NaN                                                NaN
# 2                      xX  Pedro Skvarca, Hernán De Angelis, Evgeniy Ermolin
# 3                      xX  Pedro Skvarca, Hernán De Angelis, Evgeniy Ermolin
# 4                      xX  Pedro Skvarca, Hernán De Angelis, Evgeniy Ermolin
# 5                      xX  Pedro Skvarca, Hernán De Angelis, Evgeniy Ermolin
# 6                      xX                     Pedro Skvarca, Evgeniy Ermolin
# 7                      xX                     Pedro Skvarca, Evgeniy Ermolin
# 8                      xX                     Pedro Skvarca, Evgeniy Ermolin
# 9                      xX                     Pedro Skvarca, Evgeniy Ermolin
# 10                     xX  Pedro Skvarca, Evgeniy Ermolin, Sebastián Mari...
# 11                     xX  Pedro Skvarca, Evgeniy Ermolin, Sebastián Mari...
# 12                     xX  Pedro Skvarca, Evgeniy Ermolin, Sebastián Mari...
# 13                     cG  Pedro Skvarca, Evgeniy Ermolin, Sebastián Mari...
# 14                     cG  Pedro Skvarca, Evgeniy Ermolin, Sebastián Mari...
#
#                                          SPONS_AGENCY  \
# 0                                                 NaN
# 1                                                 NaN
# 2   División Glaciología, Instituto Antártico Arge...
# 3   División Glaciología, Instituto Antártico Arge...
# 4   División Glaciología, Instituto Antártico Arge...
# 5   División Glaciología, Instituto Antártico Arge...
# 6   División Glaciología, Instituto Antártico Arge...
# 7   División Glaciología, Instituto Antártico Arge...
# 8   División Glaciología, Instituto Antártico Arge...
# 9   División Glaciología, Instituto Antártico Arge...
# 10  División Glaciología, Instituto Antártico Arge...
# 11  División Glaciología, Instituto Antártico Arge...
# 12  División Glaciología, Instituto Antártico Arge...
# 13  Departamento de Glaciología, Instituto Antárti...
# 14  Departamento de Glaciología, Instituto Antárti...
#
#                                REFERENCE  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 10                                   NaN
# 11                                   NaN
# 12                                   NaN
# 13  WGMS (2015): GGCB No. 1 (2012-2013).
# 14  WGMS (2015): GGCB No. 1 (2012-2013).
#
#                                               REMARKS
# 0                                                 NaN
# 1                                                 NaN
# 2   Survey Method: Combination of Geodetic ground ...
# 3   Survey Method: Combination of Geodetic ground ...
# 4   Survey Method: Combination of Geodetic ground ...
# 5   Survey Method: Combination of Geodetic ground ...
# 6   Survey Method: Combination of Geodetic ground ...
# 7   Survey Method: Combination of Geodetic ground ...
# 8   Survey Method: Combination of Geodetic ground ...
# 9   Survey Method: Combination of Geodetic ground ...
# 10  Survey Method: Combination of Geodetic ground ...
# 11  Survey Method: Combination of Geodetic ground ...
# 12  Survey Method: Combination of Geodetic ground ...
# 13  Survey Method: Combination of Geodetic ground ...
# 14  Survey Method: Combination of Geodetic ground ...

# %%
front_variation_df.isna().sum()
# Out:
# POLITICAL_UNIT                0
# NAME                          0
# WGMS_ID                       0
# YEAR                          0
# SURVEY_DATE                   0
# REFERENCE_DATE              768
# FRONT_VARIATION            3791
# FRONT_VAR_UNC             40773
# QUALITATIVE_VARIATION     43149
# SURVEY_PLATFORM_METHOD    31622
# INVESTIGATOR              28375
# SPONS_AGENCY              34024
# REFERENCE                 23157
# REMARKS                   40614
# dtype: int64

# %%
# nos quedaremos con las siguientes columnas:
fv_columns = ['POLITICAL_UNIT', 'NAME', 'WGMS_ID', 'YEAR', 'FRONT_VARIATION',
       'QUALITATIVE_VARIATION']
clean_front_variation_df = pd.DataFrame()
for column in fv_columns:
    clean_front_variation_df [column] = front_variation_df[column]

clean_front_variation_df .head(15)
# Out:
#    POLITICAL_UNIT              NAME  WGMS_ID  YEAR  FRONT_VARIATION  \
# 0              AQ             ADAMS      885  1989             -2.1
# 1              AQ             ADAMS      885  1990              0.0
# 2              AQ  BAHIA DEL DIABLO     2665  2000              NaN
# 3              AQ  BAHIA DEL DIABLO     2665  2001              NaN
# 4              AQ  BAHIA DEL DIABLO     2665  2002              NaN
# 5              AQ  BAHIA DEL DIABLO     2665  2003              NaN
# 6              AQ  BAHIA DEL DIABLO     2665  2004              NaN
# 7              AQ  BAHIA DEL DIABLO     2665  2005              NaN
# 8              AQ  BAHIA DEL DIABLO     2665  2006              NaN
# 9              AQ  BAHIA DEL DIABLO     2665  2007              NaN
# 10             AQ  BAHIA DEL DIABLO     2665  2008              NaN
# 11             AQ  BAHIA DEL DIABLO     2665  2009              NaN
# 12             AQ  BAHIA DEL DIABLO     2665  2010              NaN
# 13             AQ  BAHIA DEL DIABLO     2665  2012              NaN
# 14             AQ  BAHIA DEL DIABLO     2665  2013              NaN
#
#    QUALITATIVE_VARIATION
# 0                    NaN
# 1                    NaN
# 2                     ST
# 3                     ST
# 4                     ST
# 5                     ST
# 6                     ST
# 7                     ST
# 8                     ST
# 9                     ST
# 10                    ST
# 11                    ST
# 12                    ST
# 13                    ST
# 14                    ST

# %%
clean_front_variation_df.describe()
# Out:
#              WGMS_ID          YEAR  FRONT_VARIATION
# count   47087.000000  47087.000000     43296.000000
# mean     1370.812815   1971.504959       -45.858502
# std      3315.182603     33.111879       361.842636
# min         0.000000   1705.000000    -17854.000000
# 25%       447.000000   1949.000000       -24.000000
# 50%       620.000000   1976.000000        -9.000000
# 75%      1512.000000   1998.000000        -1.500000
# max    216746.000000   2023.000000     11900.000000

# %%
# Según la documentación, vamos a aplicar que si el contenido de 'FRON_VARIATION' es NaN, pero el de QUALITATIVE_VARIATION es ST (estable), front variation será 0.
clean_front_variation_df.loc[(clean_front_variation_df['FRONT_VARIATION'].isna()) & (clean_front_variation_df ['QUALITATIVE_VARIATION']=='ST'),'FRONT_VARIATION'] = 0.0
clean_front_variation_df.loc[(clean_front_variation_df['FRONT_VARIATION']>0) & (clean_front_variation_df ['QUALITATIVE_VARIATION'].isna()),'QUALITATIVE_VARIATION'] = '+X'
clean_front_variation_df.loc[(clean_front_variation_df['FRONT_VARIATION']<0) & (clean_front_variation_df ['QUALITATIVE_VARIATION'].isna()),'QUALITATIVE_VARIATION'] = '-X'
clean_front_variation_df.loc[(clean_front_variation_df['FRONT_VARIATION']==0) & (clean_front_variation_df ['QUALITATIVE_VARIATION'].isna()),'QUALITATIVE_VARIATION'] = 'ST'
clean_front_variation_df.head(25)
# Out:
#    POLITICAL_UNIT              NAME  WGMS_ID  YEAR  FRONT_VARIATION  \
# 0              AQ             ADAMS      885  1989             -2.1
# 1              AQ             ADAMS      885  1990              0.0
# 2              AQ  BAHIA DEL DIABLO     2665  2000              0.0
# 3              AQ  BAHIA DEL DIABLO     2665  2001              0.0
# 4              AQ  BAHIA DEL DIABLO     2665  2002              0.0
# 5              AQ  BAHIA DEL DIABLO     2665  2003              0.0
# 6              AQ  BAHIA DEL DIABLO     2665  2004              0.0
# 7              AQ  BAHIA DEL DIABLO     2665  2005              0.0
# 8              AQ  BAHIA DEL DIABLO     2665  2006              0.0
# 9              AQ  BAHIA DEL DIABLO     2665  2007              0.0
# 10             AQ  BAHIA DEL DIABLO     2665  2008              0.0
# 11             AQ  BAHIA DEL DIABLO     2665  2009              0.0
# 12             AQ  BAHIA DEL DIABLO     2665  2010              0.0
# 13             AQ  BAHIA DEL DIABLO     2665  2012              0.0
# 14             AQ  BAHIA DEL DIABLO     2665  2013              0.0
# 15             AQ  BAHIA DEL DIABLO     2665  2014              0.0
# 16             AQ  BAHIA DEL DIABLO     2665  2015              0.0
# 17             AQ  BAHIA DEL DIABLO     2665  2016              0.0
# 18             AQ  BAHIA DEL DIABLO     2665  2017              0.0
# 19             AQ  BAHIA DEL DIABLO     2665  2020              0.0
# 20             AQ  BAHIA DEL DIABLO     2665  2022           -100.0
# 21             AQ           BARTLEY      893  1984             -0.3
# 22             AQ           BARTLEY      893  1985             -0.7
# 23             AQ           BARTLEY      893  1986              0.2
# 24             AQ           BARTLEY      893  1987              0.5
#
#    QUALITATIVE_VARIATION
# 0                     -X
# 1                     ST
# 2                     ST
# 3                     ST
# 4                     ST
# 5                     ST
# 6                     ST
# 7                     ST
# 8                     ST
# 9                     ST
# 10                    ST
# 11                    ST
# 12                    ST
# 13                    ST
# 14                    ST
# 15                    ST
# 16                    ST
# 17                    ST
# 18                    ST
# 19                    ST
# 20                    -X
# 21                    -X
# 22                    -X
# 23                    +X
# 24                    +X

# %%
clean_front_variation_df  = clean_front_variation_df [clean_front_variation_df ['FRONT_VARIATION'].notnull()]

# %%
clean_front_variation_df ['NAME'].value_counts()
# Out:
# NAME
# OE. WURTEN K.     171
# GOLDBERG K.       171
# KLEINFLEISS K.    170
# PASTERZE          145
# RHONE             141
#                  ...
# NO 43               1
# NO 44               1
# NO 45               1
# NO 46               1
# NO 202              1
# Name: count, Length: 2488, dtype: int64

# %%
clean_front_variation_df  = clean_front_variation_df [clean_front_variation_df ['NAME'] == 'GOLDBERG K.']
clean_front_variation_df.head(15)
# Out:
#      POLITICAL_UNIT         NAME  WGMS_ID  YEAR  FRONT_VARIATION  \
# 2349             AT  GOLDBERG K.     1305  1850              0.0
# 2350             AT  GOLDBERG K.     1305  1851              0.0
# 2351             AT  GOLDBERG K.     1305  1852              0.0
# 2352             AT  GOLDBERG K.     1305  1853              0.0
# 2353             AT  GOLDBERG K.     1305  1854              0.0
# 2354             AT  GOLDBERG K.     1305  1855              0.0
# 2355             AT  GOLDBERG K.     1305  1856              0.0
# 2356             AT  GOLDBERG K.     1305  1857              0.0
# 2357             AT  GOLDBERG K.     1305  1858              0.0
# 2358             AT  GOLDBERG K.     1305  1859              0.0
# 2359             AT  GOLDBERG K.     1305  1860              0.0
# 2360             AT  GOLDBERG K.     1305  1861              0.0
# 2361             AT  GOLDBERG K.     1305  1862              0.0
# 2362             AT  GOLDBERG K.     1305  1863              0.0
# 2363             AT  GOLDBERG K.     1305  1864              0.0
#
#      QUALITATIVE_VARIATION
# 2349                    ST
# 2350                    ST
# 2351                    ST
# 2352                    ST
# 2353                    ST
# 2354                    ST
# 2355                    ST
# 2356                    ST
# 2357                    ST
# 2358                    ST
# 2359                    ST
# 2360                    ST
# 2361                    ST
# 2362                    ST
# 2363                    ST

# %%
# vamos a hacer una gráfica con el glaciar GOLDBERG K. para ver la cantidad de veces que ha retrocedido, avanzado o se ha quedado estable.
# Filtrar los datos para obtener valores positivos y negativos de POINT_BALANCE
valores_pos = clean_front_variation_df [clean_front_variation_df ['FRONT_VARIATION']>0]['FRONT_VARIATION']
valores_neg = clean_front_variation_df [clean_front_variation_df ['FRONT_VARIATION']<0]['FRONT_VARIATION']
valores_est = clean_front_variation_df [clean_front_variation_df ['FRONT_VARIATION']== 0.0]['FRONT_VARIATION']
# Hacemos la gráfica
plt.figure(figsize=(10,6))
plt.hist(valores_pos,color='blue', alpha=0.7, bins=20, label='Valores de avance')
plt.hist(valores_neg, color='red', alpha=0.7, bins=20, label='Valores de retroceso')
plt.hist(valores_est, color='green', alpha=0.7, bins=20, label='Valores estáticos')
plt.xlabel('Balance variación frontal')
plt.ylabel('Frecuencia')
plt.title('Histograma de Balance variación frontal cualitativa del glaciar GOLDBERG K.')
plt.legend()

plt.show()

# %%
# El siguiente dataset lo uniremos con este último ya que están claramente interconectados.

# %% [markdown]
# ###🧊DATASET 8 **reconstruction_front_variation.csv**:
# dataset resultante : **clean_rec_front_variation_df**

# %%
rec_front_variation_df = pd.read_csv('/content/drive/MyDrive/DATASETS/reconstruction_front_variation.csv')
rec_front_variation_df.head(15)
# Out:
#    POLITICAL_UNIT             NAME  WGMS_ID  REC_SERIES_ID  YEAR  YEAR_UNC  \
# 0              AR         AMEGHINO     3800              9  1765     100.0
# 1              AR         AMEGHINO     3800              9  1947       0.0
# 2              AR         AMEGHINO     3800              9  1970       0.0
# 3              AR         AMEGHINO     3800              9  1986       0.0
# 4              AR         AMEGHINO     3800              9  2000       0.0
# 5              AR         AMEGHINO     3800              9  2005       0.0
# 6              AR  ESPERANZA NORTE     3711             10  1691       NaN
# 7              AR  ESPERANZA NORTE     3711             10  1792       NaN
# 8              AR  ESPERANZA NORTE     3711             10  1795       NaN
# 9              AR  ESPERANZA NORTE     3711             10  1807       NaN
# 10             AR  ESPERANZA NORTE     3711             10  1830       NaN
# 11             AR  ESPERANZA NORTE     3711             10  1876       NaN
# 12             AR  ESPERANZA NORTE     3711             10  1927       NaN
# 13             AR  ESPERANZA NORTE     3711             10  1933       NaN
# 14             AR  ESPERANZA NORTE     3711             10  1951       NaN
#
#     REFERENCE_YEAR  REF_YEAR_UNC  FRONT_VARIATION QUALITATIVE_VARIATION  \
# 0              NaN           NaN              NaN                    +X
# 1           1765.0         100.0           -170.0                   NaN
# 2           1947.0           0.0           -160.0                   NaN
# 3           1970.0           0.0          -3600.0                   NaN
# 4           1986.0           0.0           -500.0                   NaN
# 5           2000.0           0.0           -390.0                   NaN
# 6           1652.0           NaN           -130.0                   NaN
# 7           1691.0           NaN           -210.0                   NaN
# 8           1792.0           NaN            100.0                   NaN
# 9           1795.0           NaN           -120.0                   NaN
# 10          1807.0           NaN             10.0                   NaN
# 11          1830.0           NaN           -280.0                   NaN
# 12          1876.0           NaN           -610.0                   NaN
# 13          1927.0           NaN           -350.0                   NaN
# 14          1933.0           NaN           -650.0                   NaN
#
#     FRONT_VAR_POS_UNC  FRONT_VAR_NEG_UNC  LOWEST_ELEVATION  HIGHEST_ELEVATION  \
# 0                 NaN                NaN               NaN                NaN
# 1                15.0               50.0               NaN                NaN
# 2                15.0               15.0               NaN                NaN
# 3                15.0               15.0               NaN                NaN
# 4                15.0               15.0               NaN                NaN
# 5                15.0               15.0               NaN                NaN
# 6                 NaN                NaN               NaN                NaN
# 7                 NaN                NaN               NaN                NaN
# 8                 NaN                NaN               NaN                NaN
# 9                 NaN                NaN               NaN                NaN
# 10                NaN                NaN               NaN                NaN
# 11                NaN                NaN               NaN                NaN
# 12                NaN                NaN               NaN                NaN
# 13                NaN                NaN               NaN                NaN
# 14                NaN                NaN               NaN                NaN
#
#     ELEVATION_UNC MORAINE_DEFINED_MAX METHOD_CODE  \
# 0             NaN                 MPE         RAD
# 1             NaN                 NaN         PHO
# 2             NaN                 NaN         PHO
# 3             NaN                 NaN         OTH
# 4             NaN                 NaN         OTH
# 5             NaN                 NaN         OTH
# 6             NaN                 NaN         DEN
# 7             NaN                 NaN         DEN
# 8             NaN                 NaN         DEN
# 9             NaN                 NaN         DEN
# 10            NaN                 NaN         DEN
# 11            NaN                 NaN         DEN
# 12            NaN                 NaN         DEN
# 13            NaN                 NaN         DEN
# 14            NaN                 NaN         OTH
#
#                                        METHOD_REMARKS  \
# 0   Radiocarbon dating of in situ stumps buried by...
# 1   Glacier front position identified in 1947 air ...
# 2   Glacier front position identified in 1970 air ...
# 3   Glacier front position identified in 1986 Land...
# 4   Glacier front position identified in 2000 Land...
# 5   Glacier front position identified in 2005 ASTE...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                 direct measurement
#
#                                               REMARKS
# 0   YEAR: Estimated date of formation of frontal m...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN

# %%
# Nos quedamos con las columnas que nos sirven:
rec_fv_columns = ['POLITICAL_UNIT', 'NAME', 'WGMS_ID', 'YEAR','rec_FRONT_VARIATION', 'rec_QUALITATIVE_VARIATION','LOWEST_ELEVATION', 'HIGHEST_ELEVATION']

clean_rec_front_variation_df = pd.DataFrame()
for col in rec_fv_columns:
  clean_rec_front_variation_df[col] = rec_front_variation_df[col.replace('rec_','')]

clean_rec_front_variation_df.head(20)
# Out:
#    POLITICAL_UNIT             NAME  WGMS_ID  YEAR  rec_FRONT_VARIATION  \
# 0              AR         AMEGHINO     3800  1765                  NaN
# 1              AR         AMEGHINO     3800  1947               -170.0
# 2              AR         AMEGHINO     3800  1970               -160.0
# 3              AR         AMEGHINO     3800  1986              -3600.0
# 4              AR         AMEGHINO     3800  2000               -500.0
# 5              AR         AMEGHINO     3800  2005               -390.0
# 6              AR  ESPERANZA NORTE     3711  1691               -130.0
# 7              AR  ESPERANZA NORTE     3711  1792               -210.0
# 8              AR  ESPERANZA NORTE     3711  1795                100.0
# 9              AR  ESPERANZA NORTE     3711  1807               -120.0
# 10             AR  ESPERANZA NORTE     3711  1830                 10.0
# 11             AR  ESPERANZA NORTE     3711  1876               -280.0
# 12             AR  ESPERANZA NORTE     3711  1927               -610.0
# 13             AR  ESPERANZA NORTE     3711  1933               -350.0
# 14             AR  ESPERANZA NORTE     3711  1951               -650.0
# 15             AR  ESPERANZA NORTE     3711  1958               -100.0
# 16             AR  ESPERANZA NORTE     3711  1972               -200.0
# 17             AR  ESPERANZA NORTE     3711  1978                140.0
# 18             AR  ESPERANZA NORTE     3711  1987               -150.0
# 19             AR  ESPERANZA NORTE     3711  1996               -290.0
#
#    rec_QUALITATIVE_VARIATION  LOWEST_ELEVATION  HIGHEST_ELEVATION
# 0                         +X               NaN                NaN
# 1                        NaN               NaN                NaN
# 2                        NaN               NaN                NaN
# 3                        NaN               NaN                NaN
# 4                        NaN               NaN                NaN
# 5                        NaN               NaN                NaN
# 6                        NaN               NaN                NaN
# 7                        NaN               NaN                NaN
# 8                        NaN               NaN                NaN
# 9                        NaN               NaN                NaN
# 10                       NaN               NaN                NaN
# 11                       NaN               NaN                NaN
# 12                       NaN               NaN                NaN
# 13                       NaN               NaN                NaN
# 14                       NaN               NaN                NaN
# 15                       NaN               NaN                NaN
# 16                       NaN               NaN                NaN
# 17                       NaN               NaN                NaN
# 18                       NaN               NaN                NaN
# 19                       NaN               NaN                NaN

# %%
# Rellenaremos los huecos igual que el anterior:
clean_rec_front_variation_df.loc[(clean_rec_front_variation_df['rec_FRONT_VARIATION']<0) & (clean_rec_front_variation_df['rec_QUALITATIVE_VARIATION'].isna()),'rec_QUALITATIVE_VARIATION'] = '-X'
clean_rec_front_variation_df.loc[(clean_rec_front_variation_df['rec_FRONT_VARIATION']>0) & (clean_rec_front_variation_df['rec_QUALITATIVE_VARIATION'].isna()),'rec_QUALITATIVE_VARIATION'] = '+X'
clean_rec_front_variation_df.loc[(clean_rec_front_variation_df['rec_FRONT_VARIATION']==0) & (clean_rec_front_variation_df['rec_QUALITATIVE_VARIATION'].isna()),'rec_QUALITATIVE_VARIATION'] = 'ST'
clean_rec_front_variation_df.loc[(clean_rec_front_variation_df['rec_FRONT_VARIATION'].isna()) & (clean_rec_front_variation_df['rec_QUALITATIVE_VARIATION']=='ST'),'rec_FRONT_VARIATION'] = 0.0

clean_rec_front_variation_df.head(25)
# Out:
#    POLITICAL_UNIT             NAME  WGMS_ID  YEAR  rec_FRONT_VARIATION  \
# 0              AR         AMEGHINO     3800  1765                  NaN
# 1              AR         AMEGHINO     3800  1947               -170.0
# 2              AR         AMEGHINO     3800  1970               -160.0
# 3              AR         AMEGHINO     3800  1986              -3600.0
# 4              AR         AMEGHINO     3800  2000               -500.0
# 5              AR         AMEGHINO     3800  2005               -390.0
# 6              AR  ESPERANZA NORTE     3711  1691               -130.0
# 7              AR  ESPERANZA NORTE     3711  1792               -210.0
# 8              AR  ESPERANZA NORTE     3711  1795                100.0
# 9              AR  ESPERANZA NORTE     3711  1807               -120.0
# 10             AR  ESPERANZA NORTE     3711  1830                 10.0
# 11             AR  ESPERANZA NORTE     3711  1876               -280.0
# 12             AR  ESPERANZA NORTE     3711  1927               -610.0
# 13             AR  ESPERANZA NORTE     3711  1933               -350.0
# 14             AR  ESPERANZA NORTE     3711  1951               -650.0
# 15             AR  ESPERANZA NORTE     3711  1958               -100.0
# 16             AR  ESPERANZA NORTE     3711  1972               -200.0
# 17             AR  ESPERANZA NORTE     3711  1978                140.0
# 18             AR  ESPERANZA NORTE     3711  1987               -150.0
# 19             AR  ESPERANZA NORTE     3711  1996               -290.0
# 20             AR  ESPERANZA NORTE     3711  2001               -320.0
# 21             AR  ESPERANZA NORTE     3711  2007               -220.0
# 22             AR            FRIAS     1347  1639                  NaN
# 23             AR            FRIAS     1347  1727               -262.0
# 24             AR            FRIAS     1347  1752                -54.0
#
#    rec_QUALITATIVE_VARIATION  LOWEST_ELEVATION  HIGHEST_ELEVATION
# 0                         +X               NaN                NaN
# 1                         -X               NaN                NaN
# 2                         -X               NaN                NaN
# 3                         -X               NaN                NaN
# 4                         -X               NaN                NaN
# 5                         -X               NaN                NaN
# 6                         -X               NaN                NaN
# 7                         -X               NaN                NaN
# 8                         +X               NaN                NaN
# 9                         -X               NaN                NaN
# 10                        +X               NaN                NaN
# 11                        -X               NaN                NaN
# 12                        -X               NaN                NaN
# 13                        -X               NaN                NaN
# 14                        -X               NaN                NaN
# 15                        -X               NaN                NaN
# 16                        -X               NaN                NaN
# 17                        +X               NaN                NaN
# 18                        -X               NaN                NaN
# 19                        -X               NaN                NaN
# 20                        -X               NaN                NaN
# 21                        -X               NaN                NaN
# 22                        +X               NaN                NaN
# 23                        -X               NaN                NaN
# 24                        -X               NaN                NaN

# %%
clean_rec_front_variation_df['LOWEST_ELEVATION'].notna().sum()
# Out:
# 1

# %%
clean_rec_front_variation_df['HIGHEST_ELEVATION'].notna().sum()
# Out:
# 1

# %%
# Literal esto no ha servido de nada en fin

# %% [markdown]
# ### 💥💥 MERGEAMOS🧊🧊 DATASET 7 Y 8
# - front_variation + reconstruction_front_variation.csv
# - dataset resultante: clean_special_event_df: **front_variation_merged**

# %%
# mergeamos los dos datasets en base al campo nombre y el campo año.
front_variation_merged = pd.merge(clean_front_variation_df, clean_rec_front_variation_df, on=['NAME', 'YEAR', 'POLITICAL_UNIT','WGMS_ID'], suffixes=('_fv', '_rec_fv'))
front_variation_merged.head(25)
# Out:
# Empty DataFrame
# Columns: [POLITICAL_UNIT, NAME, WGMS_ID, YEAR, FRONT_VARIATION, QUALITATIVE_VARIATION, rec_FRONT_VARIATION, rec_QUALITATIVE_VARIATION, LOWEST_ELEVATION, HIGHEST_ELEVATION]
# Index: []

# %%
#esto siguiente es para añadirle el prefijo al año
#fv_merged['fv_YEAR'] = fv_merged['YEAR']

# %%
front_variation_merged.head(15)
# Out:
# Empty DataFrame
# Columns: [POLITICAL_UNIT, NAME, WGMS_ID, YEAR, FRONT_VARIATION, QUALITATIVE_VARIATION, rec_FRONT_VARIATION, rec_QUALITATIVE_VARIATION, LOWEST_ELEVATION, HIGHEST_ELEVATION]
# Index: []

# %%
front_variation_merged.drop(columns='YEAR')
# Out:
# Empty DataFrame
# Columns: [POLITICAL_UNIT, NAME, WGMS_ID, FRONT_VARIATION, QUALITATIVE_VARIATION, rec_FRONT_VARIATION, rec_QUALITATIVE_VARIATION, LOWEST_ELEVATION, HIGHEST_ELEVATION]
# Index: []

# %% [markdown]
# ###🧊DATASET 9 **special_event.csv**:
# - dataset resultante: **clean_special_event_df**

# %%
# Último csv:
special_event_df = pd.read_csv('/content/drive/MyDrive/DATASETS/special_event.csv')
special_event_df.head(25)
# Out:
#    POLITICAL_UNIT                                NAME  WGMS_ID  EVENT_ID  \
# 0              AF                       UNNAMED 25830    26359      3443
# 1              AQ                               NO 38     4037       344
# 2              AR                      ALTO DEL PLOMO      922       133
# 3              AR                              AZUFRE     2851      3428
# 4              AR        CERRO MARMOLEJO EAST GLACIER     8171       594
# 5              AR                     COLINA (COLINO)     8170       593
# 6              AR              EAST OF CERRO POLLERAS     8169       592
# 7              AR                               FRIAS     1347      3444
# 8              AR                           GLACIER B     8173      1152
# 9              AR  GRANDE DEL JUNCAL GLACIER JUNCAL I     8166       588
# 10             AR  GRANDE DEL JUNCAL GLACIER JUNCAL I     8166       589
# 11             AR         GRANDE DEL NEVADO DEL PLOMO     3304        97
# 12             AR         GRANDE DEL NEVADO DEL PLOMO     3304       220
# 13             AR         GRANDE DEL NEVADO DEL PLOMO     3304       582
# 14             AR         GRANDE DEL NEVADO DEL PLOMO     3304       583
# 15             AR         GRANDE DEL NEVADO DEL PLOMO     3304       584
# 16             AR         GRANDE DEL NEVADO DEL PLOMO     3304       585
# 17             AR         GRANDE DEL NEVADO DEL PLOMO     3304      3445
# 18             AR         GRANDE DEL NEVADO DEL PLOMO     3304      3446
# 19             AR         GRANDE DEL NEVADO DEL PLOMO     3304      3447
# 20             AR         GRANDE DEL NEVADO DEL PLOMO     3304      3448
# 21             AR                   HORCONES INFERIOR      919        52
# 22             AR                   HORCONES INFERIOR      919       174
# 23             AR                           INNOMIATE     8167       590
# 24             AR                              LAGUNA     8164      1150
#
#     EVENT_DATE  ET_SURGE  ET_CALVING  ET_FLOOD  ET_AVALANCHE  ET_TECTONIC  \
# 0   20180712.0     False       False      True         False        False
# 1   19909999.0      True       False     False         False        False
# 2   19841114.0      True       False      True         False        False
# 3   20181214.0     False       False     False         False         True
# 4          NaN      True       False     False         False        False
# 5   19379999.0      True       False     False         False        False
# 6          NaN      True       False     False         False        False
# 7   19429999.0     False       False      True         False        False
# 8   19869999.0      True       False     False         False        False
# 9   19559999.0      True       False     False         False        False
# 10  19109999.0      True       False     False         False        False
# 11  19340110.0      True       False      True         False        False
# 12  20079999.0      True       False     False         False        False
# 13  17869999.0      True       False     False         False        False
# 14  19129999.0      True       False     False         False        False
# 15  19749999.0      True       False     False         False        False
# 16  19849999.0      True       False     False         False        False
# 17  17880102.0     False       False      True         False        False
# 18  19340111.0     False       False      True         False        False
# 19  19870301.0     False       False      True         False        False
# 20  19849999.0     False       False      True         False        False
# 21  19849999.0      True       False     False         False        False
# 22  20040209.0      True       False     False         False        False
# 23  19919999.0      True       False     False         False        False
# 24  19829999.0      True       False     False         False        False
#
#     ET_OTHER                                  EVENT_DESCRIPTION  \
# 0      False  On July 12, 2018 a GLOF took place in Peshghar...
# 1      False  The Oktyabr'sky glacier surged for an estimate...
# 2      False  On 14 November 1984, Rio del Plomo was dammed ...
# 3      False  Between 14/12/2018 and 15/01/2018 eruptive act...
# 4      False  Event description from Sevestre & Benn (2015):...
# 5      False  Event description from Sevestre & Benn (2015):...
# 6      False  Event description from Sevestre & Benn (2015):...
# 7      False  Between 1942 and Between 1942 and 1953, a GLOF...
# 8      False  Event description from Sevestre & Benn (2015):...
# 9      False  Event description from Sevestre & Benn (2015):...
# 10     False  Event description from Sevestre & Benn (2015):...
# 11     False  The flood of 10 January 1934 had a peak discha...
# 12     False  The Grande del Nevado glacier had a new surge ...
# 13     False  Event description from Sevestre & Benn (2015):...
# 14     False  Event description from Sevestre & Benn (2015):...
# 15     False  Event description from Sevestre & Benn (2015):...
# 16     False  Event description from Sevestre & Benn (2015):...
# 17     False  On January 2, 1788 a GLOF took place in Grande...
# 18     False  On January 1, 1934 a GLOF took place in Grande...
# 19     False  On March 1, 1987 a GLOF took place in Grande D...
# 20     False  In 1984, a GLOF took place in Grande del Nevad...
# 21     False  The Horcones Inferior glacier is located at 32...
# 22     False  The Horcones Inferior glacier is located at 32...
# 23     False  Event description from Sevestre & Benn (2015):...
# 24     False  Event description from Sevestre & Benn (2015):...
#
#                                 INVESTIGATOR  \
# 0       Sudan Bikash Maharjan; UNITAR; USAID
# 1                                        NaN
# 2                                        NaN
# 3                Pierre Pitte, Laura Zalazar
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7   Jonathan L. Carrivick and Fiona S. Tweed
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# 17  Jonathan L. Carrivick and Fiona S. Tweed
# 18  Jonathan L. Carrivick and Fiona S. Tweed
# 19  Jonathan L. Carrivick and Fiona S. Tweed
# 20                   Stephan Harrison et al.
# 21                                       NaN
# 22                                       NaN
# 23                                       NaN
# 24                                       NaN
#
#                                          SPONS_AGENCY  \
# 0   International Centre for Integrated Mountain D...
# 1                                                 NaN
# 2                                                 NaN
# 3                                     IANIGLA-CONICET
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   School of Geography, University of Leeds, Wood...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  School of Geography, University of Leeds, Wood...
# 18  School of Geography, University of Leeds, Wood...
# 19  School of Geography, University of Leeds, Wood...
# 20  University of Exeter, Prince of Wales Road, Ex...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#                                             REFERENCE  \
# 0   Maharjan (2018): Peshghor Flood in Khenj Distr...
# 1                                     Kotlakov (2008)
# 2   Espizua, L. E., Bengochea, J. D. (1990): Surge...
# 3                                                 NaN
# 4   Event description, Surge Diagnostic features a...
# 5   Event description, Surge Diagnostic features a...
# 6   Event description, Surge Diagnostic features a...
# 7   Carrivick, J. L. and Tweed, F. S. (2016). A gl...
# 8   Event description, Surge Diagnostic features a...
# 9   Event description, Surge Diagnostic features a...
# 10  Event description, Surge Diagnostic features a...
# 11  Espizua, L., 1986: Geografiska Annaler, 68 A, ...
# 12  Espizua, L., 1986: Geografiska Annaler, 68 A, ...
# 13  Espizua, L., 1986: Geografiska Annaler, 68 A, ...
# 14  Espizua, L., 1986: Geografiska Annaler, 68 A, ...
# 15  Espizua, L., 1986: Geografiska Annaler, 68 A, ...
# 16  Espizua, L., 1986: Geografiska Annaler, 68 A, ...
# 17  Carrivick, J. L. and Tweed, F. S. (2016). A gl...
# 18  Carrivick, J. L. and Tweed, F. S. (2016). A gl...
# 19  Carrivick, J. L. and Tweed, F. S. (2016). A gl...
# 20  Harrison, S. et al. (2018); Climate change and...
# 21  Happoldt H. and Schrott, L. in: WGMS (1993): F...
# 22  Happoldt H. and Schrott, L. in: WGMS (1993): F...
# 23  Event description, Surge Diagnostic features a...
# 24  Event description, Surge Diagnostic features a...
#
#                                               REMARKS
# 0                                                 NaN
# 1                                           1985-1990
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                   surge onset: 1985
# 9                                   surge onset: 1934
# 10                                                NaN
# 11                                                NaN
# 12  Data reported by Lidia Ferri Hidalgo. Earlier ...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  The data come the database of glacier and perm...
# 21  The potential hazard of the Horcones Inferior ...
# 22  Satellite image data was processed by Pierre P...
# 23                                  surge onset: 1986
# 24                                  surge onset: 1970

# %%
# Nos quedaremos solo con las columnas necesarias, y como en este csv no hay columna 'YEAR' aplicaremos la función 'solo_año' para tener una referencia igual en todas.

se_columns = ['POLITICAL_UNIT', 'NAME', 'WGMS_ID', 'YEAR',
       'ET_SURGE', 'ET_CALVING', 'ET_FLOOD', 'ET_AVALANCHE', 'ET_TECTONIC',
       'ET_OTHER']

clean_special_event_df = pd.DataFrame()

for column in se_columns:
  if column == 'YEAR':
    clean_special_event_df[column] = special_event_df['EVENT_DATE']
  else:
    clean_special_event_df[column] = special_event_df[column]

clean_special_event_df['YEAR'] = clean_special_event_df['YEAR'].apply(only_year)
clean_special_event_df.head(15)
# Out:
#    POLITICAL_UNIT                                NAME  WGMS_ID  YEAR  \
# 0              AF                       UNNAMED 25830    26359  2018
# 1              AQ                               NO 38     4037  1990
# 2              AR                      ALTO DEL PLOMO      922  1984
# 3              AR                              AZUFRE     2851  2018
# 4              AR        CERRO MARMOLEJO EAST GLACIER     8171   nan
# 5              AR                     COLINA (COLINO)     8170  1937
# 6              AR              EAST OF CERRO POLLERAS     8169   nan
# 7              AR                               FRIAS     1347  1942
# 8              AR                           GLACIER B     8173  1986
# 9              AR  GRANDE DEL JUNCAL GLACIER JUNCAL I     8166  1955
# 10             AR  GRANDE DEL JUNCAL GLACIER JUNCAL I     8166  1910
# 11             AR         GRANDE DEL NEVADO DEL PLOMO     3304  1934
# 12             AR         GRANDE DEL NEVADO DEL PLOMO     3304  2007
# 13             AR         GRANDE DEL NEVADO DEL PLOMO     3304  1786
# 14             AR         GRANDE DEL NEVADO DEL PLOMO     3304  1912
#
#     ET_SURGE  ET_CALVING  ET_FLOOD  ET_AVALANCHE  ET_TECTONIC  ET_OTHER
# 0      False       False      True         False        False     False
# 1       True       False     False         False        False     False
# 2       True       False      True         False        False     False
# 3      False       False     False         False         True     False
# 4       True       False     False         False        False     False
# 5       True       False     False         False        False     False
# 6       True       False     False         False        False     False
# 7      False       False      True         False        False     False
# 8       True       False     False         False        False     False
# 9       True       False     False         False        False     False
# 10      True       False     False         False        False     False
# 11      True       False      True         False        False     False
# 12      True       False     False         False        False     False
# 13      True       False     False         False        False     False
# 14      True       False     False         False        False     False

# %%
# Filtra las filas correspondientes al año 2010
clean_special_event_df_2010 = clean_special_event_df[clean_special_event_df['YEAR'] == '2010']

# Contar el número de ocurrencias de cada tipo de evento en el año 2018
flood_count = clean_special_event_df_2010['ET_FLOOD'].sum()
surge_count = clean_special_event_df_2010['ET_SURGE'].sum()
calving_count = clean_special_event_df_2010['ET_CALVING'].sum()
avalanche_count = clean_special_event_df_2010['ET_AVALANCHE'].sum()
tectonic_count = clean_special_event_df_2010['ET_TECTONIC'].sum()
other_count = clean_special_event_df_2010['ET_OTHER'].sum()

# Crear el histograma
plt.figure(figsize=(10,6))
plt.bar(['Flood', 'Surge', 'Calving', 'Avalanche', 'Tectonic', 'Other'],
        [flood_count, surge_count, calving_count, avalanche_count, tectonic_count, other_count],
        color=['blue', 'red', 'green', 'yellow', 'hotpink', 'black'], alpha=0.7)
plt.xlabel('Eventos especiales')
plt.ylabel('Frecuencia')
plt.title('Histograma de eventos especiales en el año 2010')
plt.show()

# %% [markdown]
# ### VAMOS A MIRAR QUE TENEMOS 👀

# %%
relevant_glaciers = clean_glacier_df[(clean_glacier_df['GLACIER_REGION_CODE'] == 'ASW') | (clean_glacier_df['GLACIER_REGION_CODE'] == 'GRL')]
relevant_glaciers
# Out:
#        POLITICAL_UNIT            NAME  WGMS_ID   LATITUDE  LONGITUDE  \
# 0                  AF        PIR YAKH    10452  35.595001  70.169998
# 1329               AF  RGI60-14.00147   106255  36.951500  74.149700
# 1330               AF  RGI60-14.00330   106422  37.062600  74.507700
# 1331               AF  RGI60-14.00341   106432  37.037600  74.563200
# 1332               AF  RGI60-14.00345   106436  37.057000  74.428500
# ...               ...             ...      ...        ...        ...
# 189468             TJ  RGI60-14.19022   120475  37.293971  74.968678
# 189469             TJ  RGI60-14.19025   120478  37.294251  74.999573
# 189470             TJ  RGI60-14.19026   120479  37.294802  74.992439
# 189471             TJ  RGI60-14.19027   120480  37.309605  75.004683
# 189472             TJ  RGI60-14.19028   120481  37.328091  75.013892
#
#        GLACIER_REGION_CODE GLACIER_SUBREGION_CODE
# 0                      ASW                 ASW-01
# 1329                   ASW                 ASW-02
# 1330                   ASW                 ASW-02
# 1331                   ASW                 ASW-02
# 1332                   ASW                 ASW-02
# ...                    ...                    ...
# 189468                 ASW                 ASW-02
# 189469                 ASW                 ASW-02
# 189470                 ASW                 ASW-02
# 189471                 ASW                 ASW-02
# 189472                 ASW                 ASW-02
#
# [45428 rows x 7 columns]

# %%
copy_clean_state_df.head()
# Out:
#    POLITICAL_UNIT              NAME  WGMS_ID  YEAR  HIGHEST_ELEVATION  \
# 9              AQ  BAHIA DEL DIABLO     2665  2004              630.0
# 10             AQ  BAHIA DEL DIABLO     2665  2008                NaN
# 11             AQ  BAHIA DEL DIABLO     2665  2010              630.0
# 12             AQ  BAHIA DEL DIABLO     2665  2014              630.0
# 13             AQ  BAHIA DEL DIABLO     2665  2015              630.0
#
#     MEDIAN_ELEVATION  LOWEST_ELEVATION     LENGTH     AREA
# 9              390.0              50.0  7599.9999      NaN
# 10               NaN               NaN        NaN  14300.0
# 11             390.0              50.0  7599.9999  14300.0
# 12             390.0              50.0  7599.9999  12900.0
# 13             390.0              50.0  7599.9999  12900.0

# %%
copy_clean_change_df.head()
# Out:
#        POLITICAL_UNIT           NAME  WGMS_ID  YEAR  AREA_CHANGE  \
# 843279             NZ  UNNAMED 21821    21821  2012          NaN
# 843280             NZ  UNNAMED 21821    21821  2015          NaN
# 843281             NZ  UNNAMED 21821    21821  2017          NaN
# 843282             NZ  UNNAMED 21821    21821  2018          NaN
# 843283             NZ  UNNAMED 21821    21821  2015          NaN
#
#         THICKNESS_CHG  VOLUME_CHANGE
# 843279        -8597.0            NaN
# 843280        -9895.0            NaN
# 843281       -13803.0            NaN
# 843282        -7734.0            NaN
# 843283       -12573.0            NaN

# %%
copy_mass_merged_df_filtered.head()
# Out:
#    POLITICAL_UNIT              NAME  WGMS_ID  YEAR     AREA  WINTER_BALANCE  \
# 14             AQ  BAHIA DEL DIABLO     2665  2000  12900.0             NaN
# 23             AQ  BAHIA DEL DIABLO     2665  2001  12900.0             NaN
# 32             AQ  BAHIA DEL DIABLO     2665  2002  12900.0             NaN
# 41             AQ  BAHIA DEL DIABLO     2665  2003  12900.0             NaN
# 50             AQ  BAHIA DEL DIABLO     2665  2004  12900.0             NaN
#
#     SUMMER_BALANCE  ANNUAL_BALANCE    ELA  ACC_AREA  ABL_AREA   AAR
# 14             NaN          -570.0  427.0       NaN       NaN  34.0
# 23             NaN           -60.0  375.0       NaN       NaN  52.0
# 32             NaN          -560.0  438.0       NaN       NaN  33.0
# 41             NaN          -180.0  389.0       NaN       NaN  43.0
# 50             NaN          -120.0  386.0       NaN       NaN  48.0

# %%
copy_mass_b_point_df.head()
# Out:
#       POLITICAL_UNIT       NAME  WGMS_ID  YEAR  POINT_ELEVATION  POINT_BALANCE
# 21679             CH  SILVRETTA      408  1920           2756.0         1870.0
# 21680             CH  SILVRETTA      408  1920           2756.0          540.0
# 21681             CH  SILVRETTA      408  1920           2756.0        -1330.0
# 21682             CH  SILVRETTA      408  1920           3009.0         2250.0
# 21683             CH  SILVRETTA      408  1920           3009.0          730.0

# %%
clean_front_variation_df.head()
# Out:
#      POLITICAL_UNIT         NAME  WGMS_ID  YEAR  FRONT_VARIATION  \
# 2349             AT  GOLDBERG K.     1305  1850              0.0
# 2350             AT  GOLDBERG K.     1305  1851              0.0
# 2351             AT  GOLDBERG K.     1305  1852              0.0
# 2352             AT  GOLDBERG K.     1305  1853              0.0
# 2353             AT  GOLDBERG K.     1305  1854              0.0
#
#      QUALITATIVE_VARIATION
# 2349                    ST
# 2350                    ST
# 2351                    ST
# 2352                    ST
# 2353                    ST

# %%
clean_special_event_df.head()
# Out:
#   POLITICAL_UNIT                          NAME  WGMS_ID    YEAR  ET_SURGE  \
# 0             AF                 UNNAMED 25830    26359  2018.0     False
# 1             AQ                         NO 38     4037  1990.0      True
# 2             AR                ALTO DEL PLOMO      922  1984.0      True
# 3             AR                        AZUFRE     2851  2018.0     False
# 4             AR  CERRO MARMOLEJO EAST GLACIER     8171     NaN      True
#
#    ET_CALVING  ET_FLOOD  ET_AVALANCHE  ET_TECTONIC  ET_OTHER
# 0       False      True         False        False     False
# 1       False     False         False        False     False
# 2       False      True         False        False     False
# 3       False     False         False         True     False
# 4       False     False         False        False     False

# %%
clean_glacier_df.head()
# Out:
#   POLITICAL_UNIT            NAME  WGMS_ID   LATITUDE  LONGITUDE  \
# 0             AF        PIR YAKH    10452  35.595001  70.169998
# 1             AF  RGI60-13.10763   156232  37.262384  73.525069
# 2             AF  RGI60-13.10764   156233  37.258539  73.546610
# 3             AF  RGI60-13.10765   156234  37.266134  73.542243
# 4             AF  RGI60-13.10766   156235  37.273266  73.535659
#
#   GLACIER_REGION_CODE GLACIER_SUBREGION_CODE
# 0                 ASW                 ASW-01
# 1                 ASC                 ASC-02
# 2                 ASC                 ASC-02
# 3                 ASC                 ASC-02
# 4                 ASC                 ASC-02

# %% [markdown]
# ### 💥💥 MERGEAMOS TODOS 🧊🧊 🧊🧊 🧊🧊

# %%
# mergeamos los dos datasets de prueba.
first_merge = pd.merge(clean_glacier_df, copy_clean_state_df, on=['WGMS_ID', 'POLITICAL_UNIT', 'NAME'], how='left')

# %%
first_merge.head(35)
# Out:
#    POLITICAL_UNIT            NAME  WGMS_ID   LATITUDE  LONGITUDE  \
# 0              AF        PIR YAKH    10452  35.595001  70.169998
# 1              AF  RGI60-13.10763   156232  37.262384  73.525069
# 2              AF  RGI60-13.10764   156233  37.258539  73.546610
# 3              AF  RGI60-13.10765   156234  37.266134  73.542243
# 4              AF  RGI60-13.10766   156235  37.273266  73.535659
# 5              AF  RGI60-13.10767   156236  37.267820  73.557927
# 6              AF  RGI60-13.10768   156237  37.270174  73.566393
# 7              AF  RGI60-13.10769   156238  37.273807  73.576475
# 8              AF  RGI60-13.10770   156239  37.284926  73.579521
# 9              AF  RGI60-13.10771   156240  37.290455  73.565636
# 10             AF  RGI60-13.10772   156241  37.296124  73.574452
# 11             AF  RGI60-13.10773   156242  37.292148  73.583840
# 12             AF  RGI60-13.10774   156243  37.309428  73.595000
# 13             AF  RGI60-13.10775   156244  37.309774  73.598329
# 14             AF  RGI60-13.10776   156245  37.313393  73.601402
# 15             AF  RGI60-13.10777   156246  37.306453  73.608867
# 16             AF  RGI60-13.10778   156247  37.318674  73.585308
# 17             AF  RGI60-13.10779   156248  37.321760  73.586684
# 18             AF  RGI60-13.10780   156249  37.327819  73.591309
# 19             AF  RGI60-13.10781   156250  37.330456  73.578525
# 20             AF  RGI60-13.10782   156251  37.333876  73.568227
# 21             AF  RGI60-13.10783   156252  37.331050  73.602606
# 22             AF  RGI60-13.10784   156253  37.333045  73.599123
# 23             AF  RGI60-13.10785   156254  37.338456  73.590729
# 24             AF  RGI60-13.10786   156255  37.347063  73.598227
# 25             AF  RGI60-13.10787   156256  37.350159  73.593218
# 26             AF  RGI60-13.10788   156257  37.274338  73.544610
# 27             AF  RGI60-13.10790   156258  37.286410  73.652287
# 28             AF  RGI60-13.10791   156259  37.287178  73.644577
# 29             AF  RGI60-13.10792   156260  37.307826  73.636395
# 30             AF  RGI60-13.10793   156261  37.305730  73.645294
# 31             AF  RGI60-13.10794   156262  37.318271  73.675515
# 32             AF  RGI60-13.10795   156263  37.329948  73.659124
# 33             AF  RGI60-13.10796   156264  37.346410  73.651370
# 34             AF  RGI60-13.10797   156265  37.341645  73.661235
#
#    GLACIER_REGION_CODE GLACIER_SUBREGION_CODE  YEAR  HIGHEST_ELEVATION  \
# 0                  ASW                 ASW-01   NaN                NaN
# 1                  ASC                 ASC-02   NaN                NaN
# 2                  ASC                 ASC-02   NaN                NaN
# 3                  ASC                 ASC-02   NaN                NaN
# 4                  ASC                 ASC-02   NaN                NaN
# 5                  ASC                 ASC-02   NaN                NaN
# 6                  ASC                 ASC-02   NaN                NaN
# 7                  ASC                 ASC-02   NaN                NaN
# 8                  ASC                 ASC-02   NaN                NaN
# 9                  ASC                 ASC-02   NaN                NaN
# 10                 ASC                 ASC-02   NaN                NaN
# 11                 ASC                 ASC-02   NaN                NaN
# 12                 ASC                 ASC-02   NaN                NaN
# 13                 ASC                 ASC-02   NaN                NaN
# 14                 ASC                 ASC-02   NaN                NaN
# 15                 ASC                 ASC-02   NaN                NaN
# 16                 ASC                 ASC-02   NaN                NaN
# 17                 ASC                 ASC-02   NaN                NaN
# 18                 ASC                 ASC-02   NaN                NaN
# 19                 ASC                 ASC-02   NaN                NaN
# 20                 ASC                 ASC-02   NaN                NaN
# 21                 ASC                 ASC-02   NaN                NaN
# 22                 ASC                 ASC-02   NaN                NaN
# 23                 ASC                 ASC-02   NaN                NaN
# 24                 ASC                 ASC-02   NaN                NaN
# 25                 ASC                 ASC-02   NaN                NaN
# 26                 ASC                 ASC-02   NaN                NaN
# 27                 ASC                 ASC-02   NaN                NaN
# 28                 ASC                 ASC-02   NaN                NaN
# 29                 ASC                 ASC-02   NaN                NaN
# 30                 ASC                 ASC-02   NaN                NaN
# 31                 ASC                 ASC-02   NaN                NaN
# 32                 ASC                 ASC-02   NaN                NaN
# 33                 ASC                 ASC-02   NaN                NaN
# 34                 ASC                 ASC-02   NaN                NaN
#
#     MEDIAN_ELEVATION  LOWEST_ELEVATION  LENGTH  AREA
# 0                NaN               NaN     NaN   NaN
# 1                NaN               NaN     NaN   NaN
# 2                NaN               NaN     NaN   NaN
# 3                NaN               NaN     NaN   NaN
# 4                NaN               NaN     NaN   NaN
# 5                NaN               NaN     NaN   NaN
# 6                NaN               NaN     NaN   NaN
# 7                NaN               NaN     NaN   NaN
# 8                NaN               NaN     NaN   NaN
# 9                NaN               NaN     NaN   NaN
# 10               NaN               NaN     NaN   NaN
# 11               NaN               NaN     NaN   NaN
# 12               NaN               NaN     NaN   NaN
# 13               NaN               NaN     NaN   NaN
# 14               NaN               NaN     NaN   NaN
# 15               NaN               NaN     NaN   NaN
# 16               NaN               NaN     NaN   NaN
# 17               NaN               NaN     NaN   NaN
# 18               NaN               NaN     NaN   NaN
# 19               NaN               NaN     NaN   NaN
# 20               NaN               NaN     NaN   NaN
# 21               NaN               NaN     NaN   NaN
# 22               NaN               NaN     NaN   NaN
# 23               NaN               NaN     NaN   NaN
# 24               NaN               NaN     NaN   NaN
# 25               NaN               NaN     NaN   NaN
# 26               NaN               NaN     NaN   NaN
# 27               NaN               NaN     NaN   NaN
# 28               NaN               NaN     NaN   NaN
# 29               NaN               NaN     NaN   NaN
# 30               NaN               NaN     NaN   NaN
# 31               NaN               NaN     NaN   NaN
# 32               NaN               NaN     NaN   NaN
# 33               NaN               NaN     NaN   NaN
# 34               NaN               NaN     NaN   NaN

# %%
first_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214651 entries, 0 to 214650
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   POLITICAL_UNIT          214651 non-null  object
#  1   NAME                    214651 non-null  object
#  2   WGMS_ID                 214651 non-null  int64
#  3   LATITUDE                214651 non-null  float64
#  4   LONGITUDE               214651 non-null  float64
#  5   GLACIER_REGION_CODE     214651 non-null  object
#  6   GLACIER_SUBREGION_CODE  214651 non-null  object
#  7   YEAR                    8 non-null       float64
#  8   HIGHEST_ELEVATION       7 non-null       float64
#  9   MEDIAN_ELEVATION        7 non-null       float64
#  10  LOWEST_ELEVATION        7 non-null       float64
#  11  LENGTH                  7 non-null       float64
#  12  AREA                    7 non-null       float64
# dtypes: float64(8), int64(1), object(4)
# memory usage: 21.3+ MB

# %%
second_merge = pd.merge(first_merge, copy_clean_change_df, on=['WGMS_ID', 'POLITICAL_UNIT', 'NAME', 'YEAR'], how='left')

# %%
second_merge.head(35)
# Out:
#    POLITICAL_UNIT            NAME  WGMS_ID   LATITUDE  LONGITUDE  \
# 0              AF        PIR YAKH    10452  35.595001  70.169998
# 1              AF  RGI60-13.10763   156232  37.262384  73.525069
# 2              AF  RGI60-13.10764   156233  37.258539  73.546610
# 3              AF  RGI60-13.10765   156234  37.266134  73.542243
# 4              AF  RGI60-13.10766   156235  37.273266  73.535659
# 5              AF  RGI60-13.10767   156236  37.267820  73.557927
# 6              AF  RGI60-13.10768   156237  37.270174  73.566393
# 7              AF  RGI60-13.10769   156238  37.273807  73.576475
# 8              AF  RGI60-13.10770   156239  37.284926  73.579521
# 9              AF  RGI60-13.10771   156240  37.290455  73.565636
# 10             AF  RGI60-13.10772   156241  37.296124  73.574452
# 11             AF  RGI60-13.10773   156242  37.292148  73.583840
# 12             AF  RGI60-13.10774   156243  37.309428  73.595000
# 13             AF  RGI60-13.10775   156244  37.309774  73.598329
# 14             AF  RGI60-13.10776   156245  37.313393  73.601402
# 15             AF  RGI60-13.10777   156246  37.306453  73.608867
# 16             AF  RGI60-13.10778   156247  37.318674  73.585308
# 17             AF  RGI60-13.10779   156248  37.321760  73.586684
# 18             AF  RGI60-13.10780   156249  37.327819  73.591309
# 19             AF  RGI60-13.10781   156250  37.330456  73.578525
# 20             AF  RGI60-13.10782   156251  37.333876  73.568227
# 21             AF  RGI60-13.10783   156252  37.331050  73.602606
# 22             AF  RGI60-13.10784   156253  37.333045  73.599123
# 23             AF  RGI60-13.10785   156254  37.338456  73.590729
# 24             AF  RGI60-13.10786   156255  37.347063  73.598227
# 25             AF  RGI60-13.10787   156256  37.350159  73.593218
# 26             AF  RGI60-13.10788   156257  37.274338  73.544610
# 27             AF  RGI60-13.10790   156258  37.286410  73.652287
# 28             AF  RGI60-13.10791   156259  37.287178  73.644577
# 29             AF  RGI60-13.10792   156260  37.307826  73.636395
# 30             AF  RGI60-13.10793   156261  37.305730  73.645294
# 31             AF  RGI60-13.10794   156262  37.318271  73.675515
# 32             AF  RGI60-13.10795   156263  37.329948  73.659124
# 33             AF  RGI60-13.10796   156264  37.346410  73.651370
# 34             AF  RGI60-13.10797   156265  37.341645  73.661235
#
#    GLACIER_REGION_CODE GLACIER_SUBREGION_CODE  YEAR  HIGHEST_ELEVATION  \
# 0                  ASW                 ASW-01   NaN                NaN
# 1                  ASC                 ASC-02   NaN                NaN
# 2                  ASC                 ASC-02   NaN                NaN
# 3                  ASC                 ASC-02   NaN                NaN
# 4                  ASC                 ASC-02   NaN                NaN
# 5                  ASC                 ASC-02   NaN                NaN
# 6                  ASC                 ASC-02   NaN                NaN
# 7                  ASC                 ASC-02   NaN                NaN
# 8                  ASC                 ASC-02   NaN                NaN
# 9                  ASC                 ASC-02   NaN                NaN
# 10                 ASC                 ASC-02   NaN                NaN
# 11                 ASC                 ASC-02   NaN                NaN
# 12                 ASC                 ASC-02   NaN                NaN
# 13                 ASC                 ASC-02   NaN                NaN
# 14                 ASC                 ASC-02   NaN                NaN
# 15                 ASC                 ASC-02   NaN                NaN
# 16                 ASC                 ASC-02   NaN                NaN
# 17                 ASC                 ASC-02   NaN                NaN
# 18                 ASC                 ASC-02   NaN                NaN
# 19                 ASC                 ASC-02   NaN                NaN
# 20                 ASC                 ASC-02   NaN                NaN
# 21                 ASC                 ASC-02   NaN                NaN
# 22                 ASC                 ASC-02   NaN                NaN
# 23                 ASC                 ASC-02   NaN                NaN
# 24                 ASC                 ASC-02   NaN                NaN
# 25                 ASC                 ASC-02   NaN                NaN
# 26                 ASC                 ASC-02   NaN                NaN
# 27                 ASC                 ASC-02   NaN                NaN
# 28                 ASC                 ASC-02   NaN                NaN
# 29                 ASC                 ASC-02   NaN                NaN
# 30                 ASC                 ASC-02   NaN                NaN
# 31                 ASC                 ASC-02   NaN                NaN
# 32                 ASC                 ASC-02   NaN                NaN
# 33                 ASC                 ASC-02   NaN                NaN
# 34                 ASC                 ASC-02   NaN                NaN
#
#     MEDIAN_ELEVATION  LOWEST_ELEVATION  LENGTH  AREA  AREA_CHANGE  \
# 0                NaN               NaN     NaN   NaN          NaN
# 1                NaN               NaN     NaN   NaN          NaN
# 2                NaN               NaN     NaN   NaN          NaN
# 3                NaN               NaN     NaN   NaN          NaN
# 4                NaN               NaN     NaN   NaN          NaN
# 5                NaN               NaN     NaN   NaN          NaN
# 6                NaN               NaN     NaN   NaN          NaN
# 7                NaN               NaN     NaN   NaN          NaN
# 8                NaN               NaN     NaN   NaN          NaN
# 9                NaN               NaN     NaN   NaN          NaN
# 10               NaN               NaN     NaN   NaN          NaN
# 11               NaN               NaN     NaN   NaN          NaN
# 12               NaN               NaN     NaN   NaN          NaN
# 13               NaN               NaN     NaN   NaN          NaN
# 14               NaN               NaN     NaN   NaN          NaN
# 15               NaN               NaN     NaN   NaN          NaN
# 16               NaN               NaN     NaN   NaN          NaN
# 17               NaN               NaN     NaN   NaN          NaN
# 18               NaN               NaN     NaN   NaN          NaN
# 19               NaN               NaN     NaN   NaN          NaN
# 20               NaN               NaN     NaN   NaN          NaN
# 21               NaN               NaN     NaN   NaN          NaN
# 22               NaN               NaN     NaN   NaN          NaN
# 23               NaN               NaN     NaN   NaN          NaN
# 24               NaN               NaN     NaN   NaN          NaN
# 25               NaN               NaN     NaN   NaN          NaN
# 26               NaN               NaN     NaN   NaN          NaN
# 27               NaN               NaN     NaN   NaN          NaN
# 28               NaN               NaN     NaN   NaN          NaN
# 29               NaN               NaN     NaN   NaN          NaN
# 30               NaN               NaN     NaN   NaN          NaN
# 31               NaN               NaN     NaN   NaN          NaN
# 32               NaN               NaN     NaN   NaN          NaN
# 33               NaN               NaN     NaN   NaN          NaN
# 34               NaN               NaN     NaN   NaN          NaN
#
#     THICKNESS_CHG  VOLUME_CHANGE
# 0             NaN            NaN
# 1             NaN            NaN
# 2             NaN            NaN
# 3             NaN            NaN
# 4             NaN            NaN
# 5             NaN            NaN
# 6             NaN            NaN
# 7             NaN            NaN
# 8             NaN            NaN
# 9             NaN            NaN
# 10            NaN            NaN
# 11            NaN            NaN
# 12            NaN            NaN
# 13            NaN            NaN
# 14            NaN            NaN
# 15            NaN            NaN
# 16            NaN            NaN
# 17            NaN            NaN
# 18            NaN            NaN
# 19            NaN            NaN
# 20            NaN            NaN
# 21            NaN            NaN
# 22            NaN            NaN
# 23            NaN            NaN
# 24            NaN            NaN
# 25            NaN            NaN
# 26            NaN            NaN
# 27            NaN            NaN
# 28            NaN            NaN
# 29            NaN            NaN
# 30            NaN            NaN
# 31            NaN            NaN
# 32            NaN            NaN
# 33            NaN            NaN
# 34            NaN            NaN

# %%
second_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214651 entries, 0 to 214650
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   POLITICAL_UNIT          214651 non-null  object
#  1   NAME                    214651 non-null  object
#  2   WGMS_ID                 214651 non-null  int64
#  3   LATITUDE                214651 non-null  float64
#  4   LONGITUDE               214651 non-null  float64
#  5   GLACIER_REGION_CODE     214651 non-null  object
#  6   GLACIER_SUBREGION_CODE  214651 non-null  object
#  7   YEAR                    8 non-null       float64
#  8   HIGHEST_ELEVATION       7 non-null       float64
#  9   MEDIAN_ELEVATION        7 non-null       float64
#  10  LOWEST_ELEVATION        7 non-null       float64
#  11  LENGTH                  7 non-null       float64
#  12  AREA                    7 non-null       float64
#  13  AREA_CHANGE             0 non-null       float64
#  14  THICKNESS_CHG           0 non-null       float64
#  15  VOLUME_CHANGE           0 non-null       float64
# dtypes: float64(11), int64(1), object(4)
# memory usage: 26.2+ MB

# %%
second_merge.isnull().sum()
# Out:
# POLITICAL_UNIT                 0
# NAME                           0
# WGMS_ID                        0
# LATITUDE                       0
# LONGITUDE                      0
# GLACIER_REGION_CODE            0
# GLACIER_SUBREGION_CODE         0
# YEAR                      214643
# HIGHEST_ELEVATION         214644
# MEDIAN_ELEVATION          214644
# LOWEST_ELEVATION          214644
# LENGTH                    214644
# AREA                      214644
# AREA_CHANGE               214651
# THICKNESS_CHG             214651
# VOLUME_CHANGE             214651
# dtype: int64

# %%
third_merge = pd.merge(second_merge,copy_mass_merged_df_filtered, on=['WGMS_ID', 'POLITICAL_UNIT', 'NAME', 'YEAR'], how='left', suffixes=['_general', '_elevationband'])

# %%
third_merge.head(35)
# Out:
#    POLITICAL_UNIT            NAME  WGMS_ID   LATITUDE  LONGITUDE  \
# 0              AF        PIR YAKH    10452  35.595001  70.169998
# 1              AF  RGI60-13.10763   156232  37.262384  73.525069
# 2              AF  RGI60-13.10764   156233  37.258539  73.546610
# 3              AF  RGI60-13.10765   156234  37.266134  73.542243
# 4              AF  RGI60-13.10766   156235  37.273266  73.535659
# 5              AF  RGI60-13.10767   156236  37.267820  73.557927
# 6              AF  RGI60-13.10768   156237  37.270174  73.566393
# 7              AF  RGI60-13.10769   156238  37.273807  73.576475
# 8              AF  RGI60-13.10770   156239  37.284926  73.579521
# 9              AF  RGI60-13.10771   156240  37.290455  73.565636
# 10             AF  RGI60-13.10772   156241  37.296124  73.574452
# 11             AF  RGI60-13.10773   156242  37.292148  73.583840
# 12             AF  RGI60-13.10774   156243  37.309428  73.595000
# 13             AF  RGI60-13.10775   156244  37.309774  73.598329
# 14             AF  RGI60-13.10776   156245  37.313393  73.601402
# 15             AF  RGI60-13.10777   156246  37.306453  73.608867
# 16             AF  RGI60-13.10778   156247  37.318674  73.585308
# 17             AF  RGI60-13.10779   156248  37.321760  73.586684
# 18             AF  RGI60-13.10780   156249  37.327819  73.591309
# 19             AF  RGI60-13.10781   156250  37.330456  73.578525
# 20             AF  RGI60-13.10782   156251  37.333876  73.568227
# 21             AF  RGI60-13.10783   156252  37.331050  73.602606
# 22             AF  RGI60-13.10784   156253  37.333045  73.599123
# 23             AF  RGI60-13.10785   156254  37.338456  73.590729
# 24             AF  RGI60-13.10786   156255  37.347063  73.598227
# 25             AF  RGI60-13.10787   156256  37.350159  73.593218
# 26             AF  RGI60-13.10788   156257  37.274338  73.544610
# 27             AF  RGI60-13.10790   156258  37.286410  73.652287
# 28             AF  RGI60-13.10791   156259  37.287178  73.644577
# 29             AF  RGI60-13.10792   156260  37.307826  73.636395
# 30             AF  RGI60-13.10793   156261  37.305730  73.645294
# 31             AF  RGI60-13.10794   156262  37.318271  73.675515
# 32             AF  RGI60-13.10795   156263  37.329948  73.659124
# 33             AF  RGI60-13.10796   156264  37.346410  73.651370
# 34             AF  RGI60-13.10797   156265  37.341645  73.661235
#
#    GLACIER_REGION_CODE GLACIER_SUBREGION_CODE  YEAR  HIGHEST_ELEVATION  \
# 0                  ASW                 ASW-01   NaN                NaN
# 1                  ASC                 ASC-02   NaN                NaN
# 2                  ASC                 ASC-02   NaN                NaN
# 3                  ASC                 ASC-02   NaN                NaN
# 4                  ASC                 ASC-02   NaN                NaN
# 5                  ASC                 ASC-02   NaN                NaN
# 6                  ASC                 ASC-02   NaN                NaN
# 7                  ASC                 ASC-02   NaN                NaN
# 8                  ASC                 ASC-02   NaN                NaN
# 9                  ASC                 ASC-02   NaN                NaN
# 10                 ASC                 ASC-02   NaN                NaN
# 11                 ASC                 ASC-02   NaN                NaN
# 12                 ASC                 ASC-02   NaN                NaN
# 13                 ASC                 ASC-02   NaN                NaN
# 14                 ASC                 ASC-02   NaN                NaN
# 15                 ASC                 ASC-02   NaN                NaN
# 16                 ASC                 ASC-02   NaN                NaN
# 17                 ASC                 ASC-02   NaN                NaN
# 18                 ASC                 ASC-02   NaN                NaN
# 19                 ASC                 ASC-02   NaN                NaN
# 20                 ASC                 ASC-02   NaN                NaN
# 21                 ASC                 ASC-02   NaN                NaN
# 22                 ASC                 ASC-02   NaN                NaN
# 23                 ASC                 ASC-02   NaN                NaN
# 24                 ASC                 ASC-02   NaN                NaN
# 25                 ASC                 ASC-02   NaN                NaN
# 26                 ASC                 ASC-02   NaN                NaN
# 27                 ASC                 ASC-02   NaN                NaN
# 28                 ASC                 ASC-02   NaN                NaN
# 29                 ASC                 ASC-02   NaN                NaN
# 30                 ASC                 ASC-02   NaN                NaN
# 31                 ASC                 ASC-02   NaN                NaN
# 32                 ASC                 ASC-02   NaN                NaN
# 33                 ASC                 ASC-02   NaN                NaN
# 34                 ASC                 ASC-02   NaN                NaN
#
#     MEDIAN_ELEVATION  ...  THICKNESS_CHG  VOLUME_CHANGE  AREA_elevationband  \
# 0                NaN  ...            NaN            NaN                 NaN
# 1                NaN  ...            NaN            NaN                 NaN
# 2                NaN  ...            NaN            NaN                 NaN
# 3                NaN  ...            NaN            NaN                 NaN
# 4                NaN  ...            NaN            NaN                 NaN
# 5                NaN  ...            NaN            NaN                 NaN
# 6                NaN  ...            NaN            NaN                 NaN
# 7                NaN  ...            NaN            NaN                 NaN
# 8                NaN  ...            NaN            NaN                 NaN
# 9                NaN  ...            NaN            NaN                 NaN
# 10               NaN  ...            NaN            NaN                 NaN
# 11               NaN  ...            NaN            NaN                 NaN
# 12               NaN  ...            NaN            NaN                 NaN
# 13               NaN  ...            NaN            NaN                 NaN
# 14               NaN  ...            NaN            NaN                 NaN
# 15               NaN  ...            NaN            NaN                 NaN
# 16               NaN  ...            NaN            NaN                 NaN
# 17               NaN  ...            NaN            NaN                 NaN
# 18               NaN  ...            NaN            NaN                 NaN
# 19               NaN  ...            NaN            NaN                 NaN
# 20               NaN  ...            NaN            NaN                 NaN
# 21               NaN  ...            NaN            NaN                 NaN
# 22               NaN  ...            NaN            NaN                 NaN
# 23               NaN  ...            NaN            NaN                 NaN
# 24               NaN  ...            NaN            NaN                 NaN
# 25               NaN  ...            NaN            NaN                 NaN
# 26               NaN  ...            NaN            NaN                 NaN
# 27               NaN  ...            NaN            NaN                 NaN
# 28               NaN  ...            NaN            NaN                 NaN
# 29               NaN  ...            NaN            NaN                 NaN
# 30               NaN  ...            NaN            NaN                 NaN
# 31               NaN  ...            NaN            NaN                 NaN
# 32               NaN  ...            NaN            NaN                 NaN
# 33               NaN  ...            NaN            NaN                 NaN
# 34               NaN  ...            NaN            NaN                 NaN
#
#     WINTER_BALANCE  SUMMER_BALANCE  ANNUAL_BALANCE  ELA  ACC_AREA  ABL_AREA  \
# 0              NaN             NaN             NaN  NaN       NaN       NaN
# 1              NaN             NaN             NaN  NaN       NaN       NaN
# 2              NaN             NaN             NaN  NaN       NaN       NaN
# 3              NaN             NaN             NaN  NaN       NaN       NaN
# 4              NaN             NaN             NaN  NaN       NaN       NaN
# 5              NaN             NaN             NaN  NaN       NaN       NaN
# 6              NaN             NaN             NaN  NaN       NaN       NaN
# 7              NaN             NaN             NaN  NaN       NaN       NaN
# 8              NaN             NaN             NaN  NaN       NaN       NaN
# 9              NaN             NaN             NaN  NaN       NaN       NaN
# 10             NaN             NaN             NaN  NaN       NaN       NaN
# 11             NaN             NaN             NaN  NaN       NaN       NaN
# 12             NaN             NaN             NaN  NaN       NaN       NaN
# 13             NaN             NaN             NaN  NaN       NaN       NaN
# 14             NaN             NaN             NaN  NaN       NaN       NaN
# 15             NaN             NaN             NaN  NaN       NaN       NaN
# 16             NaN             NaN             NaN  NaN       NaN       NaN
# 17             NaN             NaN             NaN  NaN       NaN       NaN
# 18             NaN             NaN             NaN  NaN       NaN       NaN
# 19             NaN             NaN             NaN  NaN       NaN       NaN
# 20             NaN             NaN             NaN  NaN       NaN       NaN
# 21             NaN             NaN             NaN  NaN       NaN       NaN
# 22             NaN             NaN             NaN  NaN       NaN       NaN
# 23             NaN             NaN             NaN  NaN       NaN       NaN
# 24             NaN             NaN             NaN  NaN       NaN       NaN
# 25             NaN             NaN             NaN  NaN       NaN       NaN
# 26             NaN             NaN             NaN  NaN       NaN       NaN
# 27             NaN             NaN             NaN  NaN       NaN       NaN
# 28             NaN             NaN             NaN  NaN       NaN       NaN
# 29             NaN             NaN             NaN  NaN       NaN       NaN
# 30             NaN             NaN             NaN  NaN       NaN       NaN
# 31             NaN             NaN             NaN  NaN       NaN       NaN
# 32             NaN             NaN             NaN  NaN       NaN       NaN
# 33             NaN             NaN             NaN  NaN       NaN       NaN
# 34             NaN             NaN             NaN  NaN       NaN       NaN
#
#     AAR
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
# 12  NaN
# 13  NaN
# 14  NaN
# 15  NaN
# 16  NaN
# 17  NaN
# 18  NaN
# 19  NaN
# 20  NaN
# 21  NaN
# 22  NaN
# 23  NaN
# 24  NaN
# 25  NaN
# 26  NaN
# 27  NaN
# 28  NaN
# 29  NaN
# 30  NaN
# 31  NaN
# 32  NaN
# 33  NaN
# 34  NaN
#
# [35 rows x 24 columns]

# %%
third_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214651 entries, 0 to 214650
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   POLITICAL_UNIT          214651 non-null  object
#  1   NAME                    214651 non-null  object
#  2   WGMS_ID                 214651 non-null  int64
#  3   LATITUDE                214651 non-null  float64
#  4   LONGITUDE               214651 non-null  float64
#  5   GLACIER_REGION_CODE     214651 non-null  object
#  6   GLACIER_SUBREGION_CODE  214651 non-null  object
#  7   YEAR                    8 non-null       float64
#  8   HIGHEST_ELEVATION       7 non-null       float64
#  9   MEDIAN_ELEVATION        7 non-null       float64
#  10  LOWEST_ELEVATION        7 non-null       float64
#  11  LENGTH                  7 non-null       float64
#  12  AREA_general            7 non-null       float64
#  13  AREA_CHANGE             0 non-null       float64
#  14  THICKNESS_CHG           0 non-null       float64
#  15  VOLUME_CHANGE           0 non-null       float64
#  16  AREA_elevationband      8 non-null       float64
#  17  WINTER_BALANCE          0 non-null       float64
#  18  SUMMER_BALANCE          0 non-null       float64
#  19  ANNUAL_BALANCE          8 non-null       float64
#  20  ELA                     8 non-null       float64
#  21  ACC_AREA                4 non-null       float64
#  22  ABL_AREA                4 non-null       float64
#  23  AAR                     8 non-null       float64
# dtypes: float64(19), int64(1), object(4)
# memory usage: 39.3+ MB

# %%
third_merge.isnull().sum()
# Out:
# POLITICAL_UNIT                 0
# NAME                           0
# WGMS_ID                        0
# LATITUDE                       0
# LONGITUDE                      0
# GLACIER_REGION_CODE            0
# GLACIER_SUBREGION_CODE         0
# YEAR                      214643
# HIGHEST_ELEVATION         214644
# MEDIAN_ELEVATION          214644
# LOWEST_ELEVATION          214644
# LENGTH                    214644
# AREA_general              214644
# AREA_CHANGE               214651
# THICKNESS_CHG             214651
# VOLUME_CHANGE             214651
# AREA_elevationband        214643
# WINTER_BALANCE            214651
# SUMMER_BALANCE            214651
# ANNUAL_BALANCE            214643
# ELA                       214643
# ACC_AREA                  214647
# ABL_AREA                  214647
# AAR                       214643
# dtype: int64

# %%
fourth_merge = pd.merge(third_merge, copy_mass_b_point_df, on = ['WGMS_ID', 'POLITICAL_UNIT', 'NAME', 'YEAR'], how='left')

# %%
fourth_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214651 entries, 0 to 214650
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   POLITICAL_UNIT          214651 non-null  object
#  1   NAME                    214651 non-null  object
#  2   WGMS_ID                 214651 non-null  int64
#  3   LATITUDE                214651 non-null  float64
#  4   LONGITUDE               214651 non-null  float64
#  5   GLACIER_REGION_CODE     214651 non-null  object
#  6   GLACIER_SUBREGION_CODE  214651 non-null  object
#  7   YEAR                    8 non-null       float64
#  8   HIGHEST_ELEVATION       7 non-null       float64
#  9   MEDIAN_ELEVATION        7 non-null       float64
#  10  LOWEST_ELEVATION        7 non-null       float64
#  11  LENGTH                  7 non-null       float64
#  12  AREA_general            7 non-null       float64
#  13  AREA_CHANGE             0 non-null       float64
#  14  THICKNESS_CHG           0 non-null       float64
#  15  VOLUME_CHANGE           0 non-null       float64
#  16  AREA_elevationband      8 non-null       float64
#  17  WINTER_BALANCE          0 non-null       float64
#  18  SUMMER_BALANCE          0 non-null       float64
#  19  ANNUAL_BALANCE          8 non-null       float64
#  20  ELA                     8 non-null       float64
#  21  ACC_AREA                4 non-null       float64
#  22  ABL_AREA                4 non-null       float64
#  23  AAR                     8 non-null       float64
#  24  POINT_ELEVATION         0 non-null       float64
#  25  POINT_BALANCE           0 non-null       float64
# dtypes: float64(21), int64(1), object(4)
# memory usage: 42.6+ MB

# %%
fourth_merge.head(35)
# Out:
#    POLITICAL_UNIT            NAME  WGMS_ID   LATITUDE  LONGITUDE  \
# 0              AF        PIR YAKH    10452  35.595001  70.169998
# 1              AF  RGI60-13.10763   156232  37.262384  73.525069
# 2              AF  RGI60-13.10764   156233  37.258539  73.546610
# 3              AF  RGI60-13.10765   156234  37.266134  73.542243
# 4              AF  RGI60-13.10766   156235  37.273266  73.535659
# 5              AF  RGI60-13.10767   156236  37.267820  73.557927
# 6              AF  RGI60-13.10768   156237  37.270174  73.566393
# 7              AF  RGI60-13.10769   156238  37.273807  73.576475
# 8              AF  RGI60-13.10770   156239  37.284926  73.579521
# 9              AF  RGI60-13.10771   156240  37.290455  73.565636
# 10             AF  RGI60-13.10772   156241  37.296124  73.574452
# 11             AF  RGI60-13.10773   156242  37.292148  73.583840
# 12             AF  RGI60-13.10774   156243  37.309428  73.595000
# 13             AF  RGI60-13.10775   156244  37.309774  73.598329
# 14             AF  RGI60-13.10776   156245  37.313393  73.601402
# 15             AF  RGI60-13.10777   156246  37.306453  73.608867
# 16             AF  RGI60-13.10778   156247  37.318674  73.585308
# 17             AF  RGI60-13.10779   156248  37.321760  73.586684
# 18             AF  RGI60-13.10780   156249  37.327819  73.591309
# 19             AF  RGI60-13.10781   156250  37.330456  73.578525
# 20             AF  RGI60-13.10782   156251  37.333876  73.568227
# 21             AF  RGI60-13.10783   156252  37.331050  73.602606
# 22             AF  RGI60-13.10784   156253  37.333045  73.599123
# 23             AF  RGI60-13.10785   156254  37.338456  73.590729
# 24             AF  RGI60-13.10786   156255  37.347063  73.598227
# 25             AF  RGI60-13.10787   156256  37.350159  73.593218
# 26             AF  RGI60-13.10788   156257  37.274338  73.544610
# 27             AF  RGI60-13.10790   156258  37.286410  73.652287
# 28             AF  RGI60-13.10791   156259  37.287178  73.644577
# 29             AF  RGI60-13.10792   156260  37.307826  73.636395
# 30             AF  RGI60-13.10793   156261  37.305730  73.645294
# 31             AF  RGI60-13.10794   156262  37.318271  73.675515
# 32             AF  RGI60-13.10795   156263  37.329948  73.659124
# 33             AF  RGI60-13.10796   156264  37.346410  73.651370
# 34             AF  RGI60-13.10797   156265  37.341645  73.661235
#
#    GLACIER_REGION_CODE GLACIER_SUBREGION_CODE  YEAR  HIGHEST_ELEVATION  \
# 0                  ASW                 ASW-01   NaN                NaN
# 1                  ASC                 ASC-02   NaN                NaN
# 2                  ASC                 ASC-02   NaN                NaN
# 3                  ASC                 ASC-02   NaN                NaN
# 4                  ASC                 ASC-02   NaN                NaN
# 5                  ASC                 ASC-02   NaN                NaN
# 6                  ASC                 ASC-02   NaN                NaN
# 7                  ASC                 ASC-02   NaN                NaN
# 8                  ASC                 ASC-02   NaN                NaN
# 9                  ASC                 ASC-02   NaN                NaN
# 10                 ASC                 ASC-02   NaN                NaN
# 11                 ASC                 ASC-02   NaN                NaN
# 12                 ASC                 ASC-02   NaN                NaN
# 13                 ASC                 ASC-02   NaN                NaN
# 14                 ASC                 ASC-02   NaN                NaN
# 15                 ASC                 ASC-02   NaN                NaN
# 16                 ASC                 ASC-02   NaN                NaN
# 17                 ASC                 ASC-02   NaN                NaN
# 18                 ASC                 ASC-02   NaN                NaN
# 19                 ASC                 ASC-02   NaN                NaN
# 20                 ASC                 ASC-02   NaN                NaN
# 21                 ASC                 ASC-02   NaN                NaN
# 22                 ASC                 ASC-02   NaN                NaN
# 23                 ASC                 ASC-02   NaN                NaN
# 24                 ASC                 ASC-02   NaN                NaN
# 25                 ASC                 ASC-02   NaN                NaN
# 26                 ASC                 ASC-02   NaN                NaN
# 27                 ASC                 ASC-02   NaN                NaN
# 28                 ASC                 ASC-02   NaN                NaN
# 29                 ASC                 ASC-02   NaN                NaN
# 30                 ASC                 ASC-02   NaN                NaN
# 31                 ASC                 ASC-02   NaN                NaN
# 32                 ASC                 ASC-02   NaN                NaN
# 33                 ASC                 ASC-02   NaN                NaN
# 34                 ASC                 ASC-02   NaN                NaN
#
#     MEDIAN_ELEVATION  ...  AREA_elevationband  WINTER_BALANCE  SUMMER_BALANCE  \
# 0                NaN  ...                 NaN             NaN             NaN
# 1                NaN  ...                 NaN             NaN             NaN
# 2                NaN  ...                 NaN             NaN             NaN
# 3                NaN  ...                 NaN             NaN             NaN
# 4                NaN  ...                 NaN             NaN             NaN
# 5                NaN  ...                 NaN             NaN             NaN
# 6                NaN  ...                 NaN             NaN             NaN
# 7                NaN  ...                 NaN             NaN             NaN
# 8                NaN  ...                 NaN             NaN             NaN
# 9                NaN  ...                 NaN             NaN             NaN
# 10               NaN  ...                 NaN             NaN             NaN
# 11               NaN  ...                 NaN             NaN             NaN
# 12               NaN  ...                 NaN             NaN             NaN
# 13               NaN  ...                 NaN             NaN             NaN
# 14               NaN  ...                 NaN             NaN             NaN
# 15               NaN  ...                 NaN             NaN             NaN
# 16               NaN  ...                 NaN             NaN             NaN
# 17               NaN  ...                 NaN             NaN             NaN
# 18               NaN  ...                 NaN             NaN             NaN
# 19               NaN  ...                 NaN             NaN             NaN
# 20               NaN  ...                 NaN             NaN             NaN
# 21               NaN  ...                 NaN             NaN             NaN
# 22               NaN  ...                 NaN             NaN             NaN
# 23               NaN  ...                 NaN             NaN             NaN
# 24               NaN  ...                 NaN             NaN             NaN
# 25               NaN  ...                 NaN             NaN             NaN
# 26               NaN  ...                 NaN             NaN             NaN
# 27               NaN  ...                 NaN             NaN             NaN
# 28               NaN  ...                 NaN             NaN             NaN
# 29               NaN  ...                 NaN             NaN             NaN
# 30               NaN  ...                 NaN             NaN             NaN
# 31               NaN  ...                 NaN             NaN             NaN
# 32               NaN  ...                 NaN             NaN             NaN
# 33               NaN  ...                 NaN             NaN             NaN
# 34               NaN  ...                 NaN             NaN             NaN
#
#     ANNUAL_BALANCE  ELA  ACC_AREA  ABL_AREA  AAR  POINT_ELEVATION  \
# 0              NaN  NaN       NaN       NaN  NaN              NaN
# 1              NaN  NaN       NaN       NaN  NaN              NaN
# 2              NaN  NaN       NaN       NaN  NaN              NaN
# 3              NaN  NaN       NaN       NaN  NaN              NaN
# 4              NaN  NaN       NaN       NaN  NaN              NaN
# 5              NaN  NaN       NaN       NaN  NaN              NaN
# 6              NaN  NaN       NaN       NaN  NaN              NaN
# 7              NaN  NaN       NaN       NaN  NaN              NaN
# 8              NaN  NaN       NaN       NaN  NaN              NaN
# 9              NaN  NaN       NaN       NaN  NaN              NaN
# 10             NaN  NaN       NaN       NaN  NaN              NaN
# 11             NaN  NaN       NaN       NaN  NaN              NaN
# 12             NaN  NaN       NaN       NaN  NaN              NaN
# 13             NaN  NaN       NaN       NaN  NaN              NaN
# 14             NaN  NaN       NaN       NaN  NaN              NaN
# 15             NaN  NaN       NaN       NaN  NaN              NaN
# 16             NaN  NaN       NaN       NaN  NaN              NaN
# 17             NaN  NaN       NaN       NaN  NaN              NaN
# 18             NaN  NaN       NaN       NaN  NaN              NaN
# 19             NaN  NaN       NaN       NaN  NaN              NaN
# 20             NaN  NaN       NaN       NaN  NaN              NaN
# 21             NaN  NaN       NaN       NaN  NaN              NaN
# 22             NaN  NaN       NaN       NaN  NaN              NaN
# 23             NaN  NaN       NaN       NaN  NaN              NaN
# 24             NaN  NaN       NaN       NaN  NaN              NaN
# 25             NaN  NaN       NaN       NaN  NaN              NaN
# 26             NaN  NaN       NaN       NaN  NaN              NaN
# 27             NaN  NaN       NaN       NaN  NaN              NaN
# 28             NaN  NaN       NaN       NaN  NaN              NaN
# 29             NaN  NaN       NaN       NaN  NaN              NaN
# 30             NaN  NaN       NaN       NaN  NaN              NaN
# 31             NaN  NaN       NaN       NaN  NaN              NaN
# 32             NaN  NaN       NaN       NaN  NaN              NaN
# 33             NaN  NaN       NaN       NaN  NaN              NaN
# 34             NaN  NaN       NaN       NaN  NaN              NaN
#
#     POINT_BALANCE
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN
# 28            NaN
# 29            NaN
# 30            NaN
# 31            NaN
# 32            NaN
# 33            NaN
# 34            NaN
#
# [35 rows x 26 columns]

# %%
fifth_merge = pd.merge(fourth_merge, front_variation_merged, on = ['WGMS_ID', 'POLITICAL_UNIT', 'NAME', 'YEAR'], how='left')

# %%
fifth_merge.head()
# Out:
#   POLITICAL_UNIT            NAME  WGMS_ID   LATITUDE  LONGITUDE  \
# 0             AF        PIR YAKH    10452  35.595001  70.169998
# 1             AF  RGI60-13.10763   156232  37.262384  73.525069
# 2             AF  RGI60-13.10764   156233  37.258539  73.546610
# 3             AF  RGI60-13.10765   156234  37.266134  73.542243
# 4             AF  RGI60-13.10766   156235  37.273266  73.535659
#
#   GLACIER_REGION_CODE GLACIER_SUBREGION_CODE  YEAR  HIGHEST_ELEVATION_x  \
# 0                 ASW                 ASW-01   NaN                  NaN
# 1                 ASC                 ASC-02   NaN                  NaN
# 2                 ASC                 ASC-02   NaN                  NaN
# 3                 ASC                 ASC-02   NaN                  NaN
# 4                 ASC                 ASC-02   NaN                  NaN
#
#    MEDIAN_ELEVATION  ...  ABL_AREA  AAR  POINT_ELEVATION  POINT_BALANCE  \
# 0               NaN  ...       NaN  NaN              NaN            NaN
# 1               NaN  ...       NaN  NaN              NaN            NaN
# 2               NaN  ...       NaN  NaN              NaN            NaN
# 3               NaN  ...       NaN  NaN              NaN            NaN
# 4               NaN  ...       NaN  NaN              NaN            NaN
#
#    FRONT_VARIATION  QUALITATIVE_VARIATION  rec_FRONT_VARIATION  \
# 0              NaN                    NaN                  NaN
# 1              NaN                    NaN                  NaN
# 2              NaN                    NaN                  NaN
# 3              NaN                    NaN                  NaN
# 4              NaN                    NaN                  NaN
#
#    rec_QUALITATIVE_VARIATION  LOWEST_ELEVATION_y  HIGHEST_ELEVATION_y
# 0                        NaN                 NaN                  NaN
# 1                        NaN                 NaN                  NaN
# 2                        NaN                 NaN                  NaN
# 3                        NaN                 NaN                  NaN
# 4                        NaN                 NaN                  NaN
#
# [5 rows x 32 columns]

# %%
# Al repetir el merge, nos damos cuenta que las columnas HIGHEST_ELEVATION y LOWEST_ELEVATION se repiten, comparamos las repetidas y vemos que esas columnas que provienen del dataset mass_merged son casi todos valores nulos, asi que nos cargamos las columnas.

# %%
fifth_merge = fifth_merge.drop(columns = ['HIGHEST_ELEVATION_y', 'LOWEST_ELEVATION_y'])
fifth_merge.columns
# Out:
# Index(['POLITICAL_UNIT', 'NAME', 'WGMS_ID', 'LATITUDE', 'LONGITUDE',
#        'GLACIER_REGION_CODE', 'GLACIER_SUBREGION_CODE', 'YEAR',
#        'HIGHEST_ELEVATION_x', 'MEDIAN_ELEVATION', 'LOWEST_ELEVATION_x',
#        'LENGTH', 'AREA_general', 'AREA_CHANGE', 'THICKNESS_CHG',
#        'VOLUME_CHANGE', 'AREA_elevationband', 'WINTER_BALANCE',
#        'SUMMER_BALANCE', 'ANNUAL_BALANCE', 'ELA', 'ACC_AREA', 'ABL_AREA',
#        'AAR', 'POINT_ELEVATION', 'POINT_BALANCE', 'FRONT_VARIATION',
#        'QUALITATIVE_VARIATION', 'rec_FRONT_VARIATION',
#        'rec_QUALITATIVE_VARIATION'],
#       dtype='object')

# %%
fifth_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214651 entries, 0 to 214650
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   POLITICAL_UNIT             214651 non-null  object
#  1   NAME                       214651 non-null  object
#  2   WGMS_ID                    214651 non-null  int64
#  3   LATITUDE                   214651 non-null  float64
#  4   LONGITUDE                  214651 non-null  float64
#  5   GLACIER_REGION_CODE        214651 non-null  object
#  6   GLACIER_SUBREGION_CODE     214651 non-null  object
#  7   YEAR                       8 non-null       float64
#  8   HIGHEST_ELEVATION_x        7 non-null       float64
#  9   MEDIAN_ELEVATION           7 non-null       float64
#  10  LOWEST_ELEVATION_x         7 non-null       float64
#  11  LENGTH                     7 non-null       float64
#  12  AREA_general               7 non-null       float64
#  13  AREA_CHANGE                0 non-null       float64
#  14  THICKNESS_CHG              0 non-null       float64
#  15  VOLUME_CHANGE              0 non-null       float64
#  16  AREA_elevationband         8 non-null       float64
#  17  WINTER_BALANCE             0 non-null       float64
#  18  SUMMER_BALANCE             0 non-null       float64
#  19  ANNUAL_BALANCE             8 non-null       float64
#  20  ELA                        8 non-null       float64
#  21  ACC_AREA                   4 non-null       float64
#  22  ABL_AREA                   4 non-null       float64
#  23  AAR                        8 non-null       float64
#  24  POINT_ELEVATION            0 non-null       float64
#  25  POINT_BALANCE              0 non-null       float64
#  26  FRONT_VARIATION            0 non-null       float64
#  27  QUALITATIVE_VARIATION      0 non-null       object
#  28  rec_FRONT_VARIATION        0 non-null       float64
#  29  rec_QUALITATIVE_VARIATION  0 non-null       object
# dtypes: float64(23), int64(1), object(6)
# memory usage: 49.1+ MB

# %%
clean_special_event_df['YEAR'] = clean_special_event_df['YEAR'].astype('float64')

# %%
final_merge = pd.merge(fifth_merge, clean_special_event_df, on = ['WGMS_ID', 'POLITICAL_UNIT', 'NAME', 'YEAR'], how='left')

# %%
final_merge.head(15)
# Out:
#    POLITICAL_UNIT            NAME  WGMS_ID   LATITUDE  LONGITUDE  \
# 0              AF        PIR YAKH    10452  35.595001  70.169998
# 1              AF  RGI60-13.10763   156232  37.262384  73.525069
# 2              AF  RGI60-13.10764   156233  37.258539  73.546610
# 3              AF  RGI60-13.10765   156234  37.266134  73.542243
# 4              AF  RGI60-13.10766   156235  37.273266  73.535659
# 5              AF  RGI60-13.10767   156236  37.267820  73.557927
# 6              AF  RGI60-13.10768   156237  37.270174  73.566393
# 7              AF  RGI60-13.10769   156238  37.273807  73.576475
# 8              AF  RGI60-13.10770   156239  37.284926  73.579521
# 9              AF  RGI60-13.10771   156240  37.290455  73.565636
# 10             AF  RGI60-13.10772   156241  37.296124  73.574452
# 11             AF  RGI60-13.10773   156242  37.292148  73.583840
# 12             AF  RGI60-13.10774   156243  37.309428  73.595000
# 13             AF  RGI60-13.10775   156244  37.309774  73.598329
# 14             AF  RGI60-13.10776   156245  37.313393  73.601402
#
#    GLACIER_REGION_CODE GLACIER_SUBREGION_CODE  YEAR  HIGHEST_ELEVATION_x  \
# 0                  ASW                 ASW-01   NaN                  NaN
# 1                  ASC                 ASC-02   NaN                  NaN
# 2                  ASC                 ASC-02   NaN                  NaN
# 3                  ASC                 ASC-02   NaN                  NaN
# 4                  ASC                 ASC-02   NaN                  NaN
# 5                  ASC                 ASC-02   NaN                  NaN
# 6                  ASC                 ASC-02   NaN                  NaN
# 7                  ASC                 ASC-02   NaN                  NaN
# 8                  ASC                 ASC-02   NaN                  NaN
# 9                  ASC                 ASC-02   NaN                  NaN
# 10                 ASC                 ASC-02   NaN                  NaN
# 11                 ASC                 ASC-02   NaN                  NaN
# 12                 ASC                 ASC-02   NaN                  NaN
# 13                 ASC                 ASC-02   NaN                  NaN
# 14                 ASC                 ASC-02   NaN                  NaN
#
#     MEDIAN_ELEVATION  ...  FRONT_VARIATION  QUALITATIVE_VARIATION  \
# 0                NaN  ...              NaN                    NaN
# 1                NaN  ...              NaN                    NaN
# 2                NaN  ...              NaN                    NaN
# 3                NaN  ...              NaN                    NaN
# 4                NaN  ...              NaN                    NaN
# 5                NaN  ...              NaN                    NaN
# 6                NaN  ...              NaN                    NaN
# 7                NaN  ...              NaN                    NaN
# 8                NaN  ...              NaN                    NaN
# 9                NaN  ...              NaN                    NaN
# 10               NaN  ...              NaN                    NaN
# 11               NaN  ...              NaN                    NaN
# 12               NaN  ...              NaN                    NaN
# 13               NaN  ...              NaN                    NaN
# 14               NaN  ...              NaN                    NaN
#
#     rec_FRONT_VARIATION  rec_QUALITATIVE_VARIATION  ET_SURGE  ET_CALVING  \
# 0                   NaN                        NaN       NaN         NaN
# 1                   NaN                        NaN       NaN         NaN
# 2                   NaN                        NaN       NaN         NaN
# 3                   NaN                        NaN       NaN         NaN
# 4                   NaN                        NaN       NaN         NaN
# 5                   NaN                        NaN       NaN         NaN
# 6                   NaN                        NaN       NaN         NaN
# 7                   NaN                        NaN       NaN         NaN
# 8                   NaN                        NaN       NaN         NaN
# 9                   NaN                        NaN       NaN         NaN
# 10                  NaN                        NaN       NaN         NaN
# 11                  NaN                        NaN       NaN         NaN
# 12                  NaN                        NaN       NaN         NaN
# 13                  NaN                        NaN       NaN         NaN
# 14                  NaN                        NaN       NaN         NaN
#
#     ET_FLOOD  ET_AVALANCHE  ET_TECTONIC  ET_OTHER
# 0        NaN           NaN          NaN       NaN
# 1        NaN           NaN          NaN       NaN
# 2        NaN           NaN          NaN       NaN
# 3        NaN           NaN          NaN       NaN
# 4        NaN           NaN          NaN       NaN
# 5        NaN           NaN          NaN       NaN
# 6        NaN           NaN          NaN       NaN
# 7        NaN           NaN          NaN       NaN
# 8        NaN           NaN          NaN       NaN
# 9        NaN           NaN          NaN       NaN
# 10       NaN           NaN          NaN       NaN
# 11       NaN           NaN          NaN       NaN
# 12       NaN           NaN          NaN       NaN
# 13       NaN           NaN          NaN       NaN
# 14       NaN           NaN          NaN       NaN
#
# [15 rows x 36 columns]

# %%
final_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214656 entries, 0 to 214655
# Data columns (total 36 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   POLITICAL_UNIT             214656 non-null  object
#  1   NAME                       214656 non-null  object
#  2   WGMS_ID                    214656 non-null  int64
#  3   LATITUDE                   214656 non-null  float64
#  4   LONGITUDE                  214656 non-null  float64
#  5   GLACIER_REGION_CODE        214656 non-null  object
#  6   GLACIER_SUBREGION_CODE     214656 non-null  object
#  7   YEAR                       8 non-null       float64
#  8   HIGHEST_ELEVATION_x        7 non-null       float64
#  9   MEDIAN_ELEVATION           7 non-null       float64
#  10  LOWEST_ELEVATION_x         7 non-null       float64
#  11  LENGTH                     7 non-null       float64
#  12  AREA_general               7 non-null       float64
#  13  AREA_CHANGE                0 non-null       float64
#  14  THICKNESS_CHG              0 non-null       float64
#  15  VOLUME_CHANGE              0 non-null       float64
#  16  AREA_elevationband         8 non-null       float64
#  17  WINTER_BALANCE             0 non-null       float64
#  18  SUMMER_BALANCE             0 non-null       float64
#  19  ANNUAL_BALANCE             8 non-null       float64
#  20  ELA                        8 non-null       float64
#  21  ACC_AREA                   4 non-null       float64
#  22  ABL_AREA                   4 non-null       float64
#  23  AAR                        8 non-null       float64
#  24  POINT_ELEVATION            0 non-null       float64
#  25  POINT_BALANCE              0 non-null       float64
#  26  FRONT_VARIATION            0 non-null       float64
#  27  QUALITATIVE_VARIATION      0 non-null       object
#  28  rec_FRONT_VARIATION        0 non-null       float64
#  29  rec_QUALITATIVE_VARIATION  0 non-null       object
#  30  ET_SURGE                   1488 non-null    object
#  31  ET_CALVING                 1488 non-null    object
#  32  ET_FLOOD                   1488 non-null    object
#  33  ET_AVALANCHE               1488 non-null    object
#  34  ET_TECTONIC                1488 non-null    object
#  35  ET_OTHER                   1488 non-null    object
# dtypes: float64(23), int64(1), object(12)
# memory usage: 59.0+ MB

# %%
final_merge.notnull().sum()
# Out:
# POLITICAL_UNIT               214656
# NAME                         214656
# WGMS_ID                      214656
# LATITUDE                     214656
# LONGITUDE                    214656
# GLACIER_REGION_CODE          214656
# GLACIER_SUBREGION_CODE       214656
# YEAR                              8
# HIGHEST_ELEVATION_x               7
# MEDIAN_ELEVATION                  7
# LOWEST_ELEVATION_x                7
# LENGTH                            7
# AREA_general                      7
# AREA_CHANGE                       0
# THICKNESS_CHG                     0
# VOLUME_CHANGE                     0
# AREA_elevationband                8
# WINTER_BALANCE                    0
# SUMMER_BALANCE                    0
# ANNUAL_BALANCE                    8
# ELA                               8
# ACC_AREA                          4
# ABL_AREA                          4
# AAR                               8
# POINT_ELEVATION                   0
# POINT_BALANCE                     0
# FRONT_VARIATION                   0
# QUALITATIVE_VARIATION             0
# rec_FRONT_VARIATION               0
# rec_QUALITATIVE_VARIATION         0
# ET_SURGE                       1488
# ET_CALVING                     1488
# ET_FLOOD                       1488
# ET_AVALANCHE                   1488
# ET_TECTONIC                    1488
# ET_OTHER                       1488
# dtype: int64

# %%
copy_final = final_merge

# %%
# Borramos las columnas cuyo año sea nulo, ya que no podemos trabajar con esos datos.
copy_final = copy_final.dropna(subset='YEAR')
copy_final['YEAR'].isna().sum()
# Out:
# 0

# %%
copy_final[['ET_AVALANCHE', 'ET_SURGE', 'ET_CALVING', 'ET_FLOOD', 'ET_TECTONIC', 'ET_OTHER']] = copy_final[['ET_AVALANCHE', 'ET_SURGE', 'ET_CALVING', 'ET_FLOOD', 'ET_TECTONIC', 'ET_OTHER']].fillna(False)
copy_final[['ET_AVALANCHE', 'ET_SURGE', 'ET_CALVING', 'ET_FLOOD', 'ET_TECTONIC', 'ET_OTHER']].isna().sum()
# Out:
# <ipython-input-320-e1ef5867bccd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   copy_final[['ET_AVALANCHE', 'ET_SURGE', 'ET_CALVING', 'ET_FLOOD', 'ET_TECTONIC', 'ET_OTHER']] = copy_final[['ET_AVALANCHE', 'ET_SURGE', 'ET_CALVING', 'ET_FLOOD', 'ET_TECTONIC', 'ET_OTHER']].fillna(False)
# ET_AVALANCHE    0
# ET_SURGE        0
# ET_CALVING      0
# ET_FLOOD        0
# ET_TECTONIC     0
# ET_OTHER        0
# dtype: int64

# %%
columnas_numericas = [ 'HIGHEST_ELEVATION_x',
       'MEDIAN_ELEVATION', 'LOWEST_ELEVATION_x', 'LENGTH', 'AREA_general',
       'AREA_CHANGE', 'THICKNESS_CHG', 'VOLUME_CHANGE', 'AREA_elevationband',
       'WINTER_BALANCE', 'SUMMER_BALANCE', 'ANNUAL_BALANCE', 'ELA', 'ACC_AREA',
       'ABL_AREA', 'AAR', 'POINT_ELEVATION', 'POINT_BALANCE',
       'FRONT_VARIATION', 'rec_FRONT_VARIATION']

# %%
corr_matrix = copy_final[columnas_numericas].corr()

# %%
plt.figure(figsize=(12,10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Matriz de correlation')
plt.show()

# %%
corr_matrix
# Out:
#                      HIGHEST_ELEVATION_x  MEDIAN_ELEVATION  \
# HIGHEST_ELEVATION_x                  NaN               NaN
# MEDIAN_ELEVATION                     NaN               NaN
# LOWEST_ELEVATION_x                   NaN               NaN
# LENGTH                               NaN               NaN
# AREA_general                         NaN               NaN
# AREA_CHANGE                          NaN               NaN
# THICKNESS_CHG                        NaN               NaN
# VOLUME_CHANGE                        NaN               NaN
# AREA_elevationband                   NaN               NaN
# WINTER_BALANCE                       NaN               NaN
# SUMMER_BALANCE                       NaN               NaN
# ANNUAL_BALANCE                       NaN               NaN
# ELA                                  NaN               NaN
# ACC_AREA                             NaN               NaN
# ABL_AREA                             NaN               NaN
# AAR                                  NaN               NaN
# POINT_ELEVATION                      NaN               NaN
# POINT_BALANCE                        NaN               NaN
# FRONT_VARIATION                      NaN               NaN
# rec_FRONT_VARIATION                  NaN               NaN
#
#                      LOWEST_ELEVATION_x    LENGTH  AREA_general  AREA_CHANGE  \
# HIGHEST_ELEVATION_x                 NaN       NaN           NaN          NaN
# MEDIAN_ELEVATION                    NaN       NaN           NaN          NaN
# LOWEST_ELEVATION_x                  NaN       NaN           NaN          NaN
# LENGTH                              NaN  1.000000      0.260428          NaN
# AREA_general                        NaN  0.260428      1.000000          NaN
# AREA_CHANGE                         NaN       NaN           NaN          NaN
# THICKNESS_CHG                       NaN       NaN           NaN          NaN
# VOLUME_CHANGE                       NaN       NaN           NaN          NaN
# AREA_elevationband                  NaN  0.944444      0.385894          NaN
# WINTER_BALANCE                      NaN       NaN           NaN          NaN
# SUMMER_BALANCE                      NaN       NaN           NaN          NaN
# ANNUAL_BALANCE                      NaN  0.743651      0.351332          NaN
# ELA                                 NaN -0.532983     -0.575912          NaN
# ACC_AREA                            NaN  0.777758      0.777759          NaN
# ABL_AREA                            NaN -0.775518     -0.775518          NaN
# AAR                                 NaN  0.575878      0.556475          NaN
# POINT_ELEVATION                     NaN       NaN           NaN          NaN
# POINT_BALANCE                       NaN       NaN           NaN          NaN
# FRONT_VARIATION                     NaN       NaN           NaN          NaN
# rec_FRONT_VARIATION                 NaN       NaN           NaN          NaN
#
#                      THICKNESS_CHG  VOLUME_CHANGE  AREA_elevationband  \
# HIGHEST_ELEVATION_x            NaN            NaN                 NaN
# MEDIAN_ELEVATION               NaN            NaN                 NaN
# LOWEST_ELEVATION_x             NaN            NaN                 NaN
# LENGTH                         NaN            NaN            0.944444
# AREA_general                   NaN            NaN            0.385894
# AREA_CHANGE                    NaN            NaN                 NaN
# THICKNESS_CHG                  NaN            NaN                 NaN
# VOLUME_CHANGE                  NaN            NaN                 NaN
# AREA_elevationband             NaN            NaN            1.000000
# WINTER_BALANCE                 NaN            NaN                 NaN
# SUMMER_BALANCE                 NaN            NaN                 NaN
# ANNUAL_BALANCE                 NaN            NaN            0.740149
# ELA                            NaN            NaN           -0.561603
# ACC_AREA                       NaN            NaN            0.935002
# ABL_AREA                       NaN            NaN           -0.933669
# AAR                            NaN            NaN            0.640920
# POINT_ELEVATION                NaN            NaN                 NaN
# POINT_BALANCE                  NaN            NaN                 NaN
# FRONT_VARIATION                NaN            NaN                 NaN
# rec_FRONT_VARIATION            NaN            NaN                 NaN
#
#                      WINTER_BALANCE  SUMMER_BALANCE  ANNUAL_BALANCE       ELA  \
# HIGHEST_ELEVATION_x             NaN             NaN             NaN       NaN
# MEDIAN_ELEVATION                NaN             NaN             NaN       NaN
# LOWEST_ELEVATION_x              NaN             NaN             NaN       NaN
# LENGTH                          NaN             NaN        0.743651 -0.532983
# AREA_general                    NaN             NaN        0.351332 -0.575912
# AREA_CHANGE                     NaN             NaN             NaN       NaN
# THICKNESS_CHG                   NaN             NaN             NaN       NaN
# VOLUME_CHANGE                   NaN             NaN             NaN       NaN
# AREA_elevationband              NaN             NaN        0.740149 -0.561603
# WINTER_BALANCE                  NaN             NaN             NaN       NaN
# SUMMER_BALANCE                  NaN             NaN             NaN       NaN
# ANNUAL_BALANCE                  NaN             NaN        1.000000 -0.865938
# ELA                             NaN             NaN       -0.865938  1.000000
# ACC_AREA                        NaN             NaN        0.978970 -0.986841
# ABL_AREA                        NaN             NaN       -0.978238  0.986481
# AAR                             NaN             NaN        0.930946 -0.979470
# POINT_ELEVATION                 NaN             NaN             NaN       NaN
# POINT_BALANCE                   NaN             NaN             NaN       NaN
# FRONT_VARIATION                 NaN             NaN             NaN       NaN
# rec_FRONT_VARIATION             NaN             NaN             NaN       NaN
#
#                      ACC_AREA  ABL_AREA       AAR  POINT_ELEVATION  \
# HIGHEST_ELEVATION_x       NaN       NaN       NaN              NaN
# MEDIAN_ELEVATION          NaN       NaN       NaN              NaN
# LOWEST_ELEVATION_x        NaN       NaN       NaN              NaN
# LENGTH               0.777758 -0.775518  0.575878              NaN
# AREA_general         0.777759 -0.775518  0.556475              NaN
# AREA_CHANGE               NaN       NaN       NaN              NaN
# THICKNESS_CHG             NaN       NaN       NaN              NaN
# VOLUME_CHANGE             NaN       NaN       NaN              NaN
# AREA_elevationband   0.935002 -0.933669  0.640920              NaN
# WINTER_BALANCE            NaN       NaN       NaN              NaN
# SUMMER_BALANCE            NaN       NaN       NaN              NaN
# ANNUAL_BALANCE       0.978970 -0.978238  0.930946              NaN
# ELA                 -0.986841  0.986481 -0.979470              NaN
# ACC_AREA             1.000000 -0.999993  0.999949              NaN
# ABL_AREA            -0.999993  1.000000 -0.999905              NaN
# AAR                  0.999949 -0.999905  1.000000              NaN
# POINT_ELEVATION           NaN       NaN       NaN              NaN
# POINT_BALANCE             NaN       NaN       NaN              NaN
# FRONT_VARIATION           NaN       NaN       NaN              NaN
# rec_FRONT_VARIATION       NaN       NaN       NaN              NaN
#
#                      POINT_BALANCE  FRONT_VARIATION  rec_FRONT_VARIATION
# HIGHEST_ELEVATION_x            NaN              NaN                  NaN
# MEDIAN_ELEVATION               NaN              NaN                  NaN
# LOWEST_ELEVATION_x             NaN              NaN                  NaN
# LENGTH                         NaN              NaN                  NaN
# AREA_general                   NaN              NaN                  NaN
# AREA_CHANGE                    NaN              NaN                  NaN
# THICKNESS_CHG                  NaN              NaN                  NaN
# VOLUME_CHANGE                  NaN              NaN                  NaN
# AREA_elevationband             NaN              NaN                  NaN
# WINTER_BALANCE                 NaN              NaN                  NaN
# SUMMER_BALANCE                 NaN              NaN                  NaN
# ANNUAL_BALANCE                 NaN              NaN                  NaN
# ELA                            NaN              NaN                  NaN
# ACC_AREA                       NaN              NaN                  NaN
# ABL_AREA                       NaN              NaN                  NaN
# AAR                            NaN              NaN                  NaN
# POINT_ELEVATION                NaN              NaN                  NaN
# POINT_BALANCE                  NaN              NaN                  NaN
# FRONT_VARIATION                NaN              NaN                  NaN
# rec_FRONT_VARIATION            NaN              NaN                  NaN

# %%
copy_final[columnas_numericas].isna().median()
# Out:
# HIGHEST_ELEVATION_x    0.0
# MEDIAN_ELEVATION       0.0
# LOWEST_ELEVATION_x     0.0
# LENGTH                 0.0
# AREA_general           0.0
# AREA_CHANGE            1.0
# THICKNESS_CHG          1.0
# VOLUME_CHANGE          1.0
# AREA_elevationband     0.0
# WINTER_BALANCE         1.0
# SUMMER_BALANCE         1.0
# ANNUAL_BALANCE         0.0
# ELA                    0.0
# ACC_AREA               0.5
# ABL_AREA               0.5
# AAR                    0.0
# POINT_ELEVATION        1.0
# POINT_BALANCE          1.0
# FRONT_VARIATION        1.0
# rec_FRONT_VARIATION    1.0
# dtype: float64

# %%
# Calcular el porcentaje de nulos por columnas
porcentaje_nulos_por_columna = (copy_final.isnull().sum() / len(copy_final)) * 100

print("Porcentaje de nulos por columnas:")
print(porcentaje_nulos_por_columna)
# Out:
# Porcentaje de nulos por columnas:
# POLITICAL_UNIT                 0.0
# NAME                           0.0
# WGMS_ID                        0.0
# LATITUDE                       0.0
# LONGITUDE                      0.0
# GLACIER_REGION_CODE            0.0
# GLACIER_SUBREGION_CODE         0.0
# YEAR                           0.0
# HIGHEST_ELEVATION_x           12.5
# MEDIAN_ELEVATION              12.5
# LOWEST_ELEVATION_x            12.5
# LENGTH                        12.5
# AREA_general                  12.5
# AREA_CHANGE                  100.0
# THICKNESS_CHG                100.0
# VOLUME_CHANGE                100.0
# AREA_elevationband             0.0
# WINTER_BALANCE               100.0
# SUMMER_BALANCE               100.0
# ANNUAL_BALANCE                 0.0
# ELA                            0.0
# ACC_AREA                      50.0
# ABL_AREA                      50.0
# AAR                            0.0
# POINT_ELEVATION              100.0
# POINT_BALANCE                100.0
# FRONT_VARIATION              100.0
# QUALITATIVE_VARIATION        100.0
# rec_FRONT_VARIATION          100.0
# rec_QUALITATIVE_VARIATION    100.0
# ET_SURGE                       0.0
# ET_CALVING                     0.0
# ET_FLOOD                       0.0
# ET_AVALANCHE                   0.0
# ET_TECTONIC                    0.0
# ET_OTHER                       0.0
# dtype: float64

# %%
copy_final.sample(10).QUALITATIVE_VARIATION
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-329-89d2192d4cde> in <cell line: 1>()
# ----> 1 copy_final.sample(10).QUALITATIVE_VARIATION
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5856             weights = sample.preprocess_weights(self, weights, axis)
#    5857
# -> 5858         sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    5859         result = self.take(sampled_indices, axis=axis)
#    5860
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/sample.py in sample(obj_len, size, replace, weights, random_state)
#     149             raise ValueError("Invalid weights: weights sum to zero")
#     150
# --> 151     return random_state.choice(obj_len, size=size, replace=replace, p=weights).astype(
#     152         np.intp, copy=False
#     153     )
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'

# %%
copy_final = copy_final.drop(columns=['FRONT_VARIATION','QUALITATIVE_VARIATION','rec_FRONT_VARIATION','rec_QUALITATIVE_VARIATION'])

# %%
copy_final_cleaned = copy_final.dropna(subset=['VOLUME_CHANGE'])
copy_final_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 32 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   POLITICAL_UNIT          0 non-null      object
#  1   NAME                    0 non-null      object
#  2   WGMS_ID                 0 non-null      int64
#  3   LATITUDE                0 non-null      float64
#  4   LONGITUDE               0 non-null      float64
#  5   GLACIER_REGION_CODE     0 non-null      object
#  6   GLACIER_SUBREGION_CODE  0 non-null      object
#  7   YEAR                    0 non-null      float64
#  8   HIGHEST_ELEVATION_x     0 non-null      float64
#  9   MEDIAN_ELEVATION        0 non-null      float64
#  10  LOWEST_ELEVATION_x      0 non-null      float64
#  11  LENGTH                  0 non-null      float64
#  12  AREA_general            0 non-null      float64
#  13  AREA_CHANGE             0 non-null      float64
#  14  THICKNESS_CHG           0 non-null      float64
#  15  VOLUME_CHANGE           0 non-null      float64
#  16  AREA_elevationband      0 non-null      float64
#  17  WINTER_BALANCE          0 non-null      float64
#  18  SUMMER_BALANCE          0 non-null      float64
#  19  ANNUAL_BALANCE          0 non-null      float64
#  20  ELA                     0 non-null      float64
#  21  ACC_AREA                0 non-null      float64
#  22  ABL_AREA                0 non-null      float64
#  23  AAR                     0 non-null      float64
#  24  POINT_ELEVATION         0 non-null      float64
#  25  POINT_BALANCE           0 non-null      float64
#  26  ET_SURGE                0 non-null      bool
#  27  ET_CALVING              0 non-null      bool
#  28  ET_FLOOD                0 non-null      bool
#  29  ET_AVALANCHE            0 non-null      bool
#  30  ET_TECTONIC             0 non-null      bool
#  31  ET_OTHER                0 non-null      bool
# dtypes: bool(6), float64(21), int64(1), object(4)
# memory usage: 0.0+ bytes

# %%
copy_final_cleaned.isna().sum()
# Out:
# POLITICAL_UNIT            0.0
# NAME                      0.0
# WGMS_ID                   0.0
# LATITUDE                  0.0
# LONGITUDE                 0.0
# GLACIER_REGION_CODE       0.0
# GLACIER_SUBREGION_CODE    0.0
# YEAR                      0.0
# HIGHEST_ELEVATION_x       0.0
# MEDIAN_ELEVATION          0.0
# LOWEST_ELEVATION_x        0.0
# LENGTH                    0.0
# AREA_general              0.0
# AREA_CHANGE               0.0
# THICKNESS_CHG             0.0
# VOLUME_CHANGE             0.0
# AREA_elevationband        0.0
# WINTER_BALANCE            0.0
# SUMMER_BALANCE            0.0
# ANNUAL_BALANCE            0.0
# ELA                       0.0
# ACC_AREA                  0.0
# ABL_AREA                  0.0
# AAR                       0.0
# POINT_ELEVATION           0.0
# POINT_BALANCE             0.0
# ET_SURGE                  0.0
# ET_CALVING                0.0
# ET_FLOOD                  0.0
# ET_AVALANCHE              0.0
# ET_TECTONIC               0.0
# ET_OTHER                  0.0
# dtype: float64

# %%
# En este dataset de prueba, eliminamos las columnas que consideramos que reiteran info:
columnas_a_eliminar = ['HIGHEST_ELEVATION_x','LOWEST_ELEVATION_x','WINTER_BALANCE','SUMMER_BALANCE']
copy_prueba = copy_final_cleaned
copy_prueba = copy_prueba.drop(columns=columnas_a_eliminar)
copy_prueba.isna().sum()
# Out:
# POLITICAL_UNIT            0.0
# NAME                      0.0
# WGMS_ID                   0.0
# LATITUDE                  0.0
# LONGITUDE                 0.0
# GLACIER_REGION_CODE       0.0
# GLACIER_SUBREGION_CODE    0.0
# YEAR                      0.0
# MEDIAN_ELEVATION          0.0
# LENGTH                    0.0
# AREA_general              0.0
# AREA_CHANGE               0.0
# THICKNESS_CHG             0.0
# VOLUME_CHANGE             0.0
# AREA_elevationband        0.0
# ANNUAL_BALANCE            0.0
# ELA                       0.0
# ACC_AREA                  0.0
# ABL_AREA                  0.0
# AAR                       0.0
# POINT_ELEVATION           0.0
# POINT_BALANCE             0.0
# ET_SURGE                  0.0
# ET_CALVING                0.0
# ET_FLOOD                  0.0
# ET_AVALANCHE              0.0
# ET_TECTONIC               0.0
# ET_OTHER                  0.0
# dtype: float64

# %%
# Eliminamos aquellos valores que sean nulos:
copy_prueba = copy_prueba.dropna()

# %%
# copy_prueba = copy_final_cleaned.dropna()
copy_prueba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   POLITICAL_UNIT          0 non-null      object
#  1   NAME                    0 non-null      object
#  2   WGMS_ID                 0 non-null      int64
#  3   LATITUDE                0 non-null      float64
#  4   LONGITUDE               0 non-null      float64
#  5   GLACIER_REGION_CODE     0 non-null      object
#  6   GLACIER_SUBREGION_CODE  0 non-null      object
#  7   YEAR                    0 non-null      float64
#  8   MEDIAN_ELEVATION        0 non-null      float64
#  9   LENGTH                  0 non-null      float64
#  10  AREA_general            0 non-null      float64
#  11  AREA_CHANGE             0 non-null      float64
#  12  THICKNESS_CHG           0 non-null      float64
#  13  VOLUME_CHANGE           0 non-null      float64
#  14  AREA_elevationband      0 non-null      float64
#  15  ANNUAL_BALANCE          0 non-null      float64
#  16  ELA                     0 non-null      float64
#  17  ACC_AREA                0 non-null      float64
#  18  ABL_AREA                0 non-null      float64
#  19  AAR                     0 non-null      float64
#  20  POINT_ELEVATION         0 non-null      float64
#  21  POINT_BALANCE           0 non-null      float64
#  22  ET_SURGE                0 non-null      bool
#  23  ET_CALVING              0 non-null      bool
#  24  ET_FLOOD                0 non-null      bool
#  25  ET_AVALANCHE            0 non-null      bool
#  26  ET_TECTONIC             0 non-null      bool
#  27  ET_OTHER                0 non-null      bool
# dtypes: bool(6), float64(17), int64(1), object(4)
# memory usage: 0.0+ bytes

# %%
copy_prueba.isna().sum()
# Out:
# POLITICAL_UNIT            0.0
# NAME                      0.0
# WGMS_ID                   0.0
# LATITUDE                  0.0
# LONGITUDE                 0.0
# GLACIER_REGION_CODE       0.0
# GLACIER_SUBREGION_CODE    0.0
# YEAR                      0.0
# MEDIAN_ELEVATION          0.0
# LENGTH                    0.0
# AREA_general              0.0
# AREA_CHANGE               0.0
# THICKNESS_CHG             0.0
# VOLUME_CHANGE             0.0
# AREA_elevationband        0.0
# ANNUAL_BALANCE            0.0
# ELA                       0.0
# ACC_AREA                  0.0
# ABL_AREA                  0.0
# AAR                       0.0
# POINT_ELEVATION           0.0
# POINT_BALANCE             0.0
# ET_SURGE                  0.0
# ET_CALVING                0.0
# ET_FLOOD                  0.0
# ET_AVALANCHE              0.0
# ET_TECTONIC               0.0
# ET_OTHER                  0.0
# dtype: float64

# %%
# Contar las ocurrencias de cada valor en la columna 'NAME'
value_names = copy_prueba['NAME'].value_counts()

# Obtener los nombres que se repiten al menos 50 veces
repeated_names = value_names[value_names >= 50].index

# Filtrar el DataFrame original para quedarse solo con estos nombres
copy_prueba = copy_prueba[copy_prueba['NAME'].isin(repeated_names)]

# Mostramos el dataset:
copy_prueba.head(35)
# Out:
# Empty DataFrame
# Columns: [POLITICAL_UNIT, NAME, WGMS_ID, LATITUDE, LONGITUDE, GLACIER_REGION_CODE, GLACIER_SUBREGION_CODE, YEAR, MEDIAN_ELEVATION, LENGTH, AREA_general, AREA_CHANGE, THICKNESS_CHG, VOLUME_CHANGE, AREA_elevationband, ANNUAL_BALANCE, ELA, ACC_AREA, ABL_AREA, AAR, POINT_ELEVATION, POINT_BALANCE, ET_SURGE, ET_CALVING, ET_FLOOD, ET_AVALANCHE, ET_TECTONIC, ET_OTHER]
# Index: []
#
# [0 rows x 28 columns]

# %%
copy_prueba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   POLITICAL_UNIT          0 non-null      object
#  1   NAME                    0 non-null      object
#  2   WGMS_ID                 0 non-null      int64
#  3   LATITUDE                0 non-null      float64
#  4   LONGITUDE               0 non-null      float64
#  5   GLACIER_REGION_CODE     0 non-null      object
#  6   GLACIER_SUBREGION_CODE  0 non-null      object
#  7   YEAR                    0 non-null      float64
#  8   MEDIAN_ELEVATION        0 non-null      float64
#  9   LENGTH                  0 non-null      float64
#  10  AREA_general            0 non-null      float64
#  11  AREA_CHANGE             0 non-null      float64
#  12  THICKNESS_CHG           0 non-null      float64
#  13  VOLUME_CHANGE           0 non-null      float64
#  14  AREA_elevationband      0 non-null      float64
#  15  ANNUAL_BALANCE          0 non-null      float64
#  16  ELA                     0 non-null      float64
#  17  ACC_AREA                0 non-null      float64
#  18  ABL_AREA                0 non-null      float64
#  19  AAR                     0 non-null      float64
#  20  POINT_ELEVATION         0 non-null      float64
#  21  POINT_BALANCE           0 non-null      float64
#  22  ET_SURGE                0 non-null      bool
#  23  ET_CALVING              0 non-null      bool
#  24  ET_FLOOD                0 non-null      bool
#  25  ET_AVALANCHE            0 non-null      bool
#  26  ET_TECTONIC             0 non-null      bool
#  27  ET_OTHER                0 non-null      bool
# dtypes: bool(6), float64(17), int64(1), object(4)
# memory usage: 0.0+ bytes

# %%
copy_prueba['NAME'].unique()
# Out:
# array([], dtype=object)

# %% [markdown]
# ### AÑADIMOS **VARIABLES EXOGENAS** 🌎

# %% [markdown]
#  - cdd --> Annual consecutive dry days
#  - pr --> Monthly mean of daily accumulated precipitation --> Calculada media anual
#  - rx1day --> Monthly maximum of 1-day accumulated precipitation --> Calculada media anual
#
#  - t --> Monthly mean of daily mean temperature --> Calculada media anual
#  - tn--> Monthly mean of daily minimum temperature --> Calculada media anual

# %%
# Leemos el dataset con las temperaturas, precipitaciones, etc...
temp_df = pd.read_csv('/content/drive/MyDrive/DATASETS/Copia de all_data_predictions_1950_2100.csv')
temp_df.head(20)
# Out:
#     Year  Latitude  Longitude        PR  PR_rcp26  PR_rcp85    RX1DAY  \
# 0   1950     -89.0     -179.0  0.210104       NaN       NaN  1.151218
# 1   1950     -89.0     -177.0  0.215458       NaN       NaN  1.178105
# 2   1950     -89.0     -175.0  0.218725       NaN       NaN  1.198113
# 3   1950     -89.0     -173.0  0.221469       NaN       NaN  1.213710
# 4   1950     -89.0     -171.0  0.224200       NaN       NaN  1.231212
# 5   1950     -89.0     -169.0  0.228681       NaN       NaN  1.260251
# 6   1950     -89.0     -167.0  0.232439       NaN       NaN  1.285327
# 7   1950     -89.0     -165.0  0.237047       NaN       NaN  1.320613
# 8   1950     -89.0     -163.0  0.242912       NaN       NaN  1.357893
# 9   1950     -89.0     -161.0  0.247836       NaN       NaN  1.383332
# 10  1950     -89.0     -159.0  0.249933       NaN       NaN  1.394615
# 11  1950     -89.0     -157.0  0.252071       NaN       NaN  1.409550
# 12  1950     -89.0     -155.0  0.257422       NaN       NaN  1.454890
# 13  1950     -89.0     -153.0  0.259446       NaN       NaN  1.466732
# 14  1950     -89.0     -151.0  0.259014       NaN       NaN  1.483873
# 15  1950     -89.0     -149.0  0.259463       NaN       NaN  1.485972
# 16  1950     -89.0     -147.0  0.255559       NaN       NaN  1.449429
# 17  1950     -89.0     -145.0  0.256126       NaN       NaN  1.452962
# 18  1950     -89.0     -143.0  0.255924       NaN       NaN  1.446704
# 19  1950     -89.0     -141.0  0.256202       NaN       NaN  1.448147
#
#     RX1DAY_rcp26  RX1DAY_rcp85         TN  TN_rcp26  TN_rcp85          T  \
# 0            NaN           NaN -46.137047       NaN       NaN -44.590789
# 1            NaN           NaN -46.003121       NaN       NaN -44.460775
# 2            NaN           NaN -45.896002       NaN       NaN -44.357907
# 3            NaN           NaN -45.771167       NaN       NaN -44.240403
# 4            NaN           NaN -45.704203       NaN       NaN -44.183959
# 5            NaN           NaN -45.564916       NaN       NaN -44.051648
# 6            NaN           NaN -45.387457       NaN       NaN -43.871877
# 7            NaN           NaN -45.238663       NaN       NaN -43.728819
# 8            NaN           NaN -45.104576       NaN       NaN -43.600471
# 9            NaN           NaN -44.988798       NaN       NaN -43.488447
# 10           NaN           NaN -44.896880       NaN       NaN -43.398797
# 11           NaN           NaN -44.801620       NaN       NaN -43.306714
# 12           NaN           NaN -44.698918       NaN       NaN -43.207146
# 13           NaN           NaN -44.620434       NaN       NaN -43.131073
# 14           NaN           NaN -44.559834       NaN       NaN -43.071081
# 15           NaN           NaN -44.493526       NaN       NaN -43.007324
# 16           NaN           NaN -44.488803       NaN       NaN -43.001664
# 17           NaN           NaN -44.454567       NaN       NaN -42.967406
# 18           NaN           NaN -44.436467       NaN       NaN -42.948924
# 19           NaN           NaN -44.420691       NaN       NaN -42.932951
#
#     T_rcp26  T_rcp85         CDD  CDD_rcp26  CDD_rcp85
# 0       NaN      NaN  130.136012        NaN        NaN
# 1       NaN      NaN  125.795663        NaN        NaN
# 2       NaN      NaN  124.784348        NaN        NaN
# 3       NaN      NaN  123.506196        NaN        NaN
# 4       NaN      NaN  123.396148        NaN        NaN
# 5       NaN      NaN  121.204876        NaN        NaN
# 6       NaN      NaN  120.757173        NaN        NaN
# 7       NaN      NaN  123.129041        NaN        NaN
# 8       NaN      NaN  121.591123        NaN        NaN
# 9       NaN      NaN  120.009564        NaN        NaN
# 10      NaN      NaN  120.018689        NaN        NaN
# 11      NaN      NaN  118.968380        NaN        NaN
# 12      NaN      NaN  114.177869        NaN        NaN
# 13      NaN      NaN  114.921067        NaN        NaN
# 14      NaN      NaN  113.462992        NaN        NaN
# 15      NaN      NaN  112.883183        NaN        NaN
# 16      NaN      NaN  112.634698        NaN        NaN
# 17      NaN      NaN  111.584927        NaN        NaN
# 18      NaN      NaN  112.353852        NaN        NaN
# 19      NaN      NaN  115.797986        NaN        NaN

# %%
# Uniremos los dos datasets en base a que los dos primeros dígitos de la columna latitud y longitud coincidan junto al año
# Para ello añadiremos columnas en ambos datsets con solo los dos primeros dígitos.

# Función para obtener los primeros dos caracteres si es positivo, tres si es negativo
def obtener_primeros_digitos(valor):
    valor_str = str(valor)
    if valor_str.startswith('-'):
        return valor_str[:2]
    else:
        return valor_str[:1]

temp_df['longitud_2d'] = temp_df['Longitude'].apply(obtener_primeros_digitos)
temp_df['latitud_2d'] = temp_df['Latitude'].apply(obtener_primeros_digitos)
copy_prueba['longitud_2d'] = copy_prueba['LONGITUDE'].apply(obtener_primeros_digitos)
copy_prueba['latitud_2d'] = copy_prueba['LATITUDE'].apply(obtener_primeros_digitos)

# %%
# Comprobamos resultados:
temp_df.head(15)
# Out:
#     Year  Latitude  Longitude        PR  PR_rcp26  PR_rcp85    RX1DAY  \
# 0   1950     -89.0     -179.0  0.210104       NaN       NaN  1.151218
# 1   1950     -89.0     -177.0  0.215458       NaN       NaN  1.178105
# 2   1950     -89.0     -175.0  0.218725       NaN       NaN  1.198113
# 3   1950     -89.0     -173.0  0.221469       NaN       NaN  1.213710
# 4   1950     -89.0     -171.0  0.224200       NaN       NaN  1.231212
# 5   1950     -89.0     -169.0  0.228681       NaN       NaN  1.260251
# 6   1950     -89.0     -167.0  0.232439       NaN       NaN  1.285327
# 7   1950     -89.0     -165.0  0.237047       NaN       NaN  1.320613
# 8   1950     -89.0     -163.0  0.242912       NaN       NaN  1.357893
# 9   1950     -89.0     -161.0  0.247836       NaN       NaN  1.383332
# 10  1950     -89.0     -159.0  0.249933       NaN       NaN  1.394615
# 11  1950     -89.0     -157.0  0.252071       NaN       NaN  1.409550
# 12  1950     -89.0     -155.0  0.257422       NaN       NaN  1.454890
# 13  1950     -89.0     -153.0  0.259446       NaN       NaN  1.466732
# 14  1950     -89.0     -151.0  0.259014       NaN       NaN  1.483873
#
#     RX1DAY_rcp26  RX1DAY_rcp85         TN  TN_rcp26  TN_rcp85          T  \
# 0            NaN           NaN -46.137047       NaN       NaN -44.590789
# 1            NaN           NaN -46.003121       NaN       NaN -44.460775
# 2            NaN           NaN -45.896002       NaN       NaN -44.357907
# 3            NaN           NaN -45.771167       NaN       NaN -44.240403
# 4            NaN           NaN -45.704203       NaN       NaN -44.183959
# 5            NaN           NaN -45.564916       NaN       NaN -44.051648
# 6            NaN           NaN -45.387457       NaN       NaN -43.871877
# 7            NaN           NaN -45.238663       NaN       NaN -43.728819
# 8            NaN           NaN -45.104576       NaN       NaN -43.600471
# 9            NaN           NaN -44.988798       NaN       NaN -43.488447
# 10           NaN           NaN -44.896880       NaN       NaN -43.398797
# 11           NaN           NaN -44.801620       NaN       NaN -43.306714
# 12           NaN           NaN -44.698918       NaN       NaN -43.207146
# 13           NaN           NaN -44.620434       NaN       NaN -43.131073
# 14           NaN           NaN -44.559834       NaN       NaN -43.071081
#
#     T_rcp26  T_rcp85         CDD  CDD_rcp26  CDD_rcp85 longitud_2d latitud_2d
# 0       NaN      NaN  130.136012        NaN        NaN          -1         -8
# 1       NaN      NaN  125.795663        NaN        NaN          -1         -8
# 2       NaN      NaN  124.784348        NaN        NaN          -1         -8
# 3       NaN      NaN  123.506196        NaN        NaN          -1         -8
# 4       NaN      NaN  123.396148        NaN        NaN          -1         -8
# 5       NaN      NaN  121.204876        NaN        NaN          -1         -8
# 6       NaN      NaN  120.757173        NaN        NaN          -1         -8
# 7       NaN      NaN  123.129041        NaN        NaN          -1         -8
# 8       NaN      NaN  121.591123        NaN        NaN          -1         -8
# 9       NaN      NaN  120.009564        NaN        NaN          -1         -8
# 10      NaN      NaN  120.018689        NaN        NaN          -1         -8
# 11      NaN      NaN  118.968380        NaN        NaN          -1         -8
# 12      NaN      NaN  114.177869        NaN        NaN          -1         -8
# 13      NaN      NaN  114.921067        NaN        NaN          -1         -8
# 14      NaN      NaN  113.462992        NaN        NaN          -1         -8

# %%
# Comprobamos resultados:
copy_prueba.head(15)
# Out:
#      POLITICAL_UNIT            NAME  WGMS_ID  LATITUDE  LONGITUDE  \
# 7276             AR  BROWN SUPERIOR     3903   -29.983 -69.641998
# 7277             AR  BROWN SUPERIOR     3903   -29.983 -69.641998
# 7278             AR  BROWN SUPERIOR     3903   -29.983 -69.641998
# 7279             AR  BROWN SUPERIOR     3903   -29.983 -69.641998
# 7280             AR  BROWN SUPERIOR     3903   -29.983 -69.641998
# 7281             AR  BROWN SUPERIOR     3903   -29.983 -69.641998
# 7282             AR  BROWN SUPERIOR     3903   -29.983 -69.641998
# 7283             AR  BROWN SUPERIOR     3903   -29.983 -69.641998
# 7284             AR  BROWN SUPERIOR     3903   -29.983 -69.641998
# 7285             AR  BROWN SUPERIOR     3903   -29.983 -69.641998
# 7286             AR  BROWN SUPERIOR     3903   -29.983 -69.641998
# 7287             AR  BROWN SUPERIOR     3903   -29.983 -69.641998
# 7288             AR  BROWN SUPERIOR     3903   -29.983 -69.641998
# 7289             AR  BROWN SUPERIOR     3903   -29.983 -69.641998
# 7290             AR  BROWN SUPERIOR     3903   -29.983 -69.641998
#
#      GLACIER_REGION_CODE    YEAR  MEDIAN_ELEVATION     LENGTH  AREA_general  \
# 7276                 SAN  2015.0            5060.0  569.99999         175.1
# 7277                 SAN  2015.0            5060.0  569.99999         175.1
# 7278                 SAN  2015.0            5060.0  569.99999         175.1
# 7279                 SAN  2015.0            5060.0  569.99999         175.1
# 7280                 SAN  2015.0            5060.0  569.99999         175.1
# 7281                 SAN  2015.0            5060.0  569.99999         175.1
# 7282                 SAN  2015.0            5060.0  569.99999         175.1
# 7283                 SAN  2015.0            5060.0  569.99999         175.1
# 7284                 SAN  2015.0            5060.0  569.99999         175.1
# 7285                 SAN  2015.0            5060.0  569.99999         175.1
# 7286                 SAN  2015.0            5060.0  569.99999         175.1
# 7287                 SAN  2015.0            5060.0  569.99999         175.1
# 7288                 SAN  2015.0            5060.0  569.99999         175.1
# 7289                 SAN  2015.0            5060.0  569.99999         175.1
# 7290                 SAN  2015.0            5060.0  569.99999         175.1
#
#       ...  POINT_ELEVATION  POINT_BALANCE  ET_SURGE  ET_CALVING  ET_FLOOD  \
# 7276  ...           5050.0           34.0     False       False     False
# 7277  ...           5050.0        -1981.0     False       False     False
# 7278  ...           4989.0           14.0     False       False     False
# 7279  ...           4989.0        -3018.0     False       False     False
# 7280  ...           5009.0         -102.0     False       False     False
# 7281  ...           5009.0        -3000.0     False       False     False
# 7282  ...           5115.0        -1335.0     False       False     False
# 7283  ...           5115.0        -2805.0     False       False     False
# 7284  ...           5066.0           26.0     False       False     False
# 7285  ...           5066.0        -2082.0     False       False     False
# 7286  ...           5091.0           73.0     False       False     False
# 7287  ...           5091.0        -1896.0     False       False     False
# 7288  ...           5059.0          161.0     False       False     False
# 7289  ...           5059.0        -1819.0     False       False     False
# 7290  ...           5011.0          -43.0     False       False     False
#
#       ET_AVALANCHE  ET_TECTONIC  ET_OTHER  longitud_2d  latitud_2d
# 7276         False        False     False           -6          -2
# 7277         False        False     False           -6          -2
# 7278         False        False     False           -6          -2
# 7279         False        False     False           -6          -2
# 7280         False        False     False           -6          -2
# 7281         False        False     False           -6          -2
# 7282         False        False     False           -6          -2
# 7283         False        False     False           -6          -2
# 7284         False        False     False           -6          -2
# 7285         False        False     False           -6          -2
# 7286         False        False     False           -6          -2
# 7287         False        False     False           -6          -2
# 7288         False        False     False           -6          -2
# 7289         False        False     False           -6          -2
# 7290         False        False     False           -6          -2
#
# [15 rows x 29 columns]

# %%
# Borraremos las columnas con valores nulos del dataset temp_df:
#temp_df_cleaned = temp_df.drop(columns = ['PR_rcp26', 'PR_rcp85', 'RX1DAY_rcp26', 'RX1DAY_rcp85','TN_rcp26', 'TN_rcp85', 'T_rcp26', 'T_rcp85', 'CDD_rcp26', 'CDD_rcp85'] )
temp_df_cleaned = temp_df
# Cambiamos el nombre de la columna 'Year' para luego hacer el merge correctamente:
temp_df_cleaned.rename(columns = {'Year':'YEAR'}, inplace = True)

# %%
# Comprobamos resultados
temp_df_cleaned.head()
# Out:
#    YEAR  Latitude  Longitude        PR  PR_rcp26  PR_rcp85    RX1DAY  \
# 0  1950     -89.0     -179.0  0.210104       NaN       NaN  1.151218
# 1  1950     -89.0     -177.0  0.215458       NaN       NaN  1.178105
# 2  1950     -89.0     -175.0  0.218725       NaN       NaN  1.198113
# 3  1950     -89.0     -173.0  0.221469       NaN       NaN  1.213710
# 4  1950     -89.0     -171.0  0.224200       NaN       NaN  1.231212
#
#    RX1DAY_rcp26  RX1DAY_rcp85         TN  TN_rcp26  TN_rcp85          T  \
# 0           NaN           NaN -46.137047       NaN       NaN -44.590789
# 1           NaN           NaN -46.003121       NaN       NaN -44.460775
# 2           NaN           NaN -45.896002       NaN       NaN -44.357907
# 3           NaN           NaN -45.771167       NaN       NaN -44.240403
# 4           NaN           NaN -45.704203       NaN       NaN -44.183959
#
#    T_rcp26  T_rcp85         CDD  CDD_rcp26  CDD_rcp85 longitud_2d latitud_2d
# 0      NaN      NaN  130.136012        NaN        NaN          -1         -8
# 1      NaN      NaN  125.795663        NaN        NaN          -1         -8
# 2      NaN      NaN  124.784348        NaN        NaN          -1         -8
# 3      NaN      NaN  123.506196        NaN        NaN          -1         -8
# 4      NaN      NaN  123.396148        NaN        NaN          -1         -8

# %%
temp_df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2446200 entries, 0 to 2446199
# Data columns (total 20 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   YEAR          int64
#  1   Latitude      float64
#  2   Longitude     float64
#  3   PR            float64
#  4   PR_rcp26      float64
#  5   PR_rcp85      float64
#  6   RX1DAY        float64
#  7   RX1DAY_rcp26  float64
#  8   RX1DAY_rcp85  float64
#  9   TN            float64
#  10  TN_rcp26      float64
#  11  TN_rcp85      float64
#  12  T             float64
#  13  T_rcp26       float64
#  14  T_rcp85       float64
#  15  CDD           float64
#  16  CDD_rcp26     float64
#  17  CDD_rcp85     float64
#  18  longitud_2d   object
#  19  latitud_2d    object
# dtypes: float64(17), int64(1), object(2)
# memory usage: 373.3+ MB

# %%
temp_df_cleaned.isna().sum()
# Out:
# YEAR                  0
# Latitude              0
# Longitude             0
# PR              1539000
# PR_rcp26         907200
# PR_rcp85         907200
# RX1DAY          1539000
# RX1DAY_rcp26     907200
# RX1DAY_rcp85     907200
# TN              1539000
# TN_rcp26         907200
# TN_rcp85         907200
# T               1539000
# T_rcp26          907200
# T_rcp85          907200
# CDD             1539000
# CDD_rcp26        907200
# CDD_rcp85        907200
# longitud_2d           0
# latitud_2d            0
# dtype: int64

# %%
# Hacemos el merge:
glaciares_final = pd.merge(copy_prueba, temp_df_cleaned, on = ['longitud_2d', 'latitud_2d', 'YEAR'], suffixes = ('_copy_prueba', '_temp_df'), how='outer')

# %%
glaciares_final.head(45)

# %%
# Eliminamos las columnas que creamos antes para hacer el merge y las de latitud y longitud del df de temperatura ya que no nos sirven:
glaciares_final = glaciares_final.drop(columns = ['longitud_2d', 'latitud_2d','Latitude', 'Longitude'])

# %%
# Comprobamos el resultado
glaciares_final.columns

# %%
glaciares_final.to_csv('/content/drive/MyDrive/DATASETS/dataset_glaciares.csv', index=False)
